# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import numbers
import json
import copy

# %%
# Conduct a search on Zillow by inserting the postal code.

# Get the search results URL https://www.zillow.com/homes/02128_rb/.

# Download HTML code through Python Requests.

# Parse the page through LXML.

# Export the extracted data to a CSV file.

# %%
# Conduct a search on Zillow by inserting the postal code.
houses = {}

req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}
with requests.Session() as s:
    city = 'portland/' #*****change this city to what you want*****
    url = 'https://www.zillow.com/homes/for_sale/'+city    
    r = s.get(url, headers=req_headers)
 # https://www.zillow.com/homedetails/
sresponse = r.content

# %%
soup = BeautifulSoup(r.content, 'html.parser')
url_json_str = soup.find_all(string = re.compile('"detailUrl":"https://www.zillow.com/homedetails'))
detail_urls = json.loads(str(url_json_str[0])[4:-3])
print(detail_urls)
# Out:
# {'queryState': {'usersSearchTerm': 'Portland, OR', 'mapBounds': {'west': -122.919539, 'east': -122.471849, 'south': 45.395871, 'north': 45.714497}, 'regionSelection': [{'regionId': 13373, 'regionType': 6}], 'isMapVisible': True, 'filterState': {'sortSelection': {'value': 'globalrelevanceex'}, 'isAllHomes': {'value': True}}}, 'filterDefinitions': {'keywords': {'id': 'keywords', 'shortId': 'att', 'labels': {'default': 'Keywords', 'tracking': 'Keyword'}, 'sortOrder': 2, 'type': 'String', 'defaultValue': {'value': ''}, 'exposedPillEnabled': True}, 'isPublicSchool': {'id': 'isPublicSchool', 'shortId': 'schp', 'labels': {'default': 'Public'}, 'type': 'Boolean', 'defaultValue': {'value': True}}, 'isCityView': {'id': 'isCityView', 'shortId': 'cityv', 'labels': {'default': 'City'}, 'type': 'Boolean', 'defaultValue': {'value': False}}, 'isWaterfront': {'id': 'isWaterfront', 'shortId': 'wat', 'labels': {'default': 'Waterfront'}, 'type': 'Boolean', 'defaultValue': {'value': False}}, 'isCondo': {
# ...

# %%
for link in detail_urls['cat1']['searchResults']['listResults']:
    temp = link['hdpData']['homeInfo']
    temp2 = link['detailUrl']
    if 'streetAddress' in temp.keys() and 'city' in temp.keys() and 'state' in temp.keys() and 'zipcode' in temp.keys():

        houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']] = {}
        if 'homeType' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Type'] = temp['homeType']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Type'] = None
        if 'price' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Flat Price'] = temp['price']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Flat Price'] = None
        if 'zestimate' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Zestimate'] = temp['zestimate']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['Zestimate'] = None
        if 'rentZestimate' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['rentZestimate'] = temp['rentZestimate']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['rentZestimate'] = None
        if 'taxAssessedValue' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['taxValue'] = temp['taxAssessedValue']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['taxValue'] = None
        if 'bathrooms' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['bathrooms'] = temp['bathrooms']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['bathrooms'] = None
        if 'bedrooms' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['bedrooms'] = temp['bedrooms']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['bedrooms'] = None
        if temp2:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['url'] = temp2
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['url'] = None
        if 'livingArea' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['livingArea'] = temp['livingArea']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['livingArea'] = None
        if 'zpid' in temp.keys():
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['zpid'] = temp['zpid']
        else:
            houses[temp['streetAddress'] + " " + temp['city'] + " " + temp['state'] + " " + temp['zipcode']]['zpid'] = None
print(houses)
# Out:
# {'766 N 65th St Seattle WA 98103': {'Type': 'SINGLE_FAMILY', 'Flat Price': 669000.0, 'Zestimate': 669000, 'rentZestimate': 3134, 'taxValue': 606000.0, 'bathrooms': 3.0, 'bedrooms': 3.0, 'url': 'https://www.zillow.com/homedetails/766-N-65th-St-Seattle-WA-98103/48760005_zpid/', 'livingArea': 2410.0, 'zpid': 48760005}, '4112 2nd Ave NW Seattle WA 98107': {'Type': 'SINGLE_FAMILY', 'Flat Price': 1275000.0, 'Zestimate': 1275000, 'rentZestimate': 4450, 'taxValue': 984000.0, 'bathrooms': 2.0, 'bedrooms': 2.0, 'url': 'https://www.zillow.com/homedetails/4112-2nd-Ave-NW-Seattle-WA-98107/48760139_zpid/', 'livingArea': 2450.0, 'zpid': 48760139}, '7152 29th Ave SW Seattle WA 98126': {'Type': 'SINGLE_FAMILY', 'Flat Price': 685000.0, 'Zestimate': 685000, 'rentZestimate': 2446, 'taxValue': 454000.0, 'bathrooms': 2.0, 'bedrooms': 3.0, 'url': 'https://www.zillow.com/homedetails/7152-29th-Ave-SW-Seattle-WA-98126/49083667_zpid/', 'livingArea': 1580.0, 'zpid': 49083667}, '3414 63rd Ave SW Seattle WA 98116
# ...

# %%
# <span class="Text-c11n-8-62-4__sc-aiai24-0 ctTLh"> Zestimate
# <span data-testid="price" class="Text-c11n-8-62-4__sc-aiai24-0 dpf__sc-1me8eh6-0 dDBGhS ingUtO"> Sale Price
# span class="Text-c11n-8-62-4__sc-aiai24-0 dpf__sc-2arhs5-3 bnmVPu ggUolW" Bedrooms
#
def standard_request(url):
    req_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.8',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
    }
    with requests.Session() as s:
        r = s.get(url, headers=req_headers)
    sresponse = r.content
    soup1 = BeautifulSoup(sresponse, 'html.parser')
    G = json.loads(json.loads(soup1.find_all(string=re.compile('apiCache'))[0])['apiCache']) # keys: 'VariantQuery{"zpid":48875685,"altId":null}' 'ForSaleDoubleScrollFullRenderQuery{"zpid":48875685,"contactFormRenderParameter":{"zpid":48875685,"platform":"desktop","isDoubleScroll":true}}'
    return G

# %%
def api_add(G, key, houses, key2):
    if 'lotSize' in G['VariantQuery{"zpid":'+zpid+',"altId":null}']['property'].keys():
        houses[key]['Lot Area'] = G['VariantQuery{"zpid":'+zpid+',"altId":null}']['property']['lotSize']
    else:
        houses[key]['Lot Area'] = None
    if 'yearBuilt' in G['VariantQuery{"zpid":'+zpid+',"altId":null}']['property'].keys():
        houses[key]['Year'] = G['VariantQuery{"zpid":'+zpid+',"altId":null}']['property']['yearBuilt']
    else:
        houses[key]['Year'] = None
    if 'ForSaleDoubleScrollFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}' in G.keys():
        if 'taxAnnualAmount' in G['ForSaleDoubleScrollFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['resoFacts'].keys():
            houses[key]['Annual Tax'] = G['ForSaleDoubleScrollFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['resoFacts']['taxAnnualAmount']
        else:
            houses[key]['Annual Tax'] = None
        if 'monthlyHoaFee' in G['ForSaleDoubleScrollFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property'].keys():
            houses[key]['Monthly HOA'] = G['ForSaleDoubleScrollFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['monthlyHoaFee']
        else:
            houses[key]['Monthly HOA'] = None
    elif 'ForSaleShopperPlatformFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}' in G.keys():
        if 'taxAnnualAmount' in G['ForSaleShopperPlatformFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['resoFacts'].keys():
            houses[key]['Annual Tax'] = G['ForSaleShopperPlatformFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['resoFacts']['taxAnnualAmount']
        else:
            houses[key]['Annual Tax'] = None
        if 'monthlyHoaFee' in G['ForSaleShopperPlatformFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property'].keys():
            houses[key]['Monthly HOA'] = G['ForSaleShopperPlatformFullRenderQuery{"zpid":'+zpid+',"contactFormRenderParameter":{"zpid":'+zpid+',"platform":"desktop","isDoubleScroll":true}}']['property']['monthlyHoaFee']
        else:
            houses[key]['Monthly HOA'] = None

# %%
for dic in houses.items():
    G = standard_request(dic[1]['url'])
    zpid = str(dic[1]['zpid'])
    key2 = 'VariantQuery{"zpid":' + str(dic[1]['zpid']) + ',"altId":null}'
    key = G[key2]['property']['streetAddress'] + " " + G[key2]['property']['city'] + " " + G[key2]['property']['state'] + " " + G[key2]['property']['zipcode']
    api_add(G, key, houses, zpid)

# %%
print(houses)
# Out:
# {'766 N 65th St Seattle WA 98103': {'Type': 'SINGLE_FAMILY', 'Flat Price': 669000.0, 'Zestimate': 669000, 'rentZestimate': 3134, 'taxValue': 606000.0, 'bathrooms': 3.0, 'bedrooms': 3.0, 'url': 'https://www.zillow.com/homedetails/766-N-65th-St-Seattle-WA-98103/48760005_zpid/', 'livingArea': 2410.0, 'zpid': 48760005, 'Lot Area': 2818.332, 'Annual Tax': 5980, 'Monthly HOA': None}, '4112 2nd Ave NW Seattle WA 98107': {'Type': 'SINGLE_FAMILY', 'Flat Price': 1275000.0, 'Zestimate': 1275000, 'rentZestimate': 4450, 'taxValue': 984000.0, 'bathrooms': 2.0, 'bedrooms': 2.0, 'url': 'https://www.zillow.com/homedetails/4112-2nd-Ave-NW-Seattle-WA-98107/48760139_zpid/', 'livingArea': 2450.0, 'zpid': 48760139, 'Lot Area': 4360.356, 'Annual Tax': 9625, 'Monthly HOA': None}, '7152 29th Ave SW Seattle WA 98126': {'Type': 'SINGLE_FAMILY', 'Flat Price': 685000.0, 'Zestimate': 685000, 'rentZestimate': 2446, 'taxValue': 454000.0, 'bathrooms': 2.0, 'bedrooms': 3.0, 'url': 'https://www.zillow.com/homedetails/
# ...

# %%
pandas_dict = dict()
for house in houses.items():
    simplicity = house[1]
    pandas[house[0]] = [simplicity['Type'], simplicity['Flat Price'], simplicity['Zestimate']
                       simplicity['rentZestimate'], simplicity['taxValue'], simplicity['bathrooms'],
                       simplicity['bedrooms'], simplicity['url'], simplicity['livingArea']
                       simplicity['zpid'], simplicity['Lot Area'], simplicity['Annual Tax']
                       simplicity['Monthly HOA']]

# %%
G = {'VariantQuery{"zpid":48760005,"altId":null}': {'property': {'zpid': 48760005, 'streetAddress': '766 N 65th St', 'zipcode': '98103', 'city': 'Seattle', 'state': 'WA', 'latitude': 47.676277, 'longitude': -122.348564, 'price': 669000, 'yearBuilt': 1906, 'lotSize': 2818.332, 'homeType': 'SINGLE_FAMILY', 'homeStatus': 'STATUS_UNKNOWN', 'daysOnZillow': 4, 'shouldHighlight': False, 'zestimate': 3134, 'listing_sub_type': {'is_FSBA': True}, 'isPreforeclosureAuction': False, 'homeStatusForHDP': 'FOR_SALE', 'priceForHDP': 669000, 'timeOnZillow': 1643351778000, 'isNonOwnerOccupied': False, 'isPremierBuilder': False, 'isZillowOwned': False, 'currency': 'USD', 'country': 'USA', 'taxAssessedValue': 606000, 'lotAreaValue': 2818.332, 'lotAreaUnit': 'sqft'}, 'abTests': {'HDP_WOW_NFS_OWNER_VIEW_LINK': 'CONTROL', 'ACT_SIGNIN_AFTER_SHARE': 'CONTROL', 'SEOTEST__PERMITS': 'CONTROL', 'ARCS_NON_ARCS_TO_AGENTS': 'ON', 'AndroidHDPButtonText': 'CONTROL', 'AIPERS_RT_RECS_COLLECTION_LISTING_SORT': 'CONTROL_1', 'INSTANTOFFERS_UPSELLS_OFFMARKET': 'CURIOSITY', 'EMAIL_Auto_Sign_In': 'ON', 'AndroidKFSchoolsV2': 'ON_KINGFISHER_SCHOOLS_V2', 'SXP_HDP_CONTINGENT_V2': 'ON', 'ODASH_RENT_COMPS_UPSELL': 'CONTROL', 'VL_MOB_BDP_Data': 'BLS_V2', 'SXP_REGION_AUTOCOMPLETE_SOURCE': 'TRULIA', 'AndroidAdSettings': 'ONLY_HDP_ADS_OFF', 'RE_SEO_Add_internal_links_from_RentHousesSRPstoLTapartmentSRPs': 'TEST', 'UX-Usabilla': 'CONTROL', 'SE_InstantOffer_InlineQuestionnaire': 'V1_NEWPAGE', 'AndroidRegLoginStrongPass': 'ON', 'SEOTEST__HDP_SERVICE_OFF_MARKET': 'CONTROL', 'ADT_HDP_CALLOUT': 'SAVE_AND_SHARE', 'ZO_DataStrategy_GetOfferRequestByZuid': 'ON', 'SHO_MOBILE_WEB_NAV_ADS': 'AFTER_2ND', 'ADS_BUILDER_TALK': 'ON_BOTH', 'ADS_MyAgent': 'ON', 'CDP_SERVICE': 'ON', 'DefaultToList': 'CONTROL_DEFAULT_HOME', 'AndroidFacebookTrackingDARE': 'DARE_TRACKING', 'ADS_PACE_PALS': 'CONTROL', 'ARCS_APPS_REWRITE': 'ON', 'ACQ_MOBILE_UPSELL_HDP': 'CONTROL', 'ARCS_ABAD_ATL': 'ON', 'NATIVE_AD_POSITION_IPAD': 'BELOW_SECOND', 'ACQ_TOP_SocialMentions_RatingsVSNone': 'Control_NoRatings', 'HomeHeroHeight': 'CONTROL', 'SP_NATIVE_OFF_MARKET_PAGE': 'CONTROL', 'HDP_SERVICE_FSBA': 'REACT_HDP', 'Harriet_NewsFeed': 'ON', 'ANDROID_MORE_MENU_SELLER_IMPROVEMENTS': 'ON', 'IOS_HDP_HOME_SAVE_UPSELL': 'ON', 'SEOTEST__V1_LOCALLOGIC_APARTMENTSRPS': 'CONTROL', 'ANDROID_FILTER_55': 'CONTROL_OFF', 'NC_BUILDER_MAP_LAYER': 'HDP_AND_SEARCH_MAP', 'AndroidCommuteDefault': 'CONTROL_COMMUTE_DEFAULT_OFF', 'ARCS_LDQ_DISPLAY_UI': 'CONTROL', 'MOB_FB_API_DEPRECATION': 'ON', 'DirectoryTitleTag': 'CONTROL', 'HDP_MEDIA_ENTRY_BUTTONS': 'BUTTONS', 'SEOTEST__RE_SRPTitleTags_CityStateHomesForRent_V2': 'CONTROL', 'ACT_CUSTOM_MESSAGING': 'CONTROL', 'ARCS_PROPERTY_CFRD': 'ON', 'APPS_IOS_PUSH_REGISTRATION': 'ON', 'SEOTEST__HDP_WOW_FOR_SALE_OTHER': 'CONTROL', 'UX-SatisfactionSurvey': 'CONTROL', 'HDP_WOW_FSBA_APP': 'ON', 'PERS_SORT_V0_MOB': 'SHOW_HRS', 'AndroidClickstreamSearchImpressions': 'ON_PAGEVIEW_ZPIDS', 'AndroidRegionAutoCompleteTwo': 'ON_REGION_AUTO_COMPLETE_API_TWO', 'DigsGridLayout': 'CONTROL', 'HDP_DQ_NC': 'ON', 'URLShareTracking': 'CONTROL', 'ANDROID_FILTER_FORECLOSURE_PREFORECLOSURE': 'CONTROL_OFF', 'NC_BUILDER_PROFILE': 'TEST', 'IOS_PLATFORM_DATADOG_LOGGING': 'ON', 'ADS_BLDR_TXTLNK': 'ABOVE_BLURB_LNK', 'RH_PERMANENT_RENTER_PROFILE': 'CONTROL', 'PERS_HOME_INSIGHTS_CONTENT': 'CONTROL', 'SEOTEST__RE_Add_BuildingOverview_SRP': 'CONTROL', 'RE_Move_In_Date_Filter': 'CONTROL', 'IOS_MAGELLAN_MAP': 'ON', 'HDP_SELLING_SOON_MSG': 'MOBILE_VARIANT_1', 'PA_BETH_ALAN_ALL': 'CONTROL', 'IOS_NEW_MAP_ACTIONS': 'ON_NO_NEW_SAVE_DRAW', 'iOS_Onboarding_Add_Rent_Amenities': 'CONTROL_OFF', 'IOS_UPDATE_TAB_LARGE_CARDS': 'CONTROL_OFF', 'TR_VIRTUALIZED_LIST_CARDS': 'ON', 'AndroidRentalsVideoPlayback': 'PLAYBACK_ON', 'ZSG-Colors': 'UPDATED_GOLDEN_PATH', 'ADS_PACE_QUOTE': 'CONTROL', 'IOS_ONBOARDING_SKIP_PLACEMENT': 'CONTROL_BOTTOM', 'ABService_CachedABOverridesManager': 'USE_AB_REDIS_CACHE', 'SXP_SENTRY': 'ON', 'IOS_FORECLOSURE_OFF': 'ON', 'SPT_LOADING_DOUBLE_SCROLL_ZO': 'CONTROL', 'YOLT_ABAD_MIAMI': 'CONTROL', 'AndroidZODatadogLogging': 'ON', 'ANDROID_MORE_OFFER_DASHBOARD_ENTRY': 'ON', 'RegistrationAd': 'CONTROL_OFF', 'OnboardingForIPad_AA': 'ON', 'AndroidUpdatesHomeRecs': 'ON_LIST', 'CLICKSTREAM_WEB': 'ON', 'AR_CSAT_POST_TOUR': 'VARIANT2', 'HDP_SERVICE_ZILLOW_OWNED': 'ON', 'VL_TEXT_SHARE': 'TEST', 'MOB_MAS': 'ON', 'Sell_LPAddressEntry': 'CONTROL', 'AndroidStrongerPassword': 'ON', 'RE_Flybar_Region_Services': 'CONTROL', 'ADS_EPA_LEADERBOARD_FACE': 'ON', 'IOS_CV_REFACTORING': 'ON', 'IOS_QUICK_NOTES': 'CONTROL', 'MTT_HOP_RTB_2_ONSITE_MESSAGING': 'CONTROL', 'ADS_CF_MORTGAGE_ABC_IN_APPS': 'ON', 'AR_NLP_APPOINTMENT_CONFIRMATION': 'CONTROL', 'iOSOwnerViewTest': 'CONTROL', 'AR_CSAT_STANDARD_SELECTED': 'CONTROL', 'MarketingMobileAppUpsellBannerAndroid': 'TWO_BUTTON_STYLE', 'VL_Availability_Language': 'CONTROL', 'ZOB_TOUR_ONBOARDING_WEB': 'CALENDAR_REMINDER', 'SEOTEST__ExpandedFooterLinktest': 'TEST', 'APPS_IOS_MODAL_CONTACT_FORM': 'CONTROL_OFF', 'AR_BUYER_INITIATED_RELATIONSHIPS_DELAY': 'CONTROL', 'SEOTEST__REGION_FAQ': 'ON', 'SPT_HFF_TO_PSL': 'ON', 'AndroidRentalsCombinedFilterAptsCondos': 'ON_ANDROID_RENTALS_COMBINED_FILTER_APTS_CONDOS', 'AppUpsellTopiOS': 'CONTROL_OFF', 'NC_HDP_SINGLE_SCROLL': 'ON_LINK_HIGHER', 'ADS_MobileHDPBanner': 'Control', 'AndroidForgotPasswordApiV2': 'CONTROL_FORGOT_PASSWORD_API_V2_OFF', 'HDP_AND_SEARCH_MAGELLAN': 'ON', 'HRS_HDP_RECS_CONFIG': 'CONTROL', 'NATIVE_AD_POSITION_IPHONE': 'CONTROL', 'OUTGOING_HTML_FILTER': 'CONTROL', 'SEOTEST__SXP_LIST_ONLY_SRP': 'CONTROL', 'iOSRegUpdate': 'CONTROL_OFF', 'AIPERS_SIMILAR_HOMES_GDP': 'CONTROL', 'AndroidGAPerfReporting': 'CONTROL_REPORTING_OFF', 'HDP_YOUR_HOME_COMPS_MODULE': 'ON_V1', 'IOS_RESET_PASSWORD_EMAIL_API': 'CONTROL_OFF', 'PA_LEAD_PACING': 'CONTROL', 'HDP_OPEN_HOUSE_SAVE_WEB': 'CONTROL', 'SHEN_EMS_SAVED_SEARCH': 'CONTROL', 'IOS_OFFERS_QUESTIONNAIRE_CONTACT_FORM_FIRST': 'CONTROL', 'IOS_ONBOARDING_PUSH_UPDATE': 'ON', 'HDP_WOW_NC_APP': 'ON', 'IOSFILTER_BUTTONS': 'IOSFILTER_BUTTONS_CONTROL_OFF', 'SEOTEST__HDP_WOW_RETEST': 'CONTROL', 'SXP_REACT_FOOTER_DESKTOP': 'CONTROL', 'AndroidMagellanMap': 'MAGELLAN_MAP_ON', 'AndroidZMANewLegalTerms': 'ON_ZMA_NEW_LEGAL_TERMS', 'IOS_SHOW_SELF_TOUR_V3': 'ON', 'RR_MF_OFFICE_HOUR_TOURS': 'ON', 'HDP_PROPERTY_PSL': 'CONTROL', 'ARCS_CLICK_TO_CALL_TRACKING': 'CONTROL', 'IOS_MORE_OFFER_DASHBOARD_ENTRY': 'ON', 'MTT_HMIMHW_TOP_SLOT_HOLDOUT': 'ON', 'ADS_EPA_ONE_MONTH_FREE': 'ON', 'AndroidZOHomeAccess': 'ON', 'ADS_OpaqueBAL': 'CONTROL', 'AndroidPlaybackVideo': 'SUPPORTED', 'HRS_CONTROLLER_HDP': 'ALLOWED', 'DigsSide': 'CONTROL_REG_ONLY', 'RE_LeadDistribution': 'CONTROL', 'VL_SHARE_BDP': 'TEST', 'PHONE_VL_CONTACTS': 'TRIO', 'REDIRECT_SCHOOL_DETAILS_PAGE': 'ON', 'REV_CSI_PALS': 'ON', 'YOLT_ABAD_DALLAS': 'CONTROL', 'AR_MY_AGENT_PROFILE': 'ON', 'SPT_SIMILAR_HOMES_OFF_MARKET_GDP': 'ON', 'IOS_GRANULAR_PET_FILTERS': 'ON_GRANULAR', 'LEAD_PACING_FLEX_NURTURE_INHOUSE': 'NURTURE_INHOUSE', 'ADS_NO_CF_SENSITIVE_FIELDS': 'CONTROL', 'ACQ_Search_Filters_Upsell': 'CONTROL', 'VARIANTS_BDP_768_PLUS': 'CONTROL', 'LOCATION_MODULE_VL': 'LOCATION_MODULE', 'SEL_SellerLeadsQueue': 'QUEUE', 'ADS_PACE_REGION_REDIRECT_TRAFFIC': 'CONTROL', 'YOLT_ABAD_ORLANDO': 'CONTROL', 'IOS_EMAIL_AUTO_SIGN_IN': 'ON', 'LEGO_MESSAGE_COUNT': 'COUNTER_ON', 'Z3D_HDP_PhotoWall': 'CONTROL', 'HDP_REORDER_AT_A_GLANCE': 'CONTROL', 'SEOTEST_301_Redirect_rentalURLS_houses': 'CONTROL', 'SPT_GDP_BATCH_TO_PSL_2': 'ON', 'IOS_HidePrivatePhotos': 'CONTROL_OFF', 'SXP_FLOATING_ACTION_BAR': 'ON', 'SET_REMOVE_COUNT': 'CONTROL', 'IOS_CTA_IN_GALLERY': 'CTA_BLUE', 'REV_AnnaulReceiptEnabled': 'ON', 'SET_CTA_COUNTLESS': 'CONTROL', 'REV_redirect_manage_payments_cc_to_csi': 'CONTROL', 'HOME_TRACKER_INVITE': 'ON', 'MarketingUseSubService': 'SUB_SERVICE', 'IOS_SRP_ZILLOW_OFFERS_BANNER': 'CONTROL_OFF', 'IOS_OnboardingReprompting_2': 'ON', 'iOS_Touring_V1': 'ON_DISCOVERY', 'MAS_ZG_SEARCH_OPT_IN': 'ON', 'REV_TURN_ON_OTC_ADMIN_UI': 'ON', 'SEOTEST__SRP_PAGINATION': 'ON', 'ZO_Nurture_Flow_Seller_Advisor': 'CONSULTATION', 'ARCS_ATLAS_ADS_DISPLAY': 'ON', 'HOME_TRACKER_SAVED_HOMES': 'ON', 'ZO_Questionnaire_Segment': 'CONTROL', 'SXP_LISTING_SUBTYPE': 'CONTROL', 'PERS_SORT_V0_PRE_2': 'CONTROL', 'ABS_DECISION_TOKEN_GATE': 'ON', 'ADS_RentalHomeTourMobileWeb': 'CONTROL', 'iOSCollections': 'ON_BOTTOM', 'GA_LIVE_EVENTS': 'control', 'ZO_SUB_NAV': 'CONTROL', 'HDP_ZestimateDeepDive': 'ON_W_DISAGREEMENT', 'SL_ZINSTAGRAM': 'REACT_IMAGE_UPLOADER', 'IOS_ZO_HDP_BRAND_BOOST': 'ON', 'IOS_HOME_INSIGHTS_FOR_YOU': 'ON', 'HDP_FAF_TELECOM': 'CONTROL', 'ODASH_RENT_COMPS_UPSELL_V2': 'CONTROL', 'HDP_INSPECTIONS': 'CONTROL', 'SPT_RENDER_NATIVE_ZO_HDP_PAGE': 'CONTROL', 'HDP_MWEB_PHOTOS': 'CONTROL', 'IOS_ZO_ZILLOWOWNED_FILTER': 'ON', 'KeystoneEvents3DHome': 'SEND_EVENT', 'SPT_FLYBAR_GDP_TO_REGION_API': 'ON', 'AIPERS_COLLECTIONS_UPDATES_TAB': 'CONTROL', 'ADS_EPA_INACTIVE_ZIPS': 'CONTROL', 'ARCS_PTR_CALL_AGENTS_INVENTORY': 'ON', 'IOS_PROPERTY_TAGS': 'CUSTOM_ENTRY_TRAILING', 'ANDROID_NEW_CON_SELF_TOUR': 'CONTROL_OFF', 'IOS_ZillowGroupAnalytics': 'CONTROL_OFF', 'HDP_SERVICE_FSBA_APP_V2': 'ON', 'AR_FIRST_CONNECTION_FOLLOWUP': 'CONTROL', 'ARCS_SCHEDULE_A_TOUR_MOBILE': 'ON', 'tr_top_nav_mweb': 'CONTROL', 'DigsFromHDPMobileRE': 'CONTROL_NoDigFromRE_HDP', 'RE_REDIRECT_IOS_APP_RCF': 'REDIRECTED', 'AndroidStreetView': 'STREETVIEW_ON', 'SXP_PREXIT_CLAIMS_INFO': 'ENABLED', 'IOS_2020_MAS_V2': 'ON_2', 'VL_EXPANDED_CONTENT': 'NO_BUTTON', 'IOS_HOME_LOOKUP_LIST_2020': 'ON_2', 'HDP_PublicZestimate': 'ON', 'HDP_SERVICE_NFS': 'CONTROL', 'REV_CSI_TT': 'CONTROL', 'APPS_IOS_APPLE_SATELLITE_CARDS': 'CONTROL_OFF', 'PERS_MOBILE_SEARCH': 'MY_ZILLOW_FIRST_AUTOSCROLL', 'ADT_BLOCK_FUNCTIONAL_COOKIES': 'ON', 'HDP_TOP_NAV_TOP_ONLY': 'ON', 'ACQ_HDP_Email': 'Variant_Brand', 'MAS_FB_API_DEPRECATION': 'ON', 'SEL_NEW_SELLER_LANDING_PAGE': 'ON', 'SE_InstantOffer_ZipCodes': 'PHOENIX_EXPANSION_1', 'ADS_EPA_DISPLAY_AGENT_BILLING_PORTAL': 'CONTROL', 'IOS_MOBILE_DEVICE_SERVICE': 'ON', 'ADS_INTERNATIONAL_CONTACTFORM_PHONE': 'CONTROL', 'HDP_DQ_NFS_RS': 'CONTROL', 'IOS_NATIVE_HDP': 'ON', 'SXP_NONMLS_OFF': 'CONTROL', 'SELDataScienceTest': 'CONTROL', 'ACQ_HDP_StackedvScrollaway': 'Variant_Scrollaway', 'HDP_WOW_MORTGAGE_ITERATIONS': 'CONTROL', 'APP_UPSELL_HOMEPAGE': 'CONTROL', 'IOS_GEOFENCE': 'ON_2', 'AndroidCoshoppingV1': 'CONTROL_OFF', 'VL_HEADER_OPTIMIZATION': 'CONTROL', 'AndroidRelevancySort': 'RELEVANCY_ON', 'IOS_RELEVANCY_SORT': 'RELEVANCY_ON', 'MTT_HOP_RTB_1_ONSITE_MESSAGING': 'CONTROL', 'UsePlainTextPasswordField': 'ON', 'OFFER_IN_HAND_EMAIL': 'EMAIL_ZORD_ONLY', 'ARCS_INLINE_TOUR': 'ON_BUYERS_AGENT', 'AR_CSAT_15_DAY_CHECKIN_ENABLE': 'VARIANT_1', 'ADAT_REVIEWS_REACT': 'CONTROL', 'PA_UNIVERSAL_NAV_NON_PROFILE_PAGES': 'NEW_NAV_ON', 'VL_WOW_BDP_MWEB': 'WOW_BDP', 'Mobile_Touch_SignIn': 'Control', 'APPS_ENABLE_PERIMETERX': 'CONTROL_OFF', 'ANDROID_OMHDP_REFI_UPSELL': 'CONTROL_OFF', 'CLICKSTREAM_JS_SDK_SOURCE': 'KEYSTONE', 'HDP_OV_FORSALE': 'ON_W_PUBLIC_TABS', 'AndroidZOActiveTour': 'ON', 'SI_VA_Condos': 'CONTROL', 'PACE_ABP_ACH_BANNER': 'ON', 'VL_BDP_3D': 'ON', 'YOLT_NO_OB_TOURS_ATL': 'CONTROL', 'IOS_CONTINGENT_LISTINGS_V1': 'ON', 'AR_CONTACTS_TO_L2': 'ON', 'Android3DHomesTagOnSavedList': 'CONTROL_3DHOMES_SAVED_LIST_OFF', 'HDP_NativePhotoplayer': 'ON', 'SELTargetColumn': 'CONTROL', 'ANDROID_SS_IN_AUTOCOMPLETE': 'ON', 'PPL_PPS_POGO_UDS_MIGRATION': 'UDS', 'Z3D_HDPCallout': 'PHOTO_WALL_B', 'ZSG-Icons': 'CONTROL', 'ADS_EPA_CHASE_IFRAME': 'ON', 'AndroidRegionAutoComplete': 'ON_NEW_REGION_AUTO_COMPLETE_API', 'ACQ_HDP_DynamicLocation': 'Trial_Inactive', 'AndroidDataDogLogger': 'CONTROL_OFF', 'ARCS_EXPANDED_OPAQUE_SELLER_TITLE': 'ON', 'RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT_MULTIVARIATE': 'CONTROL', 'SEOTEST__HDP_WOW_SOLD_AND_OFF': 'CONTROL', 'ACQ_TOP_DISMISSLOGIC_2wksVS24hrs': 'Control_2wks', 'HDP_SCAM_ALERT': 'CONTROL', 'AndroidZOMapDotsZillowLogo': 'CONTROL_ZO_MAP_DOTS_OFF', 'IOS_WEBVIEW_BACK_BUTTON': 'ON', 'AndroidZOStartAnOffer': 'ON', 'ACT_PageFrameInPageWrapper': 'ON', 'IOS_MEDIA_STREAM_RENTALS': 'ON', 'OM_NOO_ZO_ELIGIBLE_RENTAL_UPSELL': 'ON', 'RE_NearMeLandingPages': 'CONTROL', 'AndroidSaveInPhotoGallery': 'SAVE_IN_PHOTO_GALLERY', 'IOS_INSTANTOFFERS_UPSELLS_FORSALE': 'CONTROL', 'HDP_ASYNC_PRICE_HISTORY': 'CONTROL_SYNC', 'HDP_SSR_WRAPPED_CONTENT_ONLY_FOR_BOTS': 'ON', 'ZEXP_AA_TEST_SLOT_187': 'CONTROL', 'CONV_AI_NLP_PLATFORM_TREATMENT': 'CONTROL', 'SXP_NAV_AD_LOADING': 'CONTROL', 'ZEXP_AA_TEST_SLOT_188': 'CONTROL', 'ACT_FILTER_ON_LAND': 'CONTROL', 'PRE_CLAIM_POGO_DEPRECATION': 'ON', 'iOSEverestAdTest': 'EVEREST_ADS_ON', 'SEL_PricingEntrypoint': 'CONTROL', 'ADS_PACE_PALS_EMAIL': 'CONTROL', 'IOS_SHOW_NATIVE_ZO_QUESTIONNAIRE': 'CONTROL_OFF', 'ACT_2FA': 'CONTROL', 'AndroidComingSoonDisplay': 'ON', 'APPS_IOS_GOOGLE_TRANSITION': 'ON_SIGNED_URLS', 'SXP_PHOTO_CAROUSEL': 'CONTROL', 'ADT_COOKIE_CONSENT': 'ONETRUST', 'SEOTEST__CUSTOM_REGION_FAQ_FOR_SALE_V1': 'CONTROL', 'ADS_FiOSAd': 'ON', 'HDP_PSL_PHOTOS': 'ON', 'SPT_FLYBAR_GDP_TO_ZG_SEARCH': 'ON', 'HDP_ZO_NFS_UPSELL_ONSITE_MESSAGING': 'ONSITE_MESSAGING', 'AndroidWowMapDotsV0': 'ON_WOW_DOTS_WITH_HRS', 'REV_Replace_PALS_CC_Form_With_CSI_Functionality': 'CONTROL', 'SET_PREXIT_SHARE': 'CONTROL', 'SRP_DESKTOP_ADS_VARIANTS': 'VARIANT_B', 'VL_BDP_NYDOS': 'ON', 'HDP_FULL_SSR_NFS': 'ON', 'FOUNDATION_COLORS_TYPOGRAPHY': 'CONTROL', 'ADS_EPA_SHOW_OTHER_LEADS': 'ON', 'HDP_VT_HIGHER': 'ON', 'IOS_FLYBARQUERYUNDERSTANDING': 'ON', 'SEO__SXP_REMOVE_ANCHOR_TEXT': 'CONTROL', 'SEOTEST__RE_SRPTitleTags_CityStateHomesForRent': 'CONTROL', 'SavedSearchInstantSMS': 'CONTROL', 'REALTIME_PERS_SORT_PRE': 'REALTIME_RECS', 'NOTIFICATION_SERVICE': 'CACHED', 'VELOCITY_TimeIsMoney': 'CONTROL', 'HDP_THROTTLE_SCROLL_EVENTS': 'ON', 'MOBILE_ZO_VALUEPROP': 'VALUEPROP_ON', 'ACT_AutocompleteHW': 'CONTROL', 'ARCS_REGION_PHONE': 'ON', 'VL_BDP_UTABLE': 'SHOW_ALL', 'IOS_HDP_TOP_ACTIONS': 'CONTROL_OFF', 'ACQ_TOP_DISMISSLOGIC_Relaunch_2wksVS24hrs': 'Variant_Relaunch_24hrs', 'Traffic_Mobile_Menu_Button': 'APP_STYLE', 'ARCS_LISTEDBY': 'CONTROL', 'IOS_CURRENT_LOCATION': 'CONTROL_ON', 'HDP_NO_CARDS': 'ON', 'USE_NEW_AGENT_FINDER': 'NEW_AGENT_FINDER', 'RR_TourSchedulingOnOffSwitch': 'CONTROL', 'SELLiveViewsUI': 'CONTROL', 'PERS_HOME_INSIGHTS_POSITION': 'INSIGHTS_MID', 'IOS_SHARE_SHEET': 'ON_2', 'SPT_PSL_PRICE_HISTORY': 'ON', 'KeystoneEventHDP': 'SEND_EVENT', 'HDP_HarrietZestimate': 'TOOLS_MODULE', 'IOS_HOMERECOMMENDATIONS_V1': 'ON', 'IOS_HOMERECOMMENDATIONS_V2': 'CONTROL_OFF', 'NOTIFICATION_ADMIN_PAGE_ONLY': 'ADMIN_PAGE_ONLY', 'SXP_ACT_REMOVE_SEARCHBOX_GLEAM': 'NO_GLEAM', 'VEL-3802-ClientProfileSLAs': 'TEST', 'ZO_BuyerQuestions': 'ON', 'IOS_TAGS_V2': 'ON', 'MOB_PSL': 'ON', 'SE_InstantOffer_LandingPage': 'V5_VIDEO_C', 'IOS_NATIVE_CDP_V0': 'CONTROL', 'AAP_scheduled_cancelation': 'CONTROL', 'IOS_MEDIA_STREAM_PANO': 'ON', 'SP_NATIVE_ZO_HDP_PAGE': 'CONTROL', 'UnassistedHomeShowingWeb': 'TREATMENT', 'IOS_ZO_VALUEPROP': 'CONTROL_OFF', 'ARCS_TOUR_TYPE_TEXT': 'VIRTUAL', 'SXP_Exclude_Referer': 'TEST', 'ARCS_TOUR_TIME': 'TIME_SHOWN', 'SHO_DEFAULT_LIST_OR_MAP': 'CONTROL_DEFAULT_LIST', 'SXP_PAGE_LOAD': 'FASTER', 'FIT_HDP_ASSETS': 'CONTROL', 'NC_SELF_TOUR': 'ON', 'AndroidZOHomeAccessV2': 'ANDROID_ZO_HOME_ACCESS_VERSION_2_ON', 'AR_CSAT_MODAL_HDP_LOAD_DELAY': 'CONTROL', 'NC_MAP_KEYS_FF': 'CONTROL', 'HRS_HOME_PAGE_RECS_CONFIG': 'CONTROL', 'HDP_SERVICE_FSBA_REGIONAL': 'REACT_HDP', 'SI_ShareWithCommunityPartner': 'ON', 'RE_Rentals_Badging_v1': 'CONTROL', 'RR-TourSchedulingiOS': 'CONTROL', 'RUM_VIA_STATIC_BUNDLE': 'TREATMENT_STATIC_BUNDLE', 'SAT_AA_TEST': 'CONTROL', 'ANDROID_SRP_ZILLOW_OFFERS_BANNER': 'CONTROL_OFF', 'APPS_NATIVE_INSTANT_OFFER_PHOTO': 'CONTROL_OFF', 'GDP_STREET_VIEW_IMAGE_FALLBACK': 'ON', 'ADS_USE_METROID_BILLING': 'CONTROL', 'IOS_INSTANTOFFERS_SELL_TAB': 'CONTROL', 'IOS_UPDATES_HOMERECS': 'ON_LIST', 'LEGO_RHIP_CACHE_ENABLED': 'CONTROL_OFF', 'ZillowGroupRedirect': 'ON', 'RE_RENTER_PROFILE_V3_REFRESH': 'TEST_A', 'SXP_55PLUS_FILTER': 'CONTROL', 'ADS_EPA_MAP': 'ON', 'AndroidRenterProfile': 'PROFILE_ON', 'IOS_YOUR_HOME_UPDATE': 'CONTROL_OFF', 'RA_CIC_MIGRATION': 'ON', 'NC_Shared_Builder': 'CONTROL', 'AIPERS_RT_RECS_SELLING_SOON': 'CONTROL', 'SI_ClaimFeedListings': 'ON', 'RE_HDP_HOME_INSIGHTS_VERSION': 'CONTROL', 'IOS_ZillowGroupAnalytics_RE_1': 'ON', 'SE_InstantOffer_IsOn': 'ON_W_SUBMIT', 'SXP_REACT_GPT': 'REMOVED', 'PR_RETRY_CONTACT_SUBMITS': 'CONTROL', 'IOS_COSHOPPING_UPSELLS_V1': 'CONTROL_OFF', 'RA_PASSIVE_AUTH_ENABLED': 'CONTROL', 'HDP_WOW_FSBA_MOBILE': 'ON', 'AndroidMoreResults': 'CONTROL_75', 'ZO_HomeAccess_SendSurveyOnUnlock': 'SKIP_SEND_SURVEY', 'AndroidThreeContactButtons': 'THREE_BUTTONS_ON', 'HDP_3D_WITH_BANNER': 'CONTROL', 'ADS_ForceEnableTT_RestrictToOMF': 'ON', 'AndroidZGAnalyticsRentals': 'ZG_ANALYTICS_RENTALS_ON', 'IOS_UPDATES_TAB_HEADERS': 'CONTROL_OFF', 'ARCS_BETH_VALUE_PROPS': 'CONTROL', 'IOS_CV_TWO_COLUMN': 'ON', 'iOSZMMCustomQuotesWebView': 'CONTROL_NATIVE', 'PR_DISABLE_CONTACT_FILTERING': 'DISABLE_CONTACT_FILTERING', 'ADS_ForceEnableTT': 'ON', 'HMIMHW_ZO_NFS_UPSELL_ONSITE_MESSAGING': 'ONSITE_MESSAGING', 'JSDA': 'CONTROL', 'AppUpsellBottomAndroid': 'CONTROL_OFF', 'BuyingAndSelling': 'BuyingAndSelling_CONTROL_OFF', 'SE_InstantOffer_DryRun': 'CONTROL', 'HDP_WOW_REDBLUE': 'CONTROL', 'HOME_RECS_ON_HDP': 'ON_FLIPPED', 'AndroidStaticMapType': 'CONTROL_MAPTYPE_BING', 'ChangeToolBarTextToContactProperty': 'CONTROL_GetMoreInfo', 'ARCS_VIRTUAL_TOUR': 'ON', 'IOS_ZO_HOMEACCESS_SELFTOURNAME': 'SELFTOUR', 'IOS_2020_NEW_HDP_API': 'ON_2', 'IOS_ZO_HOMEACCESS_POSTTOUR': 'ON', 'HDP_FULL_SSR_NC': 'CONTROL', 'HDP_CommunityWebsite': 'CONTROL', 'AndroidZOHdpBrandBoost': 'ON', 'SEL_Drafts': 'ON', 'SPT_RENDER_NATIVE_PAID_BUILDER_PAGE': 'CONTROL', 'MTT_FRHDP_TOP_SLOT_HOLDOUT': 'ON', 'ANDROID_MULTIREGION_SEARCH': 'CONTROL_OFF', 'AndroidEncodedSavedSearchAPI': 'ON', 'AndroidMasApiV2': 'ON_MAS_API_V2', 'AndroidHDP': 'TEMPLATED', 'HDP_NEIGHBORHOOD_DETAILS': 'CONTROL', 'HDP_STREET_VIEW_URL': 'ON', 'RE_SEO_301_Redirect_rentalURLS': 'CONTROL', 'ZO_REDIRECT_ZO_UPSELL_TO_QUESTIONNAIRE': 'CONTROL', 'HDP_StreetView': 'SameWindow', 'HDP_Desktop_Async': 'CONTROL', 'HotHomePrediction': 'On', 'ProfileOverlappedDataCalls': 'CONTROL', 'IOS_HOMETRACKER_V2': 'ON', 'IOS_HARRIET_ONBOARDING': 'CONTROL_OFF', 'IOS_OFFERS_NATIVE_QUESTIONNAIRE_V3': 'CONTROL', 'PFS_LeaseLinks': 'CONTROL', 'PPL_AGENT_TEAMS': 'MANAGEMENT_ON_PROFILES_ON', 'IOS_OFFERS_NATIVE_QUESTIONNAIRE_V2': 'CONTROL', 'AndroidNotificationsUpgradeApi': 'NOTIFICATIONS_UPGRADE', 'IOS_RENTALS_REQUEST_TO_APPLY_NOW': 'ON', 'MORTGAGE_MEDIASTREAM_UPSELL': 'CONTROL', 'MOB_ZG_SEARCH_OPT_IN': 'ON', 'REV_Turn_On_Python_AB': 'ON', 'ACT_REG_LOGIN_TOP_NAV_DIALUP': 'CONTROL', 'ZO_Show_ABAD_Panel': 'ON', 'SPT_RENDER_PAID_BUILDER_PAGE': 'CONTROL', 'iOSFacebookTrackingDARE': 'DARE_TRACKING3', 'AndroidSchoolsSearchApi': 'ON_SCHOOLS_SEARCH_API', 'RealTimeBuyingPower_FetchUserProfile': 'CONTROL', 'HDP_HOMES_FOR_YOU_RECS_PLACEMENT': 'CONTROL', 'VL_REMOVE_OFF_MARKET_LINKS': 'REMOVE', 'IOS_MIXED_MEDIA': 'CONTROL_OFF', 'Android3DHomesFilter': 'ON_3D_HOMES_FILTER', 'FIT_SERVICE_WORKER': 'CONTROL', 'RE_CallUI': 'LINK', 'AndroidTabNavigation': 'ON_TAB_NAVIGATION', 'SPT_RENDER_FOR_RENT_PAGE': 'CONTROL', 'HDPWebView': 'HDPWebView_Template2', 'SXP_QU_PHASE_2': 'ON', 'AndroidFindAgent': 'FIND_AGENT_ON', 'EnableVrModelsOnMob': 'TEST', 'HDP_STREAMLINE_COMMUTE': 'CONTROL', 'Auth_Email_Validation': 'ON', 'HDP_INSIGHTS_VERSION': 'CONTROL', 'AndroidKingfisherFilters': 'KINGFISHER_FILTERS_ON', 'HDP_HFF_ACCORDION': 'ON', 'IOS_KINGFISHER_FILTERS': 'ON', 'IOS_UPDATE_TAB_PERSONALIZED_INSIGHTS': 'ON', 'IOS_MULTI_REGION': 'CONTROL_OFF', 'HDP_SimilarHomes': 'ON', 'AUTH_REG_LOGIN_STRONG_PASS2': 'TEST', 'RR_RENTER_PROFILE_V2': 'TEST', 'MarketingPulseAbTest': 'CONTROL', 'HDP_CONTENT_SUMMARY': 'CONTROL', 'SEOTEST__Rentals_Listing_Count': 'TEST', 'HDP_SKIP_LINKS': 'CONTROL', 'ADAT_REVIEW_SERVICE': 'CONTROL', 'ZEXP_DECISION_TOKEN_HOLD': 'WRsBmJ5mAEPS', 'HDP_SKINNY_MODULE_UPDATES': 'ON', 'AndroidHDPDwellTime': 'ON', 'IOS_BDP_3D_Tours': 'CONTROL_OFF', 'IOS_OFFERS_FLASHMOB_QUESTIONNAIRE': 'CONTROL', 'iOSSplunkMintPerfLogging': 'CONTROL_OFF', 'MobileHDP_Perf_AJAX': 'CONTROL', 'IOS_CANADA_V0': 'ON', 'iOSCustomQuotesWebView': 'WEBVIEW_ON', 'SXP_AD_TARGET_REFACTOR': 'CONTROL', 'ADS_NAV_AD_PACING': 'ON_RENTALS', 'PPL_REVIEW_MERGE': 'ON', 'LocalPagePeriscope': 'TABS', 'MTT_HMIMHW_TOP_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_CTRL', 'HDP_SKINNY_MAP_AND_FACTS': 'ON_SHORT_FACTS', 'IOS_TAG_3D_HOMES_ON_MAP': '3D_HOME_TAG', 'HDP_CLASSIC_OM_REFI_UPSELL': 'ON', 'IOS_REMOVE_OWNER_VIEW': 'CONTROL', 'ARCS_FORECLOSURE_REWRITE': 'ON', 'TENgageRegistrationUI': 'SIDE_REG_BUTTONS', 'KeystoneEventPoiTypeahead': 'SEND_EVENT', 'AR_CSAT_ONSITE': 'HOMEPAGE_CONSTELLATION', 'RICH_HDP_FloodData': 'CONTROL', 'HDP_WEBVIEW_ZO_UPSELL': 'ON', 'IOS_HIDE_NOTIFICATION_COUNT': 'CONTROL_OFF', 'TR_DISALLOW_FAQ_AFTER_FIRST_PAGE': 'CONTROL', 'ZSG-MobileAppsFont': 'BOTH_GOTHAM', 'ACT_CONFIRM_EMAIL': 'CONTROL', 'HDP_MOBILERESOURCES_UPDATE': 'ON_V2', 'PERS_GOOGLE_MAPS_API_EMAIL': 'CONTROL', 'IOS_ENABLE_PERIMETERX1': 'ON', 'RE_Search_Refinement_Filters': 'CONTROL', 'HDP_SERVICE_ALL_OTHER_TYPES': 'ON', 'SEOTEST__VL_WOW_BDP': 'WOW_BDP', 'ARCS_GET_A_CALL': 'CONTROL', 'NC_CDP_BOOTSTRAP': 'ON', 'ZO_DataStrategy_UpdateOfferRequest': 'ON', 'MIGHTY_MONTH_2022_HOLDOUT': 'CONTROL', 'PERF_HDP_NO_ZSG': 'ON', 'RE_PRODUCT_MARKUP': 'CONTROL', 'ARCS_WOW_LISTING_AGENT_ATTRIBUTION': 'ON', 'SELLER_TOOLS_ABPD_TEST': 'ON', 'NFSHDP_OWNER_OPTIONS_GOOGLE_AD': 'CONTROL', 'ANDROID_YOUR_HOME_UPDATE': 'CONTROL_OFF', 'SHO_DESKTOP_LIST_RESULT_QUANTITY': 'CONTROL', 'ARCS_TOUR_SHADOW_TEST': 'CONTROL', 'ZO_HDP_CONTACT_AGENT': 'CONTROL', 'IOS_ONBOARDING_2': 'ONBOARDING_ON', 'RE_NEW_LEAD_COPY': 'TEST', 'SXP_STATIC_MAP': 'ON_PLUS_XDP_LAZYLOAD', 'ACT_AccountSettingsPrexit': 'ON', 'AndroidUpdateTabPersonalizedInsights': 'ON', 'SE_InstantOffer_OfferReview': 'ALL_INCLUDED', 'RA_RACHEL_VERIFIED_LANDLORD_REFERENCES': 'CONTROL', 'VEL_CLIENT_PROFILER_SEARCH': '100_PERCENT', 'iOSDirectory': 'ON', 'RE_SEO_Add_internal_links_from_HDPstoSRPs': 'TEST', 'MOB_REGION_CANDIDATES_FB_MIGRATION': 'ON', 'ActHDPShareBtns': 'CONTROL', 'SXP_REDUCED_SERVER_SIDE_RENDER': 'CONTROL', 'INSTANTOFFERS_UPSELLS_FORSALE': 'BUY_SELL', 'SCHOOL_REDLINE': 'CONTROL_A', 'ADS_BuilderHomeTour': 'CONTROL', 'IARCS_MY_AGENT_TOURING': 'ON', 'SXP_DelayJS': 'AFTER_LOAD', 'AndroidMagellanAll': 'MAGELLAN_ALL_ON', 'ACQ_Banner_Suppression': 'CONTROL', 'AndroidKFSchools': 'ON_KINGFISHER_SCHOOLS', 'IMX_REPORT_PROBLEM': 'CONTROL', 'IOS_APARTMENT_COMMUNITY_FILTER': 'ON', 'SEOTEST__VL_BDP_INDEPENDENCE_DAY': 'CONTROL_LEGACY', 'HDP_OV_RENT': 'ON_W_PUBLIC_TABS', 'SEO__SRP_REGION_PROFILE_SCHEMA': 'SCHEMA_LINK', 'HDP_HIGHER_3D': 'ON', 'IOSDrawRegionFill': 'CONTROL_ON', 'HDP_WOW_FS_OTHER_APP': 'ON', 'iOSInlineActions': 'CONTROL', 'ZO_HDP_RENO_MODULE': 'CONTROL', 'TR_DUPLICATE_PROPERTY_REDIRECT': 'ON', 'AndroidHDPCallButton': 'CONTROL_NO_CALL_BUTTON', 'AndroidZOHomeAccessSafeMode': 'ON', 'ADS_CF_NO_MULTI_CHECK': 'ON', 'NC_LOT_PREMIUM_DISCLAIMER': 'CONTROL', 'GS_RATING_CLEANUP': 'CONTROL', 'ACC_MOB_POGO_UDS_MIGRATION': 'UDS', 'TrafficLogGACookieChanges': 'CONTROL', 'AndroidMDS': 'ON_MOBILE_DEVICE_SERVICE', 'AndroidOnboardingV3': 'ON_PHASE1_REFRESH', 'IOS_ZO_ACTIVE_TOUR': 'ON', 'NC_CONTACT_BUTTON_CHIP_MOBILE': 'CONTROL', 'ARCS_CONTACT_BUTTON_REFACTOR': 'CONTROL', 'AndroidOnboardingV2': 'CONTROL', 'KeystoneEventContact': 'SEND_EVENT', 'IOS_ZO_DATADOG_LOGGING': 'ON', 'ANDROID_DATADOG_BACKGROUND_EVENTS': 'CONTROL_OFF', 'MAHR_API_DEPRECATION': 'ON', 'SHOW_PL_LEAD_FORM': 'CONTROL', 'ZO_HOMEACCESS_START_AN_OFFER_ZHB_HOMES': 'CONTROL', 'HDP_GOOGLE_STREETVIEW': 'CONTROL', 'AR_CSAT_ONSITE_HDP': 'ON', 'AndroidCurrentLocation': 'CONTROL_ON', 'SHUB_SHARE_FAVORITES': 'ON', 'REV_CSI_MMP': 'ON', 'SEOTEST__HDP_WOW_FOR_SALE_OTHER_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'ON', 'percent': 0}], 'KeystoneEventMobMobileGraphite': 'CONTROL', 'ZO_HOMEACCESS_ACTIVE_TOUR': 'ON', 'SE_InstantOffer_Entrypoint': 'Curiosity', 'VL_ReactBDPSchools': 'CONTROL', 'ARCS_AFFILIATION_MESSAGING': 'CONTROL', 'AndroidTouringV1Flex': 'CONTROL_OFF', 'ARCS_ATLAS_LEAD_SUBMISSION': 'ON', 'iOS_Native_Odash': 'CONTROL', 'HDP_WOW_LAYOUT': 'CONTROL', 'ZO_HOMEACCESS_HOME_HEARTBEAT_ENTRY_DEVICE_CHECK': 'ON', 'YOLT_ABAD_RALEIGH': 'CONTROL', 'AR_BOZ_REPORT': 'ON', 'AndroidViewStateApi': 'ON_VIEW_STATE_API', 'AndroidClaimHomeUpsellV4': 'CONTROL_2B', 'AndroidClaimHomeUpsellV3': 'UPSELL_V3_HOMEVALUE', 'AndroidClaimHomeUpsellV2': 'UPSELL_V2_ON_2B', 'IOS_GET_PRE_QUALIFIED_ON_CHIP_FSBA': 'ON', 'RE_Listing_Status_Update_Table': 'CONTROL', 'iOS_SCREENSHOT_SHARE': 'ON', 'AR_PEARL_AGENT_REMOVAL_NURTURE': 'CONTROL', 'ANDROID_ZO_OFFERS_AND_CLOSINGS': 'CONTROL_OFF', 'AndroidCollapsedFilter': 'ON_COLLAPSED_FILTER', 'MTT_NFSHDP_TOP_SLOT_HOLDOUT': 'ON', 'ARCS_FEATURED_REWRITE': 'ON', 'PERF_DEFERRED_HYDRATION': 'ON', 'ARCS_TOUR_MESSAGE': 'CONTROL', 'ACQ_HP_Location_SaveTrack': 'Control_NoCopy', 'MediaStreamFloorPlan': 'ON', 'SI_LLPRachel': 'ON', 'ZO_HOMEACCESS_SYSTEM_CHECK_ENTRY_DEVICE_CHECK': 'ON', 'ProfilePageRegionFeature': 'DISABLED', 'SEO__Footer_Content': 'CONTROL', 'IOS_LOCATION_UPSELL': 'CONTROL_OFF', 'SUB_USE_MDS': 'CONTROL', 'HDP_DD_MODULE': 'CONTROL', 'SXP_STREETVIEW_REQUEST_TYPE': 'CONTROL', 'CONV_AI_NLP_PLATFORM_CONTROL': 'CONTROL', 'IOS_ZGGRAPH_COSHOPPING_PREFETCH': 'CONTROL_HOME_TRACKER', 'OMHDP_TCOS_MODULE': 'TCOS_MODULE_OMHDP_V1', 'SI_ResidentEnrollmentReminders': 'ON', 'IARCS_LEAD_PACING_VERIFICATION': 'CONTROL', 'RICH_HDP_ShowBuildingPermits': 'ON', 'AndroidMortgageLongForm': 'ON_WEBVIEW', 'IARCS_FLYBAR_LEAD_PACING': 'ON', 'IOS_ZMA_LEGAL_TERMS': 'ON', 'IOS_MAGELLAN_HDP': 'ON', 'HTCG_ZG_SEARCH_OPT_IN': 'CONTROL', 'RE_RentalsHomesForYouSort': 'CONTROL', 'ListingQualitySort': 'CONTROL', 'RE_NEW_FR_LIST_CARDS_WEB': 'CONTROL', 'ARCS_BAL_REWRITE': 'ON', 'IOS_HOME_LOOKUP_LIST_2020_V2_API': 'ON_2', 'AndroidCTAInPhoto': 'CONTROL_OFF', 'SP_FOR_RENT_PAGE': 'CONTROL', 'SEOTEST__InternalLinkSortUpdate': 'CONTROL', 'SPT_RENDER_NATIVE_OFF_MARKET_PAGE': 'ON', 'ZO_OPTIMIZELY': 'CONTROL', 'AndroidUpdateTabHorizontalSS': 'ON_COLLECTIONS', 'HDP_ZO_WARRANTY_VP': 'BOTH_ON', 'HDP_FULL_SSR_RENT': 'CONTROL', 'HDP_COMMUTE_REDESIGN': 'ON_AFTER', 'IOS_SIDE_BY_SIDE': 'ON', 'ACQ_MOBILE_UPSELL_HOMEPAGE': 'CONTROL', 'MIB_SAVED_HOME_PUSH': 'PUSH_ON', 'SEOTEST__SRP_DEFAULT_SORT': 'CONTROL', 'TrafficHDPHomevalues': 'ON', 'ADS_EPA_ONE_MONTH_FREE_SELF_SERVICE': 'ON', 'ADS_EPA_AUTOMATIC_TERMINATION': 'ON', 'SI_InventoryByAPI': 'CONTROL', 'SL_FSBA_MANUAL_POSTING_WARNING': 'SHOW_WARNING', 'IOS_OFFERS_QUESTIONNAIRE_TIME_HINT': 'CONTROL', 'ONSITE_MESSAGE_VALVE': 'OMP_ON', 'STANDING_OFFER_UPSELL': 'STANDING_OFFER_V2', 'iOS_Touring_V1_Toggle': 'CONTROL_OFF', 'ADS_PACE_PURCHASE': 'CONTROL', 'AndroidContingentV2': 'ON_CONTINGENT_V2', 'ACT_THREE_ICON_CTA_TOUR_TEXT': 'CONTROL', 'ADS_SplitActionBar': 'On_Call', 'HideHDPActionBarOnBALVisibility': 'ON', 'MOB_QUERY_UNDERSTANDING': 'ON', 'IOS_SIGN_IN_WITH_APPLE': 'SIGN_IN_WITH_APPLE_ON', 'SEL_MyListings': 'CONTROL', 'IOS_OFFERS_MORE_MENU_LANDING_PAGE': 'ON', 'PA_AWS_IMPRESSION_TRACKING': 'ON', 'TENgageLockedContentOnHDP': 'POP_OVER', 'SmartBannerTablet': 'CONTROL', 'ZXR_EXPERIMENT_AA_TEST': 'CONDITION_A', 'ARCS_ADS_DISPLAY_PREXIT': 'DISABLE_ADS_DISPLAY_CALL', 'SS_USE_REQUEST_CACHE': 'ENABLED', 'RE_VARIANT_HDP_DEFERRED_HYDRATION': 'CONTROL', 'Zo_Flag_OASIS_Block_Producing_Stream_V2_Events': 'CONTROL', 'ARCS_DESKTOP_INLINE_FORM_PLACEMENT': 'BELOW_FACTS_AND_FEATURES', 'ARCS_TOURS_REQUIRED_AGENTS_ON_OFF': 'T1_NO_LIMT', 'HDP_OV_BANNER_NFS': 'CONTROL', 'TR_WHAT_I_LOVE': 'EAGER_TO_SELL', 'IOS_Rentals_Combined_Filter_AptsCondos': 'ON', 'iOSFilterPills': 'ON', 'HDP_SERVICE_ALL_OTHER_TYPES_MOBILE': 'ON', 'IOS_ONBOARDING': 'CONTROL', 'MOB_REGIONS_API': 'ON', 'AndroidNativeAdPosition': 'CONTROL_NATIVEADS_BELOW_SECOND', 'SEOTEST__SXP_REMOVE_WHY_ZILLOW': 'REMOVE_WHY_ZILLOW', 'AR_FLYBAR_PROMOTED_AGENT_ZGCP': 'CONTROL', 'NC_BUILDER_PROFILE_V3': 'TEST', 'NC_VIDEO_TOUR': 'ON', 'AR_CSAT_AGENT_CONNECTION': 'VARIANT_1_UXR', 'IOS_ZESTIMATE_DEEPDIVE': 'ON', 'METROID_MAINTENANCE_MODE': 'CONTROL_OFF', 'AndroidHarrietOnboarding': 'CONTROL_OFF', 'iOSNativeAds': 'ON', 'RE_JanusBrainSortApps': 'CONTROL', 'HDP_WOW_FS_OTHER': 'ON', 'SE_InstantOffer_NativeQuestionnaire': 'CONTROL', 'ANDROID_RTBP_V3': 'CONTROL_OFF', 'ARCS_ADS_DISPLAY_V3': 'ON', 'MAS_NOH_API_DEPRECATION': 'CONTROL', 'RE_COVID_Tours': 'REMOVE_TOUR', 'IOS_NFS_NAV_BAR': 'CONTROL', 'HDP_DELETED_HOMES': '404', 'ACQ_SRP_GoogleCLS': 'Variant_Placeholder', 'ADS_PA_RELATIONSHIP': 'CONTROL', 'SPT_RENDER_NATIVE_FOR_RENT_PAGE': 'CONTROL', 'MTT_NFSHDP_TOP_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_CTRL', 'AndroidMediaStreamHDPAll': 'CONTROL_OLD_HDP', 'SEOTEST__RE_WOWHDP_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'TEST', 'percent': 0}], 'ZO_LiveOffer_Upsell': 'V8_V9_SUPPRESS', 'HDP_SERVICE_NC': 'ON', 'RUM_SHORT_BEACON_DELAY': 'ON', 'DXP_RTB_LINKING': 'ON', 'AndroidEndPhotoGalleryCTA': 'CONTROL', 'REGION_INSIGHTS': 'CONTROL', 'SEOTEST__TITLE_TEST_ON_MULTI_FAMILY_HDP': 'CONTROL', 'HDP_MobileForeclosure': 'ALWAYS_OPEN', 'SPT_PSL_TO_PDC_IN_GDP_SHADOW': 'CONTROL', 'SEOTEST__NOINDEX_SRPHDP': 'ALL', 'ADS_MarchexToTwilio': 'CONTROL', 'iOS_In_App_Covid_VT': 'CONTROL_OFF', 'AndroidNewHomeDetailsAPI': 'ON', 'AndroidAccountSettings': 'ON_ACCOUNT_SETTINGS', 'ZO_HDP_CHIP': 'CONTROL', 'ACT_REACT_APP_FOR_LOGIN': 'ON', 'SE_PricingTool_StaticMapOption': 'CONTROL', 'RA_RACHEL_EDITABLE_INCOME_AND_NOTES': 'ON', 'RE_Local_Protections': 'ON', 'AR_FLYBAR_MY_AGENT': 'ON', 'TENgageSEMRegistrationUI': 'SEARCH_LIGHTBOX', 'IOS_ZO_HOMEACCESS_SAFEMODE': 'ON', 'HOPS_ZHL_BANNER': 'SHOW', 'NC_EDUCATION': 'ON', 'KeystoneEventMobFavorite': 'SEND_EVENT', 'SXP_Rentals_Apartment_Community_Filter': 'TEST', 'IOS_SHOW_STANDALONE_ABAD_IN_SELFTOUR_FLOW': 'ON', 'ZO_FSHDP_RTBP_M2_NEW_QUERY': 'CONTROL', 'HDP_GTM_LOAD_STRATEGY': 'DELAY', 'AndroidPhotoPreview': 'ON_PHOTO_PREVIEW', 'ARCS_CLIENT_GEN_LEAD_ID': 'CONTROL', 'IOS_ZO_HOMEACCESS': 'IOS_ZO_HOMEACCESS_ON', 'MY_ZILLOW_TOURS': 'CONTROL', 'PERS_SORT_ROLLOUT_PRE': 'ON', 'ARCS_CONTACTS_TO_L2': 'ON', 'AndroidBedroomFilterChanges': 'CONTROL_BEDROOM_FILTER_CHANGE_OFF', 'IOS_3D_HOMES_HDP': 'CONTROL_OFF', 'ZO_OFFER_FRAMEWORK': 'CONTROL', 'TR_REDIRECT_LOGS': 'CONTROL', 'IOS_MODAL_BAL_CONTACT_BUTTONS': 'ON', 'RE_NON_VARIANT_HDP_DEFERRED_HYDRATION': 'CONTROL', 'ZO_DataStrategy_GetOfferRequestById': 'ON', 'ContactMeAnimation': 'ANIMATION', 'AgentNavigationAndroid': 'AGENT_NAV_ON', 'IOS_COMMUTE': 'CONTROL', 'ACT_VisualPageFrame': 'ON', 'ADS_BlueSkyTrackedNumbers': 'ON', 'ADS_EPA_HIDE_CC_ENTRY_WHEN_IMPERSONATING': 'ON', 'SEL_SellerLeadsFormValidation': 'CONTROL', 'AR_FLYBAR_PROMOTED_AGENT': 'ON', 'IOS_ONBOARDING_HOME_TYPE': 'CONTROL_OFF', 'IOS_NEW_NEARBY_OPEN_HOUSES_API': 'ON', 'VL_WOW_BDP_DESKTOP': 'WOW_BDP', 'IOS_TAB_NAVIGATION': 'ON', 'AndroidMediaStreamRentalDescription': 'MEDIA_STREAM_RENTAL_DESCRIPTION_ON', 'HOME_TRACKER_ACCEPT': 'ON', 'ACQ_Signin_BannerVsModule': 'Variant_Module', 'SXP_WOW_LIST_CARD': 'CONTROL', 'ZO_Homepage_Wayfinding': 'CONTROL', 'IOS_REMOVE_MAKE_ME_MOVE': 'MMM_REMOVED', 'AndroidZGAnalyticsRealEstate': 'ZG_ANALYTICS_REAL_ESTATE_ON', 'SEOTEST__PROFILE_COUNT': 'REGIONS_A_TO_J', 'AndroidNativeHDP': 'ON_NATIVE_HDP', 'HDPModalBAL': 'CONTROL_OFF_HDPModalBAL', 'MobileHDP_Perf': 'CONTROL', 'SXP_KF_FILTERS_AC': 'ON', 'RE_OFF_MARKET_COMSCORE': 'TEST', 'LEGO_RH_HOMEPAGE': 'ON_V2', 'RR_RENTER_PROFILE_V2_APPS': 'TEST', 'AndroidEverestAdTest': 'CONTROL_EVEREST_ADS_OFF', 'IOS_UPDATE_TAB_ONE_INITIAL_SAVED_SEARCH': 'CONTROL_OFF', 'ADS_EPA_OWNED_ZIPS': 'ON', 'HDP_FullScreenTouchPhotoGallery_Tablet': 'ON_W_AD', 'SE_InstantOffer_OfferAvailService': 'OASIS_SERVICE_CACHED', 'HDP_SERVICE_REDUCE_OVERLAPPED_CALLS': 'ON', 'ZO_Questionnaire_TakeoverUIAndHomeChip': 'CONTROL', 'ARCS_ATLAS_REGION_PHONE': 'ON', 'ADS_PACE_PDP_DUAL_WRITE_SNS': 'CONTROL', 'SEOTEST__RE_SRPTitleTags_WithPhotos': 'CONTROL', 'HDP_OV_BANNER_FSFR': 'CONTROL', 'IOS_MODAL_BAL_NC': 'CONTROL_OFF', 'RE_HDP_HOME_INSIGHTS': 'CONTROL', 'UDP_GDP_OMHDP_PHOTOS': 'HIDE_PHOTOS', 'AndroidMaphole': 'MAPHOLE_ON', 'ARCS_DESKTOP_PHONE': 'CONTROL', 'VL_MAP_GROUP_BY': 'CONTROL_LAT_LONG', 'ARCS_PROPERTY_TOURS_GDP': 'ON', 'SXP_FLYBAR_AUTOCOMP': 'ON', 'ARCS_SCHEDULE_A_TOUR_DESKTOP': 'ON', 'IOS_MEDIA_BROWSER': 'ON', 'PERS_MOCK_SEARCH_LATENCY_MOB': 'CONTROL', 'RE_REDIRECT_ANDROID_APP_RCF': 'REDIRECTED', 'ARCS_USE_BACKEND_TOUR_AVAILABILITY': 'CONTROL', 'IOS_ZO_HOME_ACCESS_VERSION': 'IOS_ZO_HOME_ACCESS_VERSION_CONTROL_OFF', 'ZO_QUESTIONNAIRE_CLEANUP': 'CONTROL', 'AndroidZOHomeAccessPostTour': 'ON', 'SELSusanClaim': 'CONTROL', 'KeystoneEventMobHDP': 'SEND_EVENT', 'SXP_SDS_INTEGRATION': 'CONTROL', 'TrafficDeferHomepageJS': 'CONTROL', 'RESTRICT_METRO_MLS_FSBO': 'ON', 'SXP_MOBILE_MAP_PRIORITY': 'CONTROL', 'AR_FLYBAR_SERVERLESS_CSAT_LEADS_PROCESSOR': 'ON', 'AIPERS_RT_RECS_HOMES_FOR_YOU_UPDATES_TAB': 'CONTROL', 'RE_Premium_Package_Saved_Search': 'CONTROL', ' HDP Toolbar': 'CONTROL', 'IOS_SAVE_SEARCH_VARIANTS': 'ON_TEST_C', 'HDP_ZHVI_CHART_MIGRATION': 'CONTROL', 'SS_SAVED_HOMES_WRITE': 'ENABLED', 'AndroidPerimeterX': 'ON_PERIMETER_X_2', 'HDP_WOW_RS_AND_PL': 'CONTROL', 'HDP_HOME_INSIGHTS': 'ON', 'ESTIMATE_OFFER_UPSELL': 'ON', 'VL_HDP_MODULE': 'CONTROL', 'KeystoneEventSearch': 'SEND_EVENT', 'ADS_BAL_LOCALIZATION': 'CONTROL', 'MTT_ODASH_TOP_SLOT_HOLDOUT': 'ON', 'AndroidNotificationsOneTimeUpdate': 'ONETIMEUPDATE_ON', 'HDP_WOW_RS_AND_NFS': 'ON', 'ADS_CONTACT_GUID': 'ON', 'SEOTEST__PERMITS_GA': 'ON', 'SXP_MAP_DOT_STYLE': 'CONTROL', 'RMX_3RD_PARTY_HDP_UPDATE': 'ON', 'KeystoneEventMobSearch': 'CONTROL', 'IOS_SHOW_LEGACY_SELF_TOUR': 'ON', 'TR_AGENTNOTES_FS': 'ON_Expanded', 'MTT_SRP_TOP_SLOT_POST_API_MIGRATION': 'ON', 'REDIRECT_SCHOOL_SEARCH_PAGE': 'ON', 'ZO_Sell_LPAddressEntry': 'ON', 'AndroidNewHomeRecommendationsAPI': 'ON', 'ETHNIO_JAVASCRIPT': 'OFF', 'MyZillowOffersAndClosings': 'ON', 'SS_SAVED_HOMES_READ': 'ENABLED', 'MarketingPulse': 'TEST', 'RE_RentalHomeDetailsService': 'CONTROL', 'ARCS_REMOVE_FINANCING': 'CONTROL', 'VL_compact_mapAndStreetView': 'ON', 'FAVORITE_SESSION_SERVICE_PSL_BATCH_LOOKUP': 'ON', 'IOS_AgentFinder': 'NATIVE_ON', 'AndroidAgentFinder': 'AGENTFINDER_NATIVE_ON', 'RentalsActionButtonText': 'CONTACT_MANAGER', 'HDP_AND_SEARCH_BOT_ADS': 'BOT', 'IOS_GETZ_FLASH_MOB': 'ON_2', 'iOSPanos': 'ON_Flat', 'sub_center': 'CONTROL', 'AndroidTouringV1': 'ON_DISCOVERY', 'IOS_HOMETRACKER_v1': 'ON_TAGS_COMBINED_LIST', 'AndroidZOScheduleVirtualTour': 'CONTROL_SCHEDULE_TOUR', 'RE_OMP_TOP_SLOT': 'TEST', 'SE_recent_NFS_FR': 'CONTROL', 'REV_CSI_BA': 'CONTROL', 'RR_CometWashingtonApplications': 'ON', 'APPS_IOS_MORE_RESULTS': 'CONTROL_75', 'HDP_REQUEST_MEDIA': 'CONTROL', 'AndroidMixedMedia': 'ON', 'ADS_DO_NOT_GOOGLE_TRANSLATE': 'CONTROL', 'ACQ_SigninSRP_Module': 'Variant_Module_A', 'NC_MWEB_LOWERPROMO': 'CONTROL', 'DoBubbleOpenGA': 'CONTROL_OFF', 'IOS_SEARCH_BOX_CLEARING': 'CONTROL_OFF', 'CONV_AI_PEARL_NLP_THROTTLE': 'CONTROL', 'PERF_REDUCE_SSR_IMAGES': 'ENABLED', 'MarketingMobileAppUpsellBannerIOS': 'TWO_BUTTON_STYLE', 'VL_PPC_Link_Location': 'HEADER', 'SL_OFFERDATES_HDP': 'CONTROL', 'IOS_RENTER_HUB_SATELLITE': 'CONTROL_OFF', 'ADS_EPA_MY_AGENT': 'ON', 'AndroidCanadaV0': 'CANADAV0_ON', 'AndroidNativeOwnerView': 'ALL_WEBVIEW', 'Zo_Flag_OASIS_Block_Availability_Group_Change': 'CONTROL', 'ARCS_BAL_TO_OPAQUE': 'ON', 'HDP_WOW_FSBA': 'ON', 'SEOTEST__HDP_SERVICE_OTHERS': 'CONTROL', 'AUTH_DOCUMENT_PREFERENCES': 'ON', 'SXP_USER_OPTIMIZED': 'ENABLED', 'IOS_NFS_WOW_HDP': 'ON', 'HDP_SERVICE_NC_MOBILE': 'ON', 'VL_FLOORPLAN_NAMES': 'ON', 'ZO_ABC_SellingQuestion': 'CONTROL', 'AIPERS_ZILLOW_WEB_HOME_PAGE_COLLECTIONS': 'CONTROL', 'SEOTEST__ExpandedFooterLinksForApartments': 'TEST', 'ABService_HashAlgorithm': 'MURMER', 'ADS_STICKY_300_250': 'CONTROL', 'ZILLOW_CANADA_AGENT_PROFILE': 'ON', 'IOS_WOW_MAP_DOTS': 'CONTROL_OFF', 'AndroidNewMapActions': 'ON_SATELLITE', 'APPS_IOS_MODAL_CONTACT_FORM_PRESENTATION': 'CONTROL_OFF', 'SXP_FLYBAR_PSL_ZGSEARCH': 'ON', 'HDP_WOW_RS_AND_PL_APP': 'CONTROL', 'PPL_CONTACTS_TO_L2': 'ON', 'MOBILE_ZESTIMATE_DEEPDIVE': 'ON', 'ADS_PACE_CART': 'ON', 'IOS_CSAT_SURVEY': 'SURVEY_APP_STARTUP', 'PostingService': 'USE_POSTING_SERVICE', 'HDP_OV_UPSELL_NFS_DESKTOP': 'HOME_VALUE_TRACKER', 'ARCS_OWNER_REWRITE': 'ON', 'ABS_KEYSTONE_GATE': 'ON', 'VEL_CLIENT_PROFILER_HOME': '100_PERCENT', 'iOSClaimHomeSearch': 'ON', 'ADS_Tagless': 'Casale_On', 'ARCS_DISPLAY_CALL_AGENTS_INVENTORY': 'ON', 'OV_VERSIONING_SERVICE_TURNUP': 'REMOTE_SERVICE', 'ADT_CDP': 'ON', 'HDP_AD_BELOW_MODULES': 'ON_ABOVE_CONTACT_MID_RENDER', 'ARCS_OPAQUE_EXPANSION_VALUE_PROPS': 'CONTROL', 'HDP_SIMILAR_HOMES_PLACEMENT': 'ABOVE_PERSONAL_GUIDE_MODULE', 'iOS_Touring_V1_Flex': 'CONTROL_OFF', 'VL_ReactBDPDescription': 'CONTROL', 'AR_LISTING_AGENT_LEAD_CSAT': 'CONTROL', 'HTCG_PSL_BATCH_LOOKUP': 'ON', 'AndroidRemoveLowDataFilters': 'CONTROL_REMOVE_LOW_DATA_FILTERS_OFF', 'HDP_COMMUTE_APPS': 'ON', 'A11y-ViewportMetaTag': 'CONTROL', 'IOS_BERMUDA_PLAYBACK': 'PLAYBACK_ON_2', 'SEOTEST__NC_H1': 'ALTERNATE', 'HDP_WOW_RESO_FACTSFEATURES': 'ON', 'SHO_DESKTOP_NAV_AD_LOAD_ORDER': 'EARLIER_AD_REQUEST', 'RESTRICT_NWMLS_FSBO': 'ON', 'OnboardingReprompting': 'OnboardingReprompting_CONTROL_OFF', 'IOS_NFS_WOW_CHIP': 'CONTROL', 'HDP_STATIC_COMMUTE_MAP': 'CONTROL', 'ACIntegrationTest': 'CONTROL', 'AndroidTestTrial': 'CONTROL_TREATMENT_ONE', 'NC_PLAN_PRICING_EDUCATION': 'ON', 'NC_TOUR_REQUEST_PICKER': 'CONTROL', 'SHO_NAV_AD_BACKGROUND': 'GRAY', 'SOASTA': 'CONTROL', 'AndroidHomeTrackerV2Api': 'ON_HOME_TRACKER_V2_API', 'AndroidMediaStreamRentalHDP': 'ON_MEDIA_STREAM_RENTAL_HDP', 'SXP_FLYBAR_REGION_API': 'CONTROL', 'ADS_EPA_STOP_PERFORMANCE_V2': 'ON', 'AIPERS_RT_RECS_HOMES_FOR_YOU_HDP': 'MODEL_A_1', 'ARCS_ASK_A_QUESTION': 'CONTROL', 'iPad_Onboarding_Reprompt': 'CONTROL_OFF', 'SEOTEST__HDP_EXPANDED': 'CONTROL', 'RMX_3RD_PARTY_P1': 'ON', 'ADS_HomeTourMobileWebPAA': 'CONTROL', 'SEL_SellerLead_Mobile': 'Control', 'Sell_LP_360Module': 'CONTROL', 'RUM_VIA_PRE_ENDPOINT': 'TREATMENT_OFF', 'HDP_SHOW_SELLER_COMMENT': 'ON', 'IOS_TOUR_IT_NOW_DISCOVERY': 'CONTROL_OFF', 'ARCS_DIRECT_LINK_CF': 'CONTROL', 'IOP_INVESTOR_DASHBOARD': 'CONTROL', 'PR_CONTACT_FORM': 'CONTROL', 'AndroidRentalsApplyNowIntegration': 'ON_APPLY_NOW', 'IOS_SAVED_HOMES_2021': 'ON', 'PPL_GA_MAPS': 'CONTROL', 'ACQ_SRPHDP_DynamicLocation': 'Control_SRPHDPNoCopy', 'AIPERS_SIMILAR_HOMES_MOB': 'CONTROL', 'REV_Remove_CC_Form_On_PALS_Under_Impersonation': 'ON', 'AndroidPropertySearchApi': 'ON_PROPERTY_SEARCH_API', 'ARCS_PA_ZHL_LEAD': 'CONTROL', 'RE_NY_BROKER_ATTRIBUTION': 'ON', 'IOS_UPDATE_TAB_PERS': 'ON', 'SEOTEST__RE_SRPTITLETAGTEST_WITHPHOTOS': 'CONTROL', 'ANDROID_ZILLOW_OFFERS_LANDING_PAGE': 'CONTROL_OFF', 'SHEN_SNP_MARK_UNREAD': 'SNP_MARK_UNREAD', 'MortgageMobilePreApproval': 'PreApproval_OFF', 'AppUpsellLargeAndroid': 'CONTROL_OFF', 'YOLT_ABAD_SAN_ANTONIO': 'CONTROL', 'AndroidSavedHomesPushUpsell': 'CONTROL_OFF', 'AndroidIMXViewer': 'ON', 'REALTIME_PERS_MODEL_MOB': 'CONTROL_4', 'ACQ_SRP_DynamicLocation': 'Control_NoCopy', 'RMX_LIGHTBOX_CHROME_1.5': 'CONTROL', 'SXP_EVENT_MARKUP': 'CONTROL', 'AndroidPropertyTags': 'PROPERTY_TAGS_ON', 'VL_THIRD_PARTY_VR': 'ON', 'AndroidUpdateTabPers': 'ON', 'IOS_SCHOOLS_BOUNDARIES': 'ON', 'RR-ClientProfilerEngagement': 'CONTROL_ON', 'SS_SCHOOL_SEARCH_MOB': 'CONTROL', 'IOS_ZO_HOMEACCESSVERSION': 'IOS_ZO_HOMEACCESSVERSION_V2', 'ADS_EPA_MY_ADS_ACH_BANNER': 'ON', 'MTT_ODASH_TOP_SLOT_ONSITE_MESSAGING': 'BASELINE_TREATMENT', 'SavedSearchRefactor': 'ON', 'SXP_SEARCH_DISPATCHER_SERVICE': 'CONTROL', 'ADS_BETTER_CONTACT_FORM_MESSAGES': 'CONTROL', 'HOPS_ZO_BANNER': 'CONTROL', 'RE_REQUEST_TOUR_NEW_LOOK': 'TEST', 'ZO_FSHDP_RTBP': 'CONTROL', 'AR_CSAT_TOUR_SURVEY': 'VARIANT2', 'TR_HTML_SITEMAP_LINK_HOMEPAGE': 'CONTROL', 'IOS_HOMELOOKUPLIST_V3': 'CONTROL_OFF', 'VL_WOW_BDP_CONTACTS': 'WS_SINGLE', 'AndroidMediaStreamHDP': 'MEDIA_STREAM_HDP_ON', 'AndroidMediaStreamFSPotentialDescription': 'MEDIA_STREAM_FS_POTENTIAL_DESCRIPTION_ON', 'IOS_VIRTUAL_OPEN_HOUSE': 'ON_2', 'PA_UNIVERSAL_NAV_PROFILE_PAGES': 'PROFILE_PAGES_NEW_NAV_ON', 'SPT_RENDER_OFF_MARKET_PAGE': 'ON', 'SEL_AudienceMetricsBackend': 'CONTROL', 'RE_HRSSimilarHomes': 'HRS', 'RMX_TILED_PANO': 'ON', 'STL_PostingService_ModeratedQueue': 'ON', 'ADS_VIDEO_EVERYWHERE': 'EVERYWHERE', 'XoutPropertyMobile': 'ON_XoutPropertyMobile', 'SHEN_EMS_PRE_MOB_INTEGRATION': 'EMS_ON', 'IOS_MEDIA_STREAM_RENTALS_DESCRIPTION': 'ON', 'IOS_NAME_PERSONALIZATION_ONBOARDING': 'CONTROL_OFF', 'ADS_OpaqueBAL_MW_Modal': 'MessageAgent', 'HDP_ZO_DATA_BAL': 'CONTROL', 'CAN_FEATURE_FLAGGING_SERVICE': 'ON', 'FIT_FONT_LOADING': 'NO_INITIAL_VIEW', 'ZO_Jumpstart_AddressSearch': 'QUERY_UNDERSTANDING_ENDPOINT', 'SEOTEST__HDP_WOW_REC_SOLD_AND_POTL_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'ON', 'percent': 0}], 'ANDROID_UPDATES_TAB_AGENT_COSHOPPING': 'CONTROL_OFF', 'ZO_OMHDP_Inline_Upsell': 'CONTROL', 'AndroidNFSWowHeader': 'ON', 'RE_INSTANT_TOUR_BDP': 'CONTROL', 'AndroidSavedHomeUpdates2021': 'ON', 'PA_BETH_ALAN_FLEX': 'CONTROL', 'PR_DISABLE_GOOGLE_TAG_MANAGER': 'CONTROL', 'HDP_OWNERTABS': 'VIEW', 'ABService_CachedVersionsOverridesManager': 'USE_VERSIONS_REDIS_CACHE', 'ADS_OpaqueBAL_KW': 'ON', 'AR_CSAT_45_DAY_CHECKIN_ENABLE': 'VARIANT_1', 'IMX_PHASE_2': 'CONTROL', 'SHO_GoogleTileShadow_Mobile': 'CONTROL', 'IOSIPadContactButtons': 'ON', 'HT_V1_HOMES_API_DEPRECATION': 'ON', 'RR_REAL_TIME_MF_TOUR_SCHEDULING': 'CONTROL', 'SPT_GDP_BATCH_TO_PSL': 'ON', 'HDP_DQ_FS_OTHER': 'CONTROL', 'SXP_DISPLAY_AD_LOADING': 'CONTROL', 'ADSNeighborhoodDesktop': 'ON', 'ADS_EPA_AUTORENEW': 'ON', 'MobileHDPTrial': 'CONTROL', 'NotificationCount': 'CONTROL_OFF', 'TrafficTotalEclipseMobileHomeValuesPage': 'WONDROUS', 'HDP_OV_UPSELL_NFS_MOBILE': 'HOME_VALUE_TRACKER', 'MAS_REGIONS_API': 'ON', 'ADS_CF_conversion_monitoring': 'CONTROL', 'ADS_CONTACT_SUBMIT_REFACTOR': 'CONTROL', 'KeystoneEventFavorite': 'SEND_EVENT', 'ADS_PACE_USER': 'ON', 'SEOTEST__CUSTOM_REGION_FAQ_APARTMENTS_V1': 'CONTROL', 'HDP_WOW_PANO': 'ON', 'IOS_SHOW_SEARCH_FILTERS': 'ON', 'SmartBannerAndroid': 'CONTROL', 'HDP_DQ_FSBA': 'CONTROL', 'SI_DownPaymentVALender': 'CONTROL', 'SL_OFFERDATES_INPUT': 'CONTROL', 'iOSBDPTemplate': 'ON_TemplateBDP', 'IOS_DisableHomeRecs': 'CONTROL_OFF', 'ARCS_ABAD_PHX': 'CONTROL', 'HDP_CollapsedFullPage': 'CONTROL', 'NC_TOUR_V2': 'ON', 'IOS_BDP_INSTANT_TOUR_SCHEDULING': 'CONTROL_OFF', 'SEOTEST__HDP_3D_HOME_TOUR_META_DESCRIPTION': 'CONTROL', 'AR_CSAT_REDIS': 'ON', 'YOUR_HOME': 'YOUR_HOME_V1', 'IOS_WEB_DEEPLINK_ROUTING': 'CONTROL', 'AB_DASHBOARD_AA_TEST': 'CONTROL', 'iOS_Native_OV': 'allWebView', 'iOSHDPMapHole': 'ON_WITHOUT_LABEL', 'RR_ContactSubmit_SLA_Alarms': 'ON', 'ADS_PACE_REGION': 'ON', 'REALTIME_PERS_SORT_MOB': 'REALTIME_RECS', 'SPT_SIMILAR_HOMES': 'ON', 'IOS_DEACTIVATE_ACCOUNT_OPTION': 'CONTROL_OFF', 'RentalTransactionHistory': 'NEW', 'ADS_EPA_LEADS_TIP': 'ON', 'IOS_SHOW_FEWER_RECENT_SEARCHES': 'CONTROL_OFF', 'ADS_EPA_PROMO_PERMISSIONS': 'CONTROL', 'IOS_TABS_LISTING_TYPES': 'CONTROL_OFF', 'RE_NearMeLinks': 'CONTROL', 'DIRECT_LINK_TO_CONTACT_FORMS': 'CONTROL', 'ARCS_ATLAS_PROPERTY_TOURS': 'ON', 'iOS_RenterProfile': 'iOSRenterProfile_ON', 'SP_ZO_HDP_PAGE': 'CONTROL', 'SET_COMPARE': 'CONTROL', 'AndroidHomeRecommendations': 'CONTROL_OFF', 'IOS_UPDATES_TAB_NAME': 'CONTROL_OFF', 'RE_Irene_Owner_Application_Upsell': 'TEST', 'IOS_MEDIA_STREAM_FOR_SALE_POTENTIAL': 'ON', 'NC_VERTICAL_LIVING_COMMUNITY': 'ON', 'IOS_MORE_MENU_SELLER_IMPROVEMENTS': 'CONTROL_OFF', 'ZGMIAIR_CHIP_ZHL_PREQUAL': 'CONTROL', 'ARCS_NY_AD_COMPLIANCE': 'ON', 'SS_DEPRECATE_PRE_APIS': '410_RESPONSE', 'IOS_SS_AUTOCOMPLETE': 'CONTROL_OFF', 'WIDGET_SCHOOL_PARAM': 'SchoolFiltersOpen', 'IOS_ZO_SCHEDULE_VIRTUAL_TOUR': 'CONTROL_SCHEDULE_TOUR', 'iOSNotificationUpsell2': 'CONTROL_OFF', 'IOS_Onboarding_v3': 'ON_PHASE1_REFRESH', 'HDP_COMMUTE': 'ON', 'HDP_COMMUTE_ROUTES': 'ON', 'VIDEO_RENTALS_IOS': 'ON', '2020_TOGGLE_VISIBILITY': 'CONTROL_OFF', 'ADS_EPA_SHOW_OLD_INVOICES_LINK': 'ON', 'AndroidClickstreamLongTermFix': 'CLICK_STREAM_LONG_TERM_FIX_ON', 'AndroidOwnerViewExpanded': 'CONTROL_EXPANDED_OWNER_VIEW_OFF', 'ACQ_TOP_Multivariate_CTACopy': 'Variant_OpenApp', 'AndroidNFSWowTools': 'CONTROL', 'USE_PROPERTY_DATA_SERVICE': 'SERVICE', 'SchoolsOnMap': 'ON', 'EnableVrModels': 'CONTROL', 'SPT_PSL_TO_PDC_IN_GDP': 'ON', 'ARCS_INLINE_TOUR_SECTION': 'ON', 'HDPGalleryUpsell': 'CAROUSEL_ONLY', 'MobileLargerThumbnailImages': 'THUMBNAIL_150_112', 'SS_DEPRECATE_WIDGET': 'FMR_WIDGET_410_RESPONSE', 'ACT_PAGE_FRAME_STYLE_LIB': 'STYLED_CACHED', 'ADS_PostSubmitUpsellTemplate': 'ON', 'KeystoneEventMobContact': 'SEND_EVENT', 'RA_IRENE_BVL': 'CONTROL', 'ADT_HOME_TO_SRP_REDIRECT': 'CONTROL', 'ODASH_NFS_NEW_ZEST_HOME_VALUE': 'ON', 'IOS_HIDE_EXPOSED_FILTERS': 'ON', 'HomeVideoNorthPole': 'CONTROL', 'IOS_IMX_VIEWER': 'ON', 'VL_UnitPhotos': 'ON', 'SEL_VANITY_BAL': 'ON', 'ADS_TrolleyTown': 'ON', 'AgentAdvertiseLinkPlacement': 'CONTROL', 'IOS_OFFERS_REGIONAL_LPS': 'CONTROL', 'IOS_ONBOARDING_PUSH_PROMPT_ON_LAUNCH': 'ON', 'HDP_Toolbar': 'Sticky_Bottom', 'IOS_LISTING_COLOR_BLUE_TO_RED': 'ON_NO_BLUE_2', 'ODASH_TCOS_MODULE': 'TCOS_MODULE_ODASH_V1', 'SI_DprRemoveGdpFiltering': 'TEST', 'NonCompeteHouseAds': 'AD_A', 'Android3DHomesHDP': 'ON_3D_HOMES_HDP', 'NC_DRIVING_DIRECTIONS': 'CONTROL', 'RE_Premium_Package_Email_Upsell': 'CONTROL', 'ZO_Flag_Use_Bridge_Bathroom_Info': 'CONTROL', 'iOS_Onboarding_V3_Copy_Changes': 'ON', 'ANDROID_SEARCH_BOX_CLEARING': 'CONTROL_OFF', 'AndroidZOMapDots': 'CONTROL_OFF', 'AndroidShowSmartToggle': 'ON_SHOW_SMART_TOGGLE', 'MTT_HDP_TOP_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_TREATMENT', 'SEOTEST__ADS_AND_TRACKING_PIXELS': 'CONTROL', 'HDP_Other_Costs_Mobile': 'CONTROL', 'NC_LOT_BANNER': 'CONTROL', 'IOS_SCHOOLS_MAP_ICON': 'CONTROL_OFF', 'IOS_ZO_HOMEACCESS_CAROUSEL': 'CAROUSEL_ON', 'iOSBuildingCallButton': 'ON_BLUE_BUTTON', 'iOS_EncodedSavedSearchAPI': 'ON', 'MarketingPersistentSmartAppBanner': 'PERSISTENT', 'ADT_TOP_SLOT_SRP': 'ONSITE_MESSAGING', 'HDP_FakeLightbox': 'CONTROL', 'SL_OFFERINHAND_INPUT': 'CONTROL', 'RA_IRENE_REMOVE_SSN_FROM_IDV': 'CONTROL', 'Android_Show_Search_Filters': 'ON_SHOW_SEARCH_FILTERS', 'AndroidOwnerView': 'ON_OWNER_VIEW', 'ClaimUpsell': 'CONTROL', 'UDP_PRE_EDIT_HOME_FACT': 'NEW_UI', 'PERS_ENGAGEMENT_SAVED_SEARCH': 'ENGAGEMENT_ON', 'SI_RenterInfo': 'TEST', 'IOS_REG_LOGIN_STRONG_PASS': 'ON', 'PPL_PHOTOGRAPHER_SPECIALIZATION': 'ON', 'PERF_PRELOAD_HDP_IMAGE': 'CONTROL', 'HDP_WOW_RS_AND_NFS_UPSELL': 'REFI_UPSELL', 'PERF_HDP_WEBP': 'ENABLED', 'IOS_3D_HOMES_FILTER': 'ON', 'Traffic_PRExit_Browse_Homes': 'CONTROL', 'AndroidSideBySide': 'CONTROL_OFF', 'ACQ_TOP_MODIFIEDCTA_GETvsDOWNLOAD': 'Control_DL', 'ZO_HDP_COMING_SOON': 'CONTROL', 'ADS_EPA_SHOW_ACH': 'ON', 'VEL_CLIENT_PROFILER_BUILDINGDETAILS': '100_PERCENT', 'HDP_AD_MWEB': 'ON', 'MAS_PSL_BATCH_LOOKUP': 'ON', 'IO_WhatsMyHomeWorth': 'ON', 'ZON_TEST_TRAIL': 'CONTROL', 'BALButtonStyle': 'TOP_BLUE_BALButtonStyle', 'ADT_DESKTOP_HDP_CALLOUT': 'SAVE_AND_SHARE', 'ADS_EPA_DISPLAY_AGENT_BILLING_PORTAL_LINK': 'ON', 'RE_BlendedHomeRecsModule': 'CONTROL', 'ZO_UPSELL_CHECK_FROM_OASIS': 'ON', 'AndroidHomeRecsPushReg': 'HOME_RECS_REG_ON', 'IOS_HomeTrackerToggleIconOnHDP': 'CONTROL_OFF', 'IOS_ACCOUNT_SETTINGS': 'ON', 'AndroidBDP': 'TEMPLATED', 'SEL_SpamFighting': 'ON', 'VL_InferredBADAttributes': 'ON', 'SP_NATIVE_BUILDING_PAGE': 'CONTROL', 'IOS_OMHDP_REFI_UPSELL': 'CONTROL_OFF', 'CommunityPillar_Hide_CP': 'CONTROL', 'HDP_FNF_BULLETS': 'ON', 'PPL_CONS_PUB_PROFILES': 'REMOVE_PROFILES', 'TR_INLINE_SRP_SPECIFIC_ZSG': 'ON', 'RE_Public_Health_Advisory': 'ON', 'IOS_KINGFISHER_FILTERS_REDESIGN': 'ON_3', 'Zo_Flag_OASIS_Use_Zg_Graph': 'CONTROL', 'ANDROIDCLAIMHOMEUPSELL': 'UPSELL_ON', 'HDP_SERVICE_NC_APP_V2': 'ON', 'ZEST_OFFERS_GR_PROMO': 'ON', 'ACQ_MOBILE_UPSELL_APPS': 'ON', 'ARCS_UDS_GDP': 'CONTROL', 'ADSNeighborhoodPhone': 'ON', 'ADS_ENABLE_STREET_EASY_ZONE': 'ON', 'IOSVIDEOPLAYBACK': 'ON', 'ARCS_THREE_BUTTONS_APPS_ANDROID': 'ON', 'AndroidBermudaPlayback': 'PLAYBACK_ON', 'AndroidMediaStreamFSBADescription': 'MEDIA_STREAM_FSBA_DESCRIPTION_ON', 'ACQ_Homepage_2CTAModule': 'Variant_BrowserSelect', 'FLEX_COUNTY_FLIP': 'ON', 'AndroidAllHDPsNative': 'ON_ALL_HDPS_NATIVE', 'TrafficTotalEclipseDesktopHomeValuesPage': 'MAGICAL', 'BDP_SKIP_LINKS': 'SKIPLINKS_HEADER', 'Traffic_SRP_Footer': 'LINKS_20', 'VL_BDP_NEW_TAB': 'CONTROL', 'AGENT_DASHBOARD_REDIRECT': 'REDIRECT', 'iOSZMMLongFormWebView': 'CONTROL_NATIVE', 'ACQ_TOP_Copy_GetAlertsVSNone': 'Control_NoCopy', 'AgentNavigationiOS': 'AGENT_NAV_ON', 'SEOTEST__REGION_INSIGHTS': 'CONTROL', 'ZO_DataStrategy_CreateOfferRequest': 'ON', 'AndroidNewLocationLookupApi': 'ON_ANDROID_NEW_LOCAION_LOOKUP_API', 'Android_OnboardingReprompting_2': 'ONBOARDINGREPROMPTING_2_ON', 'HDP_SuperShare': 'ON', 'VL_BLS_V2': 'V2', 'RE_Rental_MF_OffMarket_NoIndex': 'ON', 'AndroidMapRefactoring': 'ON_MAP_REFACTORING', 'ADS_OpaqueBAL_MW': 'CONTROL', 'Android_CollapsedHDP': 'ON', 'iOSIPadHDPLightbox': 'ON_2', 'ARCS_MY_AGENT_A11Y_UI': 'ON', 'AndroidCSATSurvey': 'SURVEY_APP_STARTUP', 'HomeSearchNoAutoFocus': 'CONTROL', 'ADT_PERSONALIZED_HOME_LANDING': 'CONTROL', 'PERS_GRS': 'CONTROL', 'HDP_TOURING_LEGACY': 'CONTROL', 'PPL_TEAM_PROFILE_STYLING': 'PROXIMAL_BUTTONS', 'ARCS_TRULIA_VIA_PSL': 'ON', 'SI_DownPaymentAssistance': 'ON_NO_CITY_FILTER', 'SEOTEST__HDPAddressVariants': 'IN_BREADCRUMB', 'SXP_PREXIT_CLAIMS_CHECK': 'ENABLED', 'VL_FAQ': 'ON', 'SHO_ZIPCODES_IN_REGION_AUTOCOMPLETE': 'INCLUDE_ZIPCODES', 'SEOTEST__SXP_SEO_TEST': 'CONTROL', 'TR_Maps': 'CONTROL', 'HDP_UPDATED_FNF': 'ON', 'SEOTEST__HDP_WOW_RED_BLUE': 'CONTROL', 'iOSHomeRecs': 'CONTROL_NO_HOME_RECS', 'IOS_MEDIA_STREAM_FS_POT_DESCRIPTION': 'ON', 'RE_IDVBadge': 'CONTROL', 'UnrestrictMarketingPixels': 'NO_CAMPAIGN_REQUIRED', 'SXP_OPEN_HOUSE_FLEX': 'OPEN_HOUSE_BOOSTED', 'AndroidModalBalContactButtons': 'ON', 'HDP_CollapsedUpdate': 'CONTROL', 'HDP_SERVICE_FULL_SSR': 'CONTROL', 'SEOTEST__EVENT_MARKUP_DISABLED_REGIONS': 'CONTROL', 'PPL_INVESTOR': 'ACTIVE_INTERNAL_USE', 'IOS_OFFERS_NATIVE_QUESTIONNAIRE': 'CONTROL', 'HDP_DQ': 'ON', 'SHEN_EMS_PROPERTY_ALERT': 'CONTROL', 'AndroidHomeLookupApi': 'ON_HOME_LOOKUP_API', 'SP_NATIVE_FOR_SALE_PAGE': 'CONTROL', 'FullScreenPhotoModalBAL': 'CONTROL_OFF_FullScreenPhotoModalBAL', 'SEOTEST__RE_SRPTitleTags_CityStateApartments': 'CONTROL', 'AndroidProfileV0': 'ON', 'MTT_SRP_TOP_SLOT_HOLDOUT': 'ON', 'IOS_RENTALS_APPLY_NOW_INTEGRATION': 'ON_APPLY_NOW', 'IOS_ZillowGroupAnalytics_RE': 'CONTROL_OFF', 'YOLT_ABAD_JACKSONVILLE': 'CONTROL', 'IOS_COSHOPPING_V1': 'COSHOPPING_ON', 'SP_FOR_SALE_PAGE': 'CONTROL', 'HDP_SERVICE_NFS_APP_V2': 'ON', 'VEL_AB_SERVICE': 'REMOTE_SERVICE', 'IOS_MEDIA_STREAM_ALL_HDP_TYPES': 'CONTROL_OFF', 'AndroidCoshoppingUpsellsV1': 'CONTROL_OFF', 'SEOTEST__RE_WOWHDP': 'CONTROL', 'SPT_LOADING_DOUBLE_SCROLL_NFS': 'CONTROL', 'ARCS_FEATURED_IMAGE': 'CONTROL', 'ZO_OffersLP_ZO_Pause_Banner': 'ON', 'IOS_INSTANTOFFERS_SELL_TAB_V2': 'CONTROL', 'HDP_COMMUTE_SOURCE': 'TRULIA', 'AndroidOnboardingAddRentFilters': 'CONTROL_OFF', 'PERS_MOCK_SEARCH_LATENCY_PRE': 'CONTROL', 'SRP_MWEB_ADS_VARIANTS': 'VARIANT_B', 'ADS_EPA_HIDE_OLD_INVOICES_LINK': 'CONTROL', 'REV_remove_cc_entry_when_impersonating_AB': 'ON', 'ARCS_TOURS_REQUIRED_AGENTS': 'CONTROL_5_AGENTS', 'ADS_EPA_DISPLAY_FLEX_LABELING': 'CONTROL', 'HDP_InlineCSS': 'CONTROL', 'IOS_SHOW_NOTIFICATION_COUNT': 'CONTROL_OFF', 'REV-4302_hide_otc_token_in_admin_ui': 'CONTROL', 'TRACK_HOME_VALUE_V1': 'COPY_A', 'SHO_GoogleTileShadow_Desktop': 'CONTROL', 'SXP_PAGINATION': 'LEGACY_PAGINATION', 'AndroidPanoramas': 'PANORAMAS_ON', 'AndroidExposedShare': 'ON', 'REV_SEM_BA': 'CONTROL', 'SXP_KF_FILTERS_V2': 'ON', 'ADAT_HFF_SSTT': 'ON', 'AndroidZOZillowOwnedFilter': 'ON', 'ACQ_Placement_TopvsBottom': 'Control_Top', 'YOLT_ABAD_FAYETTEVILLE': 'CONTROL', 'AndroidMagellanHDP': 'MAGELLAN_HDP_ON', 'MobileInlineActions': 'SHARE_FIRST', 'VL_RESPONSIVE_SRP_OPEN_FULL_PAGE': 'OPEN_IN_LIGHTBOX', 'IOS_ZEST_OFFERS_UPSELL': 'CONTROL_OFF', 'AndroidWhatsNew3DHomes': 'ON_WHATS_NEW_3D', 'HDP_SIMILAR_HOMES_RECS': 'HDP', 'IOS_CTA_END_GALLERY': 'CONTROL', 'SXP_MLS_NONMLS_FILTER': 'CONTROL', 'VL_BLS_FLYBAR': 'ON', 'ACQ_iOS14_AdjustvsApple': 'Control_Adjust', 'AppUpsellBottomiOS': 'CONTROL_OFF', 'CAREERS_BRAND_MLOA': 'ON', 'ARCS_STREAMLINED_TOURS_DESKTOP': 'ON', 'AndroidExposedFilters': 'ON', 'RE_GuidedSearchFiltersPOC': 'CONTROL', 'SRP_DISABLE_NC_COMMUNITY_LAYER': 'CONTROL', 'IOS_NATIVE_BDP': 'USE_NATIVE_BDP_ENABLED', 'ZO_LandingPage_Autocomplete': 'AUTOCOMPLETE_ENDPOINT', 'SELLING_SOON_MODEL': 'CONTROL', 'SI_ANONYMIZE': 'CONTROL', 'SL_FSBA_MANUAL_POSTING': 'DISABLED', 'HDP_UPDATED_STATS_DISPLAY': 'CONTROL', 'IOS_RTBP_V3': 'CONTROL_OFF', 'IOS_INAPP_NOTIFICATION': 'CONTROL_NONE', 'HDP_COMPS_API_V2': 'CONTROL', 'APPS_IOS_HDP_DWELL_TIME': 'ON', 'SE_InstantOffer_Questionnaire_IntroBadge': 'ON', 'SEOTEST__HDP_WOW_SOLD_AND_OFF_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'ON', 'percent': 0}], 'HDP_WOW_LAYOUT_FOR_SALE': 'CONTROL', 'Claim_Home_Customized_Experience_PopUP': 'CONTROL', 'ZSG-Typeramp': 'GOTHAM_FOR_ALL', 'MapUpsellMessages': 'TEXT_WITH_IMAGE_TEXT_TWO', 'VL_UNIT_TABLE_MATCHES': 'TEST', 'IOS_HIDE_55': 'CONTROL_OFF', 'RA_RACHEL_INCOME_DOCS_ENCOURAGEMENT': 'CONTROL', 'SXP_3DHOME_FILTER': 'ON', 'ARCS_A11Y_UI': 'ON', 'IOS_Profile_v0': 'ON', 'AndroidAgentFinderPerfReporting': 'CONTROL_AGENTFINDER_REPORTING_OFF', 'NC_ZO_UPSELL_LEVEL': 'CONTROL', 'SEOTEST__HDP_SERVICE_FOR_SALE': 'CONTROL', 'ADS_BAL_INVERTED_MW_MODAL': 'INVERTED', 'REV_Replace_TT_CC_Form_with_CSI': 'CONTROL', 'SI_SelectLLPRenterForContact': 'CONTROL', 'ADS_CF_ANDROID_INSTANT': 'CONTROL', 'SEOTEST__WIL_BANNER': 'ON', 'IOS_CLICKSTREAM_SEARCH_IMPRESSIONS': 'ON_PAGEVIEW_ZPIDS', 'SchoolFilterPlacement': 'TOP_LEVEL_SchoolFilterPlacement', 'NC_ZO_BUILDER_BADGE': 'ON', 'ARCS_MY_AGENT_REWRITE': 'ON', 'HDP_WOW_LAYOUT_FSBA': 'CONTROL', 'AndroidInAppCovidVT': 'CONTROL_OFF', 'SP_BUILDING_PAGE': 'CONTROL', 'SXP_QU_MIGRATION': 'ON', 'APPS_IOS_AUTOCOMPLETE2': 'CONTROL_OFF', 'HomePageSellZestimateQueryViewEqualsOwner': 'ON', 'IMX_LIGHTBOX': 'ON', 'SEL_SEM_LANDING_PAGE': 'ON', 'HDP_Mobile_Bounce': 'FORSALE_COUNT_EMAIL', 'AndroidModalBalNewConstruction': 'CONTROL_OFF', 'AndroidRenterProfileV2': 'RENTER_PROFILE_V2_ON', 'IOS_ZO_STARTANOFFER': 'ON', 'ACQ_MOBILE_UPSELL_SXP': 'CONTROL', 'ADS_OpaqueBALImpressions': 'CONTROL', 'IOS_GETZ_SCHOOLS_FROM_MAS': 'ON', 'IOS_ZO_MAP_DOTS': 'CONTROL', 'PERS_ENGAGEMENT_PROPERTY_ALERT': 'ENGAGEMENT_ON', 'MobileMortgageLongForm': 'CONTROL_LongForm_ON', 'HOME_VALUATION_GDP': 'CONTROL', 'SHO_ADS_AND_TRACKING_PIXELS': 'CONTROL', 'Android_RTBP_FSHDP': 'CONTROL_OFF', 'AIPERS_SIMILAR_HOMES_RENTAL_GDP': 'CONTROL', 'ZO_FSHDP_RTBP_V3': 'CONTROL', 'AndroidAutocompleteV3': 'ON_ANDROID_AUTOCOMPLETE_V3', 'HDP_SCHOOL_INFO': 'NEW_SKOOL', 'USER_DATA_SERVICE_CLIENT_DATASOURCE': 'USER_DATA_SERVICE', 'ACQ_SRP_NavBarInteraction': 'Variant_Stacked', 'ADS_PACE_ALLOW_LIST': 'ON', 'AIPERS_GDP_HOME_RECS': 'RT_RECS', 'Actions (Type . to access issue actions)': 'CONTROL', 'SXP_LIST_ONLY_SRP': 'CONTROL', 'ZO_DataStrategy_GetOfferRequests': 'ON', 'IOS_THIRD_PARTY_VIRTUAL_TOUR': 'ON', 'ZORD_BETH_CONTACT_INFO': 'CONTROL', 'AppUpsellTesting': 'CONTROL', 'ARCS_OPAQUE_REWRITE': 'ON', 'MTT_HDP_TOP_SLOT_HOLDOUT': 'ON', 'RR-TakeBackOurLeads': 'TAKE_BACK', 'MOB_SNP_API': 'ON', 'AndroidCaptureVideo': 'CAPTURE', 'ARCS_TOUR_REWRITE': 'ON', 'IOSVIDEOCAPTURE': 'ON', 'IOS_ONBOARDING_PUSH_NEW_FLOW': 'ON', 'IOS_ZO_HOMEACCESS_VERIFICATION': 'ON', 'IOS_Splunk_Logs': 'CONTROL_OFF', 'REV_replace_cc_with_csi': 'CONTROL', 'HDP_IMAGE_CAROUSEL_CHEVRON': 'ON', 'SEMMobilePage': 'FullScreenWhite', 'REGION_AUTOCOMPLETE_IOS': 'ON', 'HDP_DARKER_LIGHTBOX': 'CONTROL', 'AppUpsellTopAndroid': 'CONTROL_OFF', 'NC_TOUR_MOBILE': 'ON', 'ARCS_PROPERTY_TOURS_V2': 'CONTROL', 'ARCS_BAL_RADIO_REMOVAL': 'CONTROL', 'HDP_SERVICE_REST_ALL_OTHER_TYPES_APP_V2': 'ON', 'AndroidModalBAL': 'CONTROL_OFF', 'SPT_RENDER_NATIVE_FOR_SALE_PAGE': 'CONTROL', 'HDP_OV_UPSELLMODULE': 'OWNERDASH_ALL', 'ADS_EPA_ROI': 'ON', 'IOS_HOME_TRACKER_VIEWED_STATE': 'ON', 'OrganicPaAdsHomePageCopy': 'CONNECT_QUALITY_LEADS', 'PERS_SORT_V0_PRE': 'CONTROL', 'SXP_HDP_Load_Order': 'OPTIMIZED', 'VEL_CLIENT_PROFILER_HOMEDETAILS': '100_PERCENT', 'AndroidNativeAds': 'NATIVEADS_ON', 'RE_JanusBrainSort': 'CONTROL', 'SEOTEST__RE_ForRentForSaleSRPBreadcrumbs': 'CONTROL', 'IOS_LIST_CARD_REDESIGN': 'ON_WOW_CARD2', 'SPT_ABPD_SHADOW_TEST': 'CONTROL', 'IOS_MAP_MVVM_REFACTORING': 'ON', 'ARCS_THREE_BUTTONS_APPS': 'ON_FOR_IOS', 'ARCS_MLS_COMING_SOON': 'ON', 'ZOB_START_AN_OFFER': 'ALL', 'IOS_INSTANTOFFERS_UPSELLS_OFFMARKET': 'CONTROL', 'HDP_NFS_NEW_ZEST_HOME_VALUE': 'ON', 'TRAFFIC_URL_SERVICE_PDC_DATA': 'ON', 'ADS_TCPA_APP': 'ON', 'RR-TourSchedulingAndroid': 'CONTROL', 'ARCS_FB_ADS_DISPLAY': 'ON', 'IOS_MAGELLAN_ALL': 'ON', 'HDP_REDUCE_RERENDERS': 'CONTROL', 'STABLE_HOME_VALUE_MODULE': 'CONTROL', 'ZO_Bridge_Square_Footage': 'ON', 'AR_INTERCOM': 'CONTROL', 'HDP_VideoWalkthrough_Upsells': 'Control', 'PERF_ANALYTICS_LOADED': 'ENABLED', 'HDP_ReportSelfSelect': 'ON', 'SEOTEST__SCHEMA_RANKING_TRIAL_V1': 'CONTROL', 'iOSOwnerView': 'iOSOwnerView_ON', 'KeystoneEventStartVideo': 'SEND_EVENT', 'AndroidTagsV2': 'ON', 'IOS_MEDIA_BROWSER_CAROUSEL': 'ON', 'SPT_LISTINGACCOUNTID_SOURCE': 'VIA_AGENT_PROFILE', 'HDP_WOW_RS_AND_NFS_APP': 'ON', 'ADS_EPA_SCHEDULED_CANCELATION': 'ON', 'POGO_REGION_SEARCH_SERVICE_MIGRATION': 'CONTROL', 'SPT_RENDER_FOR_SALE_PAGE': 'ON', 'REALTIME_PERS_MODEL_PRE': 'CONTROL_4', 'SEOTEST__HDP_WOW_FOR_SALE_BY_AGENT_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'ON', 'percent': 0}], 'z3dThumbnailStripStyle': 'ON', 'AndroidDataDogRUM': 'CONTROL_OFF', 'SXP_MAKE_ME_MOVE': 'REMOVED', 'HDP_EXPANDED_MODULES': 'CONTROL', 'HDP_FLYBAR_PRE': 'ON', 'IOS_CONTINGENT_V2': 'ON', 'IOS_UPDATE_TAB_HORIZONTAL_SS': 'ON_COLLECTIONS', 'NC_SURNAME': 'SURNAME_REQUIRED', 'PL_UPSELL_COPY': 'VARIANT_C', 'SHO_GA_ResultsTotalEvent': 'ON', 'DigsSideNum': 'CONTROL_5', 'PreApprovalMobileHDPUpsell': 'CONTROL', 'ARCS_PREAPPROVAL_CHECK': 'CONTROL', 'Android3dToursBDP': 'CONTROL_ANDROID_BDP_3D_TOUR_OFF', 'BDP_PERF_DEFERRED_PRIORITY': 'DEFERRED_AND_PRIORITY', 'HDP_MobileSummaryCalc': 'CONTROL', 'ADS_EAN_PREFS': 'ON', 'HOME_SUMMARY_CONTINGENT_LISTINGS_V1': 'ON', 'IOS_ZO_MAP_DOTS_TWO': 'CONTROL_OFF', 'ACQ_TOP_Holdout': 'Control', 'ADS_HomeTourMobileWeb': 'CONTROL', 'ARCS_LISTING_AGENT_RELOCATION': 'CONTROL', 'IOS_HDP_CALL_BUTTON': 'CONTROL_OFF', 'AndroidNativeBDPView': 'ON_SHOW_NATIVE_BDP', 'MTT_MRTD_POST_API_MIGRATION': 'ON', 'HDP_FULL_SSR_FS_POT': 'ON', 'AndroidInstantOfferForSale': 'INSTOFFER_FS_PHOTO_GALLERY', 'APPS_IOS_NATIVE_HDP_ALL_TYPES': 'ALL_TYPES', 'DigsMobileWebDigFromHDP': 'CONTROL', 'AndroidHomeLookupApiV3': 'CONTROL_HOMELOOKUP_API_V3', 'TrafficAutoAccountCreationMessaging': 'POPUP_MESSAGE', 'AndroidGeofence': 'ON_GEOFENCING', 'MapMarkersForZoomLevel': 'CONTROL_OFF', 'RE_Mweb_Application_Upsell': 'CONTROL', 'iOSCommunityPillars': 'ON', 'YOLT_NO_OB_TOURS_PHX': 'CONTROL', 'RE_Flybar_Mg_Url_Service': 'TEST', 'iOSLongFormWebView': 'WEBVIEW_ON', 'HDP_PRELESS_WEBVIEW': 'CONTROL', 'ComingSoonContactLink': 'CONTROL', 'ContextualAddressSearch': 'ON', 'SEOTEST__HDP_WOW_FOR_SALE_BY_AGENT': 'CONTROL', 'MTT_HOP_RTB_3_ONSITE_MESSAGING': 'CONTROL', 'AndroidCommute': 'CONTROL_COMMUTE_OFF', 'ADS_SubmitButtonInViewApp': 'CONTROL_OFF_ADS_SubmitButtonInViewApp', 'ODASH_ZO_NFS_UPSELL_ONSITE_MESSAGING': 'ONSITE_MESSAGING', 'RE_HDP_Change_Footer_Links_To_Apartments': 'CONTROL', 'AndroidPaginationList': 'PAGINATION_LIST_ON', 'AIPERS_SIMILAR_HOMES_PRE': 'CONTROL', 'ARCS_REACT_MWEB_NO_LIGHTBOX': 'CONTROL', 'AR_CHER_BROWNOUT': 'CONTROL', 'ZO_Rewards_FSHDP_Upsell': 'CONTROL', 'DualTrackerTrial': 'NEW_iOS_DUAL_TRACKER', 'PA_EAN_PROVISIONS_ON_Z': 'PROVISIONS_OFF', 'TrafficHomeValuesHDPModule': 'CONTROL_DISABLED', 'REGION_PROFILE': 'CONTROL', 'PERS_SORT_ROLLOUT_MOB': 'ON', 'ZO_SellLP_ZO_Pause_Banner': 'ON', 'ZO_DataStrategy_GetOfferRequestByZpid': 'ON', 'ZO_TOP_NAV': 'CONTROL', 'HDP_OPEN_HOUSE_SAVE': 'APP_ONLY', 'iOS_ATS_HTTPS': 'CONTROL', 'AndroidInstantOfferForOffMarket': 'CONTROL_INSTOFFER_OFFMARKET_OFF', 'MTT_ODASH_BOTTOM_SLOT_HOLDOUT': 'ON', 'ADS_PACE_PALS_METROID': 'CONTROL', 'HDP_HOME_RECS_REACT': 'ON', 'RE_SearchRefinementIntegration': 'CONTROL', 'ADS_OpaquePAC': 'CONTROL', 'CAN_FEATURE_FLAGGING_SERVICE_PRE': 'CONTROL', 'ADS_TCPA_WEB': 'ON', 'SE_SellerLead_PhoneRenterDisambiguation': 'CONTROL', 'SEOTEST__SHO_MAGIC_CARPET_SEO': 'HDP_IN_LIGHTBOX', 'ANDROID_ZEST_OFFERS_UPSELL': 'CONTROL_OFF', 'RE_Bounty_Brain_Sort': 'CONTROL', 'ARCS_SELECT_BAL_AGENTS': 'CONTROL', 'RR-RentalContactFormRefactor': 'CONTROL', 'ZOB_ABAD_DISCLAIMER': 'CONTROL', 'SEOTEST__HDP_WOW_REC_SOLD_AND_POTL': 'CONTROL', 'EmailAutoSignInAndroid': 'ON', 'RE_CANADA_CTA': 'CONTROL', 'PROFILE_SALES_LISTINGS_API': 'CONTROL', 'ARCS_TOUR_UPGRADE_V1': 'CONTROL', 'CommunityPillarRegistrationCheckbox': 'CONTROL_Professional', 'HDP_SERVICE_ZILLOW_OWNED_APP': 'CONTROL', 'IOS_LOCAL_PUSH': 'CONTROL_OFF', 'DXP_HERO_SHORTENING': 'CONTROL', 'HideNotificationCount': 'CONTROL_OFF', 'Templates_CollapsedHDP': 'On_All', 'KeystoneEventCrawlMonitor': 'SEND_EVENT', 'ADT_GEO_LANDING_TRIAL': 'CONTROL', 'ARCS_CONTACTABLE_LISTING_AGENT': 'CONTROL', 'NFS_RS_HomeClaims': 'IsThisYourHome', 'IOS_RTBP_FSHDP': 'CONTROL_OFF', 'ZO_HDP_HOUR_ONE_VIDEO': 'CONTROL', 'NC_PRICE_MODIFIER': 'CONTROL', 'VL_FACTS_AND_FEATURES_REDESIGN': 'CONTROL', 'FLEXIBLE_SEARCH': 'ON', 'RR_BDP_Page_Name': 'NEW', 'SXP_VISUAL_AUDIT_2021': 'CONTROL', 'IARCS_FLYBAR_VOYAGER_REGIONS': 'ON', 'IOS_SIDE_BY_SIDE_DISCOVERY': 'CONTROL_OFF', 'HDP_OV_OFFMRKT': 'ON_W_PUBLIC_TABS', 'ACT_THREE_ICON_CTA': 'ON', 'IOSIPadMapClickFlow': 'CONTROL_OFF', 'REAppUpsell': 'CONTROL', 'ARCS_SENTRY': 'CONTROL', 'TENgageHomeReportSignups_Desktop': 'Control', 'SXP_HDP_BLUE_TO_RED': 'ON', 'PhotocardsVsMapBubbleVsCarousel': 'CONTROL_PHOTOCARDS', 'AndroidSideBySideDiscovery': 'CONTROL_OFF', 'LayersViewPosition': 'CONTROL_Standalone', 'SHUB_FAVORITES_PAGE': 'CONTROL', 'HDP_SERVICE_RENT_APP_V2': 'ON', 'SE_InstantOffer_ContactForm': 'CONTROL', 'AndroidNewRegistration': 'NEW_REGISTRATION', 'ZO_Z360_LPAddressEntry': 'CONTROL', 'PROFILE_LISTINGS_API': 'USE_PROFILE_PAGE_API', 'IOS_MEDIA_STREAM_HDP': 'ON', 'PremierAgentNav': 'PREMIER_AGENT_NAV_ON', 'MTT_FRHDP_TOP_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_CTRL', 'AndroidOnboardingV3CopyChanges': 'COPY_CHANGES_ON', 'SHUB_SHARE_HDP': 'CONTROL', 'HDP_DQ_BDP': 'CONTROL', 'PERS_SHARED_FAVORITES': 'CONTROL', 'PERF_HOPS_NO_UPSELL_SHIFT': 'ON', 'HDP_FACTS_AND_FEATURES': 'ON', 'iOSTimeOnZillow': 'ON', 'HDP_TOP_SLOT': 'ONSITE_MESSAGING', 'MarketingMobileAppUpsellBanner': 'ONE_BUTTON_STYLE', 'HomeReportOnSave': 'HOME_REPORT_ON_SAVE', 'HDP_DESKTOP_LAYOUT_TOPNAV': 'CONTROL', 'ACT_SIGN_IN_WITH_APPLE': 'ON', 'HDP_GALLERY_CONTACT': 'CONTROL', 'SEOTEST__HDP_WOW_RED_BLUE_percents': [{'treatment': 'CONTROL', 'percent': 100}, {'treatment': 'ON', 'percent': 0}], 'Android3DHomesTagOnMap': 'ON_3DHOMES_TAG', 'AndroidNewConstructionGeofence': 'CONTROL_NEW_CONSTRUCTION_GEOFENCE_OFF', 'NC_REVIEWS': 'ON', 'MTT_ODASH_BOTTOM_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_CTRL', 'HDP_FEDERATED_PHOTOS': 'CONTROL', 'HDP_DQ_OVERRIDE': 'CONTROL', 'EQUITY_MODULE_ODASH_V1': 'ON', 'SHUB_DISCOVER_SIGNIN': 'ON', 'HDP_LIP_SUNSCORE': 'LIP', 'SL_AudienceMetricsViewsAndSaves': 'CounterService', 'IARCS_LEAD_PACING_BEHAVIORS': 'CONTROL', 'ZO_Questionnaire_NewCon': 'TEST', 'IOS_ENABLE_PERIMETERX': 'CONTROL_OFF', 'IOS_SHOW_ZILLOW_DOCUMENT_PREFERENCES': 'CONTROL_OFF', 'AndroidHDP23': 'NATIVE', 'IOS_QUESTIONNAIRE_V4': 'CONTROL', 'AndroidNormalPerfReporting': 'CONTROL_REPORTING_OFF', 'HDP_TOURING_REACT': 'CONTROL', 'HDP_WOW_CLASSIC_MWEB': 'CLASSIC_WOW', 'RR-CometWhoAmI': 'OFF', 'HDP_SERVICE_FSBA_MOBILE': 'ON', 'IOSPHOTOPEEK': 'ON', 'HDP_ADD_OPTIMIZE': 'ON', 'VL_SPECIAL_OFFER_UPDATE': 'TEST', 'RE_BDPHomeRecsModule': 'CONTROL', 'IOS_TWENTY_TWENTY': 'CONTROL_OFF', 'ANDROID_NAME_PERSONALIZATION_ONBOARDING': 'CONTROL_OFF', 'SXP_HEADER_TAG_WRAPPER': 'ON', 'NEW_CAREERS_SITE': 'ON', 'NC_ZILLOWOFFERS_BANNER': 'CONTROL', 'AppUpsellLargeiOS': 'CONTROL_OFF', 'iOS_Saved_Homes_3DHomes_Discovery': 'CONTROL_OFF', 'IOS_STRONGER_PASSWORD': 'ON', 'AAP_PROMOTED_AGENT_INTEGRATION': 'CONTROL', 'ShowSchoolPage': 'CONTROL', 'AndroidNewNearbyOpenHousesAPI': 'ON', 'BALButtonText': 'CONTACT_AGENT_BALButtonText', 'iOS_CollapsedHDP': 'ON', 'HDP_BING_V8': 'V8_REL_BIRDSEYE', 'IOS_2020_DATA_QUALITY': 'ON', 'Susan_CMATool': 'ON', 'AndroidGetPreQualifiedOnChipFSBA': 'ON_GET_PRE_QUALIFIED_ON_CHIP_FSBA', 'HDP_VIDEO': 'ON_W_MSG', 'NFSHDP_CLAIMS_UPSELL': 'VARIANT_C', 'HDP_OV_OFFER_STATUS': 'CONTROL', 'USER_DATA_SERVICE_CLIENT_MODE': 'LIVE', 'ANDROID_ONBOARDING': 'ONBOARDING_ON_SS', 'SXP_Multifamily_Filter': 'MULTIFAMILY_SEPARATE', 'SXP_FOOTER': 'RESPONSIVE_REACT', 'HDP_WOW_NC': 'ON', 'IARCS_EXCLUSIVE_AGENTS_BEHAVIOR': 'ON', 'CAREERS_JOBS_WORKDAY': 'ON', 'HDP_ZMA': 'ON_ENFORCE_PW', 'ZSG-SvgIcons': 'CONTROL', 'HDP_WOW_APPS_V0': 'CONTROL', 'MOBILE_MAGELLAN_FIELD': 'ON', 'AndroidThirdPartyVirtualTours': 'ON', 'TR_RENOVATIONS': 'CONTROL', 'ADS_FSBOUncheck': 'CONTROL', 'AndroidSellHomeTab': 'CONTROL_OFF', 'AndroidZOHomeAccessVerification': 'ON', 'SEOTEST__CUSTOM_REGION_FAQ_AZ': 'CONTROL', 'PRE_SEARCH_DISPATCHER_OWNERVIEW_LOGIC_WITH_CLAIMS': 'ON_CLAIMS', 'PPL_PROFILE_REGION': 'ON', 'ADS_SubmitButtonInViewAppAndroid': 'CONTROL_ALIGN_TOP', 'MptHomeVideoVsStaticHeroImage': 'VIDEO_ON', 'HDP_OV_New_Header': 'ON', 'AndroidSRPTest': 'ON', 'iOSNavigationAds': 'ON_NavigationAds', 'SmartBannerBigiOs': 'STICKY_TOP_BANNER', 'AndroidTouringV1Toggle': 'CONTROL_OFF', 'AndroidListingColorBlueToRed': 'ON_NO_BLUE', 'PERF_3RD_PARTY_MON': 'CONTROL', 'TR_CrimePage': 'CONTROL', 'iOSGroupedDisplayAds': 'iOSGroupedDisplayAds_CONTROL_OFF', 'IOS_MEDIA_STREAM_FSBA_DESCRIPTION': 'ON', 'ARCS_STREAMLINED_TOURS': 'T2_Simple_w_Photo', 'ADS_BAL_TALK': 'CONTROL', 'SELContactForms': 'PredictedAudience', 'SHEN_SNP_GET_NOTICE': 'SNP_ON', 'IOS_FLYBARAUTOCOMPLETE': 'ON', 'MTT_SRP_TOP_SLOT_ONSITE_MESSAGING': 'BASELINE_TREATMENT', 'iOSRecentlyViewed': 'ON', 'ACQ_Deeplink_DirectOpen': 'Variant', 'HDP_CONTENT_REGROUP': 'CONTROL', 'ADS_BAL_INVERTED_PRIMARY': 'INVERTED', 'SP_PAID_BUILDER_PAGE': 'CONTROL', 'HDPUpsellBlocks': 'CURRENT_UPSELL', 'RE_RachelSuccessSurvey': 'ON', 'APPS_COSHOPPING_SAVE_FAVORITE': 'COSHOPPING_ON', 'AndroidNYDOS': 'ON_NYDOS', 'ACT_APPLE_DISCONNECT': 'CONTROL_HIDE', 'AndroidListCardUpdates': 'ON_UPDATED_WOW_CARD', 'ZO_Flag_Renew_Check_Questionnaire_Terminations': 'ON', 'SP_OFF_MARKET_PAGE': 'CONTROL', 'IOS_REMOVE_GARAGE_FILTER': 'ON_REMOVED', 'REV_Turn_Off_Billing_Admin_CC_Form': 'OFF', 'OnboardingForIPad': 'CONTROL_OFF', 'SPT_RENDER_ZO_HDP_PAGE': 'CONTROL', 'IOS_ONBOARDING_REPROMPTING': 'ON', 'IOS_VIDEO_STAB': 'CONTROL_OFF', 'AIPERS_RT_RECS_GLOBAL_RELEVANCE_SORT': 'CONTROL', 'AndroidContingentListingsV1': 'ON', 'HDP_ECON_HOMEVALUES': 'CONTROL', 'IOS_ZILLOW_OFFERS_LANDING_PAGE': 'CONTROL_OFF', 'HDP_HIGHER_COMMUTE': 'CONTROL', 'ACC_ADS_DISPLAY_UDS_MIGRATION': 'UDS', 'ARCS_CONTACT_SUBMIT_PREXIT': 'CONTROL', 'HDP_PSL_USER_TEST': 'ON', 'SXP_KINGFISHER_FILTERS': 'P1_PHASE_1', 'MTT_NFSHDP_BOTTOM_SLOT_ONSITE_MESSAGING': 'PORTFOLIO_INTEGRATION_CTRL', 'ACQ_SRP2CTA': 'CONTROL', 'RE_SECOND_BOOST': 'SLOT_4', 'ZO_FSHDP_RTBP_M2': 'CONTROL', 'AndroidMDSMetadataSend': 'CONTROL_MOBILE_DEVICE_SERVICE_OFF', 'IOS_MUTUALLY_EXCLUSIVE_FILTERS': 'ON_3', 'REDIRECT_DISTRICT_DETAILS_PAGE': 'ON', 'IOS_Onboarding_Buying_And_Selling': 'CONTROL_OFF', 'ARCS_ABPD_SEARCH': 'CONTROL', 'HDP_ZESTIMATE_LIST_PRICE': 'V1', 'SE_InstantOffer_Questionnaire': 'CONTROL', 'RE_LeadDistributionApps': 'CONTROL', 'ADAT_FLYBAR_ProReviews': 'CONTROL', 'HDP_ZMA_UPDATED_TERMS': 'ON', 'ADT_PROGRESSIVE_MESSAGE': 'CONTROL', 'IOS_HOME_RECS_PUSH_REG': 'ON', 'AndroidMortgageCustomQuotes': 'ON_WEBVIEW', 'RE_Application_Upsell': 'TEST', 'iOSClaimHomeUpsellV3': 'UPSELL_ON_2B', 'iOSClaimHomeUpsellV4': 'CONTROL_UPSELL_ON_2B', 'SXP_Combined_Filter_Apartments_Condos': 'TEST', 'AndroidHomeTrackerV1': 'ON_TAGS_COMBINED_LIST', 'AndroidVirtualOpenHouse': 'ON_VIRTUAL_OPEN_HOUSE', 'IOS_STREETVIEW': 'ON', 'AR_SHOWCASE_HDP_WIDGET': 'CONTROL', 'AndroidMediaStreamForSalePotential': 'ON_MEDIA_STREAM_FOR_SALE_POTENTIAL', 'ARCS_CE_PSL_MIGRATION': 'FALLBACK_IF_NULL', 'IOS_EXPOSED_FILTERS_2': 'ON', 'AndroidSaveSearchUpsell': 'ON_SHOW_SAVE_SEARCH_UPSELL', 'ADAT_SSTT': 'ON', 'AR_PRE_TOUR_SURVEY': 'CONTROL', 'AR_FIRST_CONNECTION_CSAT': 'VARIANT_1', 'HDP_WOW_LAYOUT_ALL_OTHER_TYPES': 'CONTROL', 'AgentPastSalesPRExit': 'CONTROL_RedirectToHome', 'HDP_SERVICE_HOME_INFO_ON_SEARCH': 'CONTROL', 'SE_InstantOffer_Zestimate': 'CONTROL', 'IOS_ZillowGroupAnalytics_1': 'ON', 'MobileActionBar': 'PRE_APPROVAL', 'ADS_fixed_bal': 'fixed', 'ACQ_MOBILE_UPSELL_DISMISS_KEY': 'APP_UPSELL_DISMISS_080620', 'IOS_Native_HDP_Chip': 'ON', 'SEOTEST__SXP_REACT_FOOTER_DESKTOP': 'ON', 'AR_BUYER_INITIATED_RELATIONSHIP_UI': 'CONTROL', 'OWNER_DASHBOARD': 'ON', 'HDP_DS_MORTGAGE_STICKY': 'ON', 'VL_SaveBuildings': 'TEST', 'HDP_SERVICE_NFS_MOBILE': 'CONTROL', 'PERS_SHARED_FAVORITES_FEATURE': 'FEATURES_ON', 'VL_RENTER_HUB': 'ON', 'RA_IRENE_SEES_ICRAA_DETAILS': 'ON', 'SXP_3DTOUR_MAP_DOT': 'ON', 'iOSNotificationUpsell': 'CONTROL_OFF', 'PA_FLEXIBLE_CTA_WIDGET': 'CONTROL', 'IOS_NYDOS_LIST_CARD': 'ON', 'HDP_Other_Costs_Desktop': 'CONTROL', 'Z360_LPAddressEntry': 'CONTROL', 'MTT_NFSHDP_BOTTOM_SLOT_HOLDOUT': 'ON', 'HDP_ZMA_VOW': 'CONTROL', 'PERF_HDP_SSR': 'ON', 'AndroidRealUserMonitoringDatadog': 'ON_DD_RUM', 'MTT_HOP_HERO_IMAGE_ONSITE_MESSAGING': 'CONTROL', 'AndroidFirebasePerfMonitoring': 'CONTROL_OFF', 'iOS_Whats_New_3D_Homes': 'CONTROL_OFF', 'CDP_MAP_BUBBLE': 'DIRECT_TO_PAGE', 'ANDROID_ONBOARDING_SKIP_PLACEMENT': 'GONE', 'KeystoneEventDwell': 'SEND_EVENT', 'TopNavTest': 'NEW_NAV_WITH_ADVICE'}}, 'ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}': {'property': {'listingDataSource': 'Phoenix', 'zpid': 48760005, 'city': 'Seattle', 'state': 'WA', 'homeStatus': 'FOR_SALE', 'address': {'streetAddress': '766 N 65th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103', 'neighborhood': None, 'community': None, 'subdivision': None}, 'isListingClaimedByCurrentSignedInUser': False, 'isCurrentSignedInAgentResponsible': False, 'bedrooms': 3, 'bathrooms': 3, 'price': 669000, 'yearBuilt': 1906, 'streetAddress': '766 N 65th St', 'zipcode': '98103', 'isCurrentSignedInUserVerifiedOwner': False, 'regionString': 'Seattle WA 98103', 'propertyUpdatePageLink': None, 'moveHomeMapLocationLink': None, 'propertyEventLogLink': None, 'editPropertyHistorylink': None, 'isRentalListingOffMarket': False, 'hdpUrl': '/homedetails/766-N-65th-St-Seattle-WA-98103/48760005_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_FSBO': False, 'is_FSBA': True, 'is_foreclosure': False, 'is_bankOwned': False, 'is_forAuction': False, 'is_comingSoon': False, 'is_pending': False, 'is_openHouse': False}, 'nearbyCities': [{'regionUrl': {'path': '/auburn-wa/'}, 'name': 'Auburn', 'body': None}, {'regionUrl': {'path': '/bellevue-wa/'}, 'name': 'Bellevue', 'body': None}, {'regionUrl': {'path': '/bothell-wa/'}, 'name': 'Bothell', 'body': None}, {'regionUrl': {'path': '/federal-way-wa/'}, 'name': 'Federal Way', 'body': None}, {'regionUrl': {'path': '/kent-wa/'}, 'name': 'Kent', 'body': None}, {'regionUrl': {'path': '/kirkland-wa/'}, 'name': 'Kirkland', 'body': None}, {'regionUrl': {'path': '/redmond-wa/'}, 'name': 'Redmond', 'body': None}, {'regionUrl': {'path': '/renton-wa/'}, 'name': 'Renton', 'body': None}, {'regionUrl': {'path': '/sammamish-wa/'}, 'name': 'Sammamish', 'body': None}, {'regionUrl': {'path': '/seattle-wa/'}, 'name': 'Seattle', 'body': None}], 'nearbyNeighborhoods': [{'regionUrl': {'path': '/beacon-hill-seattle-wa/'}, 'name': 'Beacon Hill', 'body': None}, {'regionUrl': {'path': '/capitol-hill-seattle-wa/'}, 'name': 'Capitol Hill', 'body': None}, {'regionUrl': {'path': '/first-hill-seattle-wa/'}, 'name': 'First Hill', 'body': None}, {'regionUrl': {'path': '/fremont-seattle-wa/'}, 'name': 'Fremont', 'body': None}, {'regionUrl': {'path': '/greenwood-seattle-wa/'}, 'name': 'Greenwood', 'body': None}, {'regionUrl': {'path': '/magnolia-seattle-wa/'}, 'name': 'Magnolia', 'body': None}, {'regionUrl': {'path': '/north-beacon-hill-seattle-wa/'}, 'name': 'North Beacon Hill', 'body': None}, {'regionUrl': {'path': '/ravenna-seattle-wa/'}, 'name': 'Ravenna', 'body': None}, {'regionUrl': {'path': '/university-district-seattle-wa/'}, 'name': 'University District', 'body': None}, {'regionUrl': {'path': '/wallingford-seattle-wa/'}, 'name': 'Wallingford', 'body': None}], 'country': 'USA', 'nearbyZipcodes': [{'regionUrl': {'path': '/seattle-wa-98103/'}, 'name': '98103', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98105/'}, 'name': '98105', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98109/'}, 'name': '98109', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98115/'}, 'name': '98115', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98117/'}, 'name': '98117', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98118/'}, 'name': '98118', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98122/'}, 'name': '98122', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98125/'}, 'name': '98125', 'body': None}, {'regionUrl': {'path': '/shoreline-wa-98133/'}, 'name': '98133', 'body': None}, {'regionUrl': {'path': '/seattle-wa-98144/'}, 'name': '98144', 'body': None}], 'citySearchUrl': {'text': 'Homes in Seattle', 'path': '/seattle-wa/'}, 'zipcodeSearchUrl': {'path': '/seattle-wa-98103/'}, 'apartmentsForRentInZipcodeSearchUrl': {'path': '/seattle-wa-98103/apartments/'}, 'housesForRentInZipcodeSearchUrl': {'path': '/seattle-wa-98103/rent-houses/'}, 'abbreviatedAddress': '766 N 65th St', 'neighborhoodRegion': {'name': 'Phinney Ridge'}, 'building': None, 'isUndisclosedAddress': False, 'boroughId': None, 'providerListingID': None, 'neighborhoodSearchUrl': {'path': '/phinney-ridge-seattle-wa/'}, 'stateSearchUrl': {'path': '/wa/'}, 'boroughSearchUrl': None, 'communityUrl': None, 'isPremierBuilder': False, 'isZillowOwned': False, 'homeType': 'SINGLE_FAMILY', 'adTargets': {'aamgnrc1': '766 N 65th St', 'bd': '3', 'fsbid': '39', 'city': 'Seattle', 'proptp': 'sfh', 'pid': '48760005', 'lot': '1', 'zestibuck': '600-699k', 'listtp': 'buy_agent', 'sqftrange': '2000-2499', 'price': '669000', 'sqft': '2410', 'state': 'WA', 'mlong': '-122.348564', 'cnty': 'King', 'prange': '600-699k', 'zip': '98103', 'mlat': '47.676277', 'zusr': 'true', 'price_band': 'z600', 'yrblt': '1900-1919', 'zestimate': '669000', 'premieragent': 'no', 'dma': '206', 'guid': '4b52ea55-dbc0-41da-90aa-33f525a68310', 'ssid': '39'}, 'currency': 'USD', 'resoFacts': {'accessibilityFeatures': None, 'associationFee': None, 'associationAmenities': None, 'associationFee2': None, 'associationFeeIncludes': None, 'associationName': None, 'associationName2': None, 'associationPhone': None, 'associationPhone2': None, 'basementYN': False, 'buildingName': 'Cravens Div Of Greenlake Add Less Street Plat', 'buyerAgencyCompensation': '3', 'buyerAgencyCompensationType': '%', 'appliances': ['Washer', 'Water Heater: Natural Gas', 'Water Heater Location: Basement'], 'atAGlanceFacts': [{'factLabel': 'Type', 'factValue': 'Single Family Residence'}, {'factLabel': 'Year Built', 'factValue': '1906'}, {'factLabel': 'Heating', 'factValue': 'Forced Air, 90%+ High Efficiency, Wall'}, {'factLabel': 'Cooling', 'factValue': '90%+ High Efficiency, Forced Air, Wall'}, {'factLabel': 'Parking', 'factValue': '2 Attached Garage spaces'}, {'factLabel': 'Lot', 'factValue': '2,818 sqft'}, {'factLabel': 'Days on Zillow', 'factValue': '5 Days'}, {'factLabel': 'Price/sqft', 'factValue': '$278'}, {'factLabel': "Buyer's Agent Fee", 'factValue': '3'}, {'factLabel': 'Offer Review Date', 'factValue': '2022-02-01'}], 'attic': None, 'availabilityDate': None, 'basement': 'Bath/Stubbed', 'bathrooms': 3, 'bathroomsFull': 1, 'bathroomsHalf': 1, 'bathroomsOneQuarter': None, 'bathroomsPartial': None, 'bathroomsThreeQuarter': 1, 'bedrooms': 3, 'bodyType': None, 'canRaiseHorses': False, 'carportParkingCapacity': None, 'cityRegion': 'Seattle', 'commonWalls': None, 'communityFeatures': None, 'cooling': ['90%+ High Efficiency', 'Forced Air', 'Wall'], 'coveredParkingCapacity': 2, 'cropsIncludedYN': None, 'developmentStatus': None, 'doorFeatures': None, 'electric': ['Company: Seattle City Light'], 'elevation': None, 'elevationUnits': 'Feet', 'entryLevel': None, 'entryLocation': 'Main', 'exclusions': None, 'fencing': None, 'fireplaceFeatures': None, 'fireplaces': None, 'flooring': ['Softwood', 'See Remarks', 'Vinyl', 'Vinyl Plank', 'Carpet', 'Fir/Softwood', 'Wall to Wall Carpet'], 'foundationArea': None, 'furnished': False, 'garageParkingCapacity': None, 'gas': None, 'greenBuildingVerificationType': None, 'greenEnergyEfficient': None, 'greenIndoorAirQuality': None, 'greenSustainability': None, 'greenWaterConservation': None, 'hasAssociation': None, 'hasAttachedGarage': True, 'hasAttachedProperty': False, 'hasCooling': True, 'hasCarport': False, 'hasElectricOnProperty': False, 'hasFireplace': False, 'hasGarage': False, 'hasHeating': True, 'hasLandLease': False, 'hasOpenParking': False, 'hasSpa': False, 'hasPrivatePool': None, 'hasView': True, 'hasWaterfrontView': None, 'heating': ['Forced Air', '90%+ High Efficiency', 'Wall'], 'highSchool': 'Buyer To Verify', 'highSchoolDistrict': 'Seattle', 'hoaFee': None, 'homeType': 'SingleFamily', 'horseAmenities': None, 'horseYN': None, 'interiorFeatures': ['Bath Off Primary', 'Dining Room'], 'irrigationWaterRightsAcres': None, 'irrigationWaterRightsYN': False, 'isSeniorCommunity': None, 'landLeaseAmount': None, 'landLeaseExpirationDate': None, 'laundryFeatures': None, 'levels': 'Two', 'listingId': None, 'lotFeatures': ['Curbs', 'Paved', 'Sidewalk', 'Rooftop Deck', 'RV Parking'], 'lotSize': '2,818 sqft', 'mainLevelBathrooms': None, 'mainLevelBedrooms': 0, 'marketingType': None, 'middleOrJuniorSchool': 'Buyer To Verify', 'middleOrJuniorSchoolDistrict': None, 'municipality': None, 'numberOfUnitsInCommunity': None, 'offerReviewDate': '2022-02-01', 'onMarketDate': 1643241600000, 'openParkingCapacity': None, 'otherEquipment': None, 'otherFacts': [], 'otherParking': None, 'ownershipType': None, 'parkingCapacity': 2, 'parkingFeatures': ['RV Parking', 'Driveway', 'Attached Garage', 'Off Street'], 'patioAndPorchFeatures': None, 'poolFeatures': None, 'pricePerSquareFoot': 278, 'roadSurfaceType': None, 'roofType': 'Built-Up,Composition,Torch Down', 'rooms': [{'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Lower', 'roomType': 'UtilityRoom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Main', 'roomType': 'LivingRoom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Main', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Main', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Main', 'roomType': 'DiningRoom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': 'BonusRoom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': 'Bedroom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': 'Bedroom', 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Main', 'roomType': None, 'width': None}, {'area': None, 'description': None, 'dimensions': None, 'level': None, 'features': None, 'roomArea': None, 'roomAreaSource': None, 'roomAreaUnits': None, 'roomDescription': None, 'roomDimensions': None, 'roomFeatures': None, 'roomLength': None, 'roomLengthWidthSource': None, 'roomLengthWidthUnits': None, 'roomLevel': 'Upper', 'roomType': None, 'width': None}], 'securityFeatures': None, 'sewer': ['Sewer Connected', 'Company: City of Seattle'], 'spaFeatures': None, 'specialListingConditions': 'Standard', 'stories': None, 'storiesTotal': None, 'subdivisionName': 'Green Lake', 'taxAnnualAmount': 5980, 'totalActualRent': None, 'utilities': ['Sewer Connected', 'Electricity Available', 'Natural Gas Connected', 'Buyer To Verify', 'Buyer To Verify'], 'view': ['City', 'Lake', 'Mountain(s)', 'Partial', 'See Remarks', 'Territorial'], 'waterSource': ['Public', 'Company: City of Seattle'], 'waterBodyName': None, 'waterfrontFeatures': None, 'waterView': 'Lake', 'waterViewYN': True, 'windowFeatures': ['Double Pane/Storm Window'], 'yearBuilt': 1906, 'zoning': None, 'zoningDescription': 'SF 5000,Jurisdiction: City', 'aboveGradeFinishedArea': None, 'additionalParcelsDescription': None, 'architecturalStyle': 'Craftsman', 'belowGradeFinishedArea': None, 'builderModel': None, 'builderName': None, 'buildingArea': '2,410', 'buildingAreaSource': None, 'buildingFeatures': None, 'constructionMaterials': ['Cement/Concrete', 'Wood Siding'], 'exteriorFeatures': [], 'foundationDetails': ['Poured Concrete', 'Slab'], 'frontageLength': None, 'frontageType': None, 'hasAdditionalParcels': False, 'hasPetsAllowed': False, 'hasRentControl': None, 'hasHomeWarranty': False, 'inclusions': ['Washer'], 'incomeIncludes': None, 'isNewConstruction': None, 'listingTerms': 'Cash Out,See Remarks', 'livingAreaRange': None, 'livingAreaRangeUnits': None, 'livingArea': '2,410 sqft', 'lotSizeDimensions': '30 x 98', 'numberOfUnitsVacant': None, 'otherStructures': None, 'ownership': None, 'parcelNumber': '1814801640', 'propertyCondition': 'Fixer', 'propertySubType': ['Single Family Residence'], 'structureType': 'House', 'topography': 'Level', 'vegetation': ['Brush'], 'woodedArea': None, 'yearBuiltEffective': 2002, 'virtualTour': None, 'elementarySchool': 'Buyer To Verify', 'elementarySchoolDistrict': None, 'listAOR': None}, 'attributionInfo': {'listingAgreement': None, 'mlsId': '1878274', 'mlsName': 'NWMLS', 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_95_35.jpg', 'agentName': 'Chris Thorndike-Kent', 'agentPhoneNumber': '360-671-5000', 'brokerName': 'Windermere Real Estate Whatcom', 'brokerPhoneNumber': '360-671-5000', 'trueStatus': 'Active', 'infoString1': '1878274', 'infoString2': 'NWMLS', 'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_95_35.jpg', 'infoString4': 'Chris Thorndike-Kent', 'infoString5': '360-671-5000', 'infoString6': 'Windermere Real Estate Whatcom', 'infoString7': '360-671-5000', 'infoString10': 'Listing information is provided by the Northwest Multiple Listing Service (NWMLS). Property information is based on available data that may include MLS information, county records, and other sources. Listings marked with this symbol: provided by Northwest Multiple Listing Service, 2021. All information provided is deemed reliable but is not guaranteed and should be independently verified. All properties are subject to prior sale or withdrawal. © 2021 NWMLS. All rights are reserved. Disclaimer: The information contained in this listing has not been verified by Zillow, Inc. and should be verified by the buyer. Some IDX listings have been excluded from this website. [Click here for more information](/info/mls-disclaimers/#mls_39)', 'infoString11': '2022-01-29 16:37:09', 'infoString12': '2022-01-29 16:37:09', 'infoString13': None, 'infoString14': None, 'infoString15': None, 'infoString16': None, 'infoString17': None, 'infoString18': None, 'infoString19': None, 'infoString20': None, 'mlsDisclaimer': 'Listing information is provided by the Northwest Multiple Listing Service (NWMLS). Property information is based on available data that may include MLS information, county records, and other sources. Listings marked with this symbol: provided by Northwest Multiple Listing Service, 2021. All information provided is deemed reliable but is not guaranteed and should be independently verified. All properties are subject to prior sale or withdrawal. © 2021 NWMLS. All rights are reserved. Disclaimer: The information contained in this listing has not been verified by Zillow, Inc. and should be verified by the buyer. Some IDX listings have been excluded from this website. [Click here for more information](/info/mls-disclaimers/#mls_39)', 'lastChecked': '2022-01-29 16:37:09', 'lastUpdated': '2022-01-29 16:37:09', 'coAgentName': None, 'coAgentNumber': None, 'coAgentLicenseNumber': None, 'agentEmail': None, 'agentLicenseNumber': None, 'buyerAgentName': None, 'buyerAgentMemberStateLicense': None, 'buyerBrokerageName': None, 'infoList1': [{'infoField1': 'listOffice', 'infoField2': 'Windermere Real Estate Whatcom'}], 'infoList2': [{'infoField1': 'Chris Thorndike-Kent', 'infoField2': 'listAgent', 'infoField3': '9201'}], 'listingOffices': [{'associatedOfficeType': 'listOffice', 'officeName': 'Windermere Real Estate Whatcom'}], 'listingAgents': [{'memberFullName': 'Chris Thorndike-Kent', 'associatedAgentType': 'listAgent', 'memberStateLicense': '9201'}], 'attributionTitle': None, 'infoString9': 'Active'}, 'listPriceLow': None, 'solarPotential': {'sunScore': 59.58, 'buildFactor': 49.6, 'climateFactor': 5.82, 'electricityFactor': 1.83, 'solarFactor': 2.32}, 'homeRecommendations': {'blendedRecs': [], 'displayShort': ''}, 'livingArea': 2410, 'livingAreaValue': 2410, 'zestimate': 669000, 'newConstructionType': None, 'zestimateLowPercent': '5', 'zestimateHighPercent': '5', 'rentZestimate': 3134, 'restimateLowPercent': '13', 'restimateHighPercent': '13', 'hideZMA': False, 'zestimateDeepDiveData': {'zmaModel': {'approveDate': None}}, 'listingMetadata': {'passwordRequiredForZestimateMarketAnalysis': False, 'FlexibleLayoutQ': False, 'FlexibleLayoutR': False, 'FlexibleLayoutS': False, 'FlexibleLayoutT': False, 'FlexibleLayoutW': False, 'FlexibleLayoutX': False, 'FlexibleLayoutZ': False, 'mustDisplayAttributionListAgentEmail': False, 'mustDisplayAttributionListAgentPhone': False, 'mustDisplayAttributionListingOfficePhone': False, 'mustHighlightAgentName': None, 'mustHighlightListOfficeName': False, 'mustMakeListingAgentContactable': False, 'mustAttributeOfficeNameBeforeAgentName': False, 'isAdsRestricted': False, 'FlexibleLayoutAB': True, 'FlexibleLayoutB': True, 'FlexibleLayoutC': True, 'FlexibleLayoutD': True, 'FlexibleLayoutE': True, 'FlexibleLayoutF': False, 'FlexibleLayoutG': False, 'FlexibleLayoutH': False, 'FlexibleLayoutI': True, 'FlexibleLayoutJ': False, 'FlexibleLayoutK': False, 'FlexibleLayoutL': False, 'FlexibleLayoutM': True, 'FlexibleLayoutN': True, 'FlexibleLayoutO': True, 'FlexibleLayoutP': True, 'FlexibleLayoutU': False, 'FlexibleLayoutV': True, 'FlexibleLayoutY': False, 'FlexibleLayoutAA': True, 'canShowAutomatedValuationDisplay': True, 'canShowTaxHistory': True, 'canShowPriceHistory': True, 'canShowUserGeneratedContent': True, 'hidePriceAdjustmentFlexField': False, 'canCommingleComparables': False, 'canShowComparables': True, 'isSuperTrafficOptimized': False, 'mustDisplayDisclaimerBelowAttribution': False, 'mustDisplayFeedLogoInContactBox': False, 'canShowCroppedPhotos': True, 'canShowNonIDXMedia': True, 'canShowOnMap': True, 'comminglingCategory': True, 'mustHighlightMlsId': None, 'mustHighlightMlsStatus': True, 'mustHighlightMarketingType': False, 'canShowZillowLogoInHeader': True, 'canShowPrequalifiedLinkInChip': True, 'comminglingCategoryIsRulesApplicable': True}, 'contingentListingType': None, 'dateSoldString': '1985-10-28', 'lastSoldPrice': 61000, 'livingAreaUnitsShort': 'sqft', 'lotAreaValue': 2818.332, 'lotAreaUnits': 'Square Feet', 'lotSize': 2818, 'photos': [{'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1536.webp', 'width': 1536}]}, 'caption': ''}], 'schools': [{'distance': 1.3, 'name': 'Licton Springs K-8', 'rating': 5, 'level': 'Primary', 'studentsPerTeacher': 9, 'assigned': None, 'grades': 'PK-8', 'link': 'https://www.greatschools.org/school?id=03277&state=WA', 'type': 'Public', 'size': 174, 'totalCount': 2, 'isAssigned': True}, {'distance': 3.2, 'name': 'Ingraham High School', 'rating': 7, 'level': 'High', 'studentsPerTeacher': 20, 'assigned': None, 'grades': '9-12', 'link': 'https://www.greatschools.org/school?id=01571&state=WA', 'type': 'Public', 'size': 1397, 'totalCount': 1, 'isAssigned': True}], 'homeValues': None, 'parentRegion': {'name': 'Phinney Ridge'}, 'nearbyHomes': [{'zpid': 48760004, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/b164b6350c868db9969971ad3cf77eab-p_c.jpg'}], 'price': 645000, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 1, 'livingArea': 0, 'livingAreaValue': 0, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 4926, 'lotAreaValue': 4926.636, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '762 N 65th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '762 N 65th St'}, {'fullValue': None}]}, 'latitude': 47.676277, 'longitude': -122.34872, 'homeStatus': 'SOLD', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/762-N-65th-St-Seattle-WA-98103/48760004_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1679636', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48760002, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/a69220b7aaa3f640ab596ae4acf1894f-p_c.jpg'}], 'price': 1120049, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 3, 'livingArea': 2360, 'livingAreaValue': 2360, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3990, 'lotAreaValue': 3990.096, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '718 N 65th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '718 N 65th St'}, {'fullValue': None}]}, 'latitude': 47.676277, 'longitude': -122.349075, 'homeStatus': 'SOLD', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/718-N-65th-St-Seattle-WA-98103/48760002_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1630783', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48759991, 'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=316x234&zoom=17&center=47.6766242980957,-122.34855651855469&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&&signature=Fc4Mfh0pEqyUDV-85dBUxCyrbkY='}], 'price': 904000, 'currency': 'USD', 'bedrooms': 2, 'bathrooms': 2, 'livingArea': 1460, 'livingAreaValue': 1460, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3720, 'lotAreaValue': 3720.024, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '733 N 66th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '733 N 66th St'}, {'fullValue': None}]}, 'latitude': 47.676624, 'longitude': -122.34856, 'homeStatus': 'OTHER', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/733-N-66th-St-Seattle-WA-98103/48759991_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '82271', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48759990, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/46e2babf195f2404f1de7b27baa09582-p_c.jpg'}], 'price': 1245000, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 3, 'livingArea': 2160, 'livingAreaValue': 2160, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3645, 'lotAreaValue': 3645.972, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '737 N 66th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '737 N 66th St'}, {'fullValue': None}]}, 'latitude': 47.676624, 'longitude': -122.34844, 'homeStatus': 'RECENTLY_SOLD', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/737-N-66th-St-Seattle-WA-98103/48759990_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1812897', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 49140155, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/8336ea6c9e80859479f160a86f44ce75-p_c.jpg'}], 'price': 1509300, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 3, 'livingArea': 2850, 'livingAreaValue': 2850, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 5000, 'lotAreaValue': 5000.688, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '6417 Linden Ave N', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '6417 Linden Ave N'}, {'fullValue': None}]}, 'latitude': 47.675915, 'longitude': -122.34863, 'homeStatus': 'OTHER', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/6417-Linden-Ave-N-Seattle-WA-98103/49140155_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1374046', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 247769229, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/4eb8c3f5adcd2f50f2db427e9a2cc374-p_c.jpg'}], 'price': 1918900, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 4, 'livingArea': 2960, 'livingAreaValue': 2960, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3752, 'lotAreaValue': 3752, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '739 N 66th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '739 N 66th St'}, {'fullValue': None}]}, 'latitude': 47.676624, 'longitude': -122.34832, 'homeStatus': 'OTHER', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/739-N-66th-St-Seattle-WA-98103/247769229_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1101006', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48759989, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/11f409a1e5b9ccf52a74e14144180a48-p_c.jpg'}], 'price': 1951500, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 4, 'livingArea': 2960, 'livingAreaValue': 2960, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3752, 'lotAreaValue': 3752, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '741 N 66th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '741 N 66th St'}, {'fullValue': None}]}, 'latitude': 47.676624, 'longitude': -122.3482, 'homeStatus': 'OTHER', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/741-N-66th-St-Seattle-WA-98103/48759989_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1113688', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 82362084, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/81dddda2a04e1bc6ba28676f36ad2f7b-p_c.jpg'}], 'price': 1508700, 'currency': 'USD', 'bedrooms': 5, 'bathrooms': 4, 'livingArea': 2630, 'livingAreaValue': 2630, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3750, 'lotAreaValue': 3750.516, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '743 N 66th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '743 N 66th St'}, {'fullValue': None}]}, 'latitude': 47.67662, 'longitude': -122.348076, 'homeStatus': 'OTHER', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/743-N-66th-St-Seattle-WA-98103/82362084_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '27124715', 'mlsName': None, 'providerLogo': None, 'agentName': None, 'agentPhoneNumber': None, 'brokerName': None, 'brokerPhoneNumber': None, 'trueStatus': None}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}], 'countyFIPS': '53033', 'parcelId': '1814801640', 'taxHistory': [{'time': 1580611969353, 'taxPaid': 5980.4, 'taxIncreaseRate': -0.027373232, 'value': 606000, 'valueIncreaseRate': -0.04113924}, {'time': 1549075969353, 'taxPaid': 6148.71, 'taxIncreaseRate': 0.05092855, 'value': 632000, 'valueIncreaseRate': -0.058122206}, {'time': 1517539969353, 'taxPaid': 5850.74, 'taxIncreaseRate': -0.02331885, 'value': 671000, 'valueIncreaseRate': 0.122073576}, {'time': 1486003969353, 'taxPaid': 5990.43, 'taxIncreaseRate': 0.377804, 'value': 598000, 'valueIncreaseRate': 0.124060154}, {'time': 1454381569353, 'taxPaid': 4347.81, 'taxIncreaseRate': 0, 'value': 532000, 'valueIncreaseRate': 0.08350305}, {'time': 1422845569353, 'taxPaid': 4347.81, 'taxIncreaseRate': 0, 'value': 491000, 'valueIncreaseRate': 0.10089686}, {'time': 1391309569353, 'taxPaid': 4347.81, 'taxIncreaseRate': 0, 'value': 446000, 'valueIncreaseRate': 0.1377551}, {'time': 1359773569353, 'taxPaid': 4347.81, 'taxIncreaseRate': 0, 'value': 392000, 'valueIncreaseRate': 0.031578947}, {'time': 1328151169353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 380000, 'valueIncreaseRate': 0}, {'time': 1296615169353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 380000, 'valueIncreaseRate': 0.013333334}, {'time': 1265079169353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 375000, 'valueIncreaseRate': 0}, {'time': 1233543169353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 375000, 'valueIncreaseRate': 0.041666668}, {'time': 1170384769353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 360000, 'valueIncreaseRate': 0.061946902}, {'time': 1138848769353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 339000, 'valueIncreaseRate': 0.06940063}, {'time': 1107312769353, 'taxPaid': None, 'taxIncreaseRate': 0, 'value': 317000, 'valueIncreaseRate': 0.4744186}, {'time': 981082369353, 'taxPaid': 2566.37, 'taxIncreaseRate': 0.0959104, 'value': 215000, 'valueIncreaseRate': 0.15591398}, {'time': 949459969353, 'taxPaid': 2341.77, 'taxIncreaseRate': 0, 'value': 186000, 'valueIncreaseRate': 0}], 'priceHistory': [{'date': '2022-01-27', 'time': 1643241600000, 'price': 669000, 'pricePerSquareFoot': 278, 'priceChangeRate': 9.967213114754099, 'event': 'Listed for sale', 'source': 'NWMLS', 'buyerAgent': None, 'sellerAgent': None, 'showCountyLink': False, 'postingIsRental': False, 'attributeSource': {'infoString1': '1878274', 'infoString2': 'NWMLS', 'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg'}}, {'date': '1985-10-28', 'time': 499305600000, 'price': 61000, 'pricePerSquareFoot': 25, 'priceChangeRate': 0, 'event': 'Sold', 'source': 'Agent Provided', 'buyerAgent': None, 'sellerAgent': None, 'showCountyLink': False, 'postingIsRental': False, 'attributeSource': {'infoString1': None, 'infoString2': None, 'infoString3': None}}], 'comps': [{'zpid': 49140273, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/97bbf8bc762c1506721a82da09484d08-p_c.jpg'}], 'price': 749000, 'currency': 'USD', 'bedrooms': 2, 'bathrooms': 1, 'livingArea': 1400, 'livingAreaValue': 1400, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 3550, 'lotAreaValue': 3550.14, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '6211 Woodland Pl N', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '6211 Woodland Pl N'}, {'fullValue': 'Seattle, WA 98103'}]}, 'latitude': 47.67429, 'longitude': -122.34795, 'homeStatus': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/6211-Woodland-Pl-N-Seattle-WA-98103/49140273_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1883089', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'George L Beasley', 'agentPhoneNumber': '206-538-0730', 'brokerName': None, 'brokerPhoneNumber': '206-538-0730', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 49102255, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/2165bbcdabbe471dad618a234741927e-p_c.jpg'}], 'price': 699000, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 3, 'livingArea': 1320, 'livingAreaValue': 1320, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 1359, 'lotAreaValue': 1359.072, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '4515 8th Ave NE UNIT B', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98105'}, 'formattedChip': {'location': [{'fullValue': '4515 8th Ave NE UNIT B'}, {'fullValue': 'Seattle, WA 98105'}]}, 'latitude': 47.661865, 'longitude': -122.319786, 'homeStatus': 'PENDING', 'homeType': 'TOWNHOUSE', 'hdpUrl': '/homedetails/4515-8th-Ave-NE-UNIT-B-Seattle-WA-98105/49102255_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882249', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Robin Sheridan', 'agentPhoneNumber': '206-330-0314', 'brokerName': None, 'brokerPhoneNumber': '206-330-0314', 'trueStatus': 'Pending'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48853596, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/bff5d7d2d15a3647cc0e3c73a6ef49e0-p_c.jpg'}], 'price': 759995, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 2, 'livingArea': 1390, 'livingAreaValue': 1390, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 2243, 'lotAreaValue': 2243.34, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '10209 8th Ave NE', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98125'}, 'formattedChip': {'location': [{'fullValue': '10209 8th Ave NE'}, {'fullValue': 'Seattle, WA 98125'}]}, 'latitude': 47.702534, 'longitude': -122.32074, 'homeStatus': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/10209-8th-Ave-NE-Seattle-WA-98125/48853596_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1877000', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Sarah Rollinger', 'agentPhoneNumber': '206-258-6097', 'brokerName': None, 'brokerPhoneNumber': '206-258-6097', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 49025564, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/9706dfc0dccf1fc507b4a0a12d26d612-p_c.jpg'}], 'price': 675000, 'currency': 'USD', 'bedrooms': 4, 'bathrooms': 1, 'livingArea': 2270, 'livingAreaValue': 2270, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 4390, 'lotAreaValue': 4390.848, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '2302 E Pike St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98122'}, 'formattedChip': {'location': [{'fullValue': '2302 E Pike St'}, {'fullValue': 'Seattle, WA 98122'}]}, 'latitude': 47.61432, 'longitude': -122.302376, 'homeStatus': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/2302-E-Pike-St-Seattle-WA-98122/49025564_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1880609', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Carmen Gayton', 'agentPhoneNumber': '206-448-6000', 'brokerName': None, 'brokerPhoneNumber': '206-448-6000', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 2066595189, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/e2635c6da7e9fdc2cc1a09af22467943-p_c.jpg'}], 'price': 989950, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 4, 'livingArea': 1806, 'livingAreaValue': 1806, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 1964, 'lotAreaValue': 1964.556, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '804 N 46th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98103'}, 'formattedChip': {'location': [{'fullValue': '804 N 46th St'}, {'fullValue': 'Seattle, WA 98103'}]}, 'latitude': 47.66217, 'longitude': -122.348526, 'homeStatus': 'FOR_SALE', 'homeType': 'TOWNHOUSE', 'hdpUrl': '/homedetails/804-N-46th-St-Seattle-WA-98103/2066595189_zpid/', 'listing_sub_type': {'is_newHome': True, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': False}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1884031', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Tom J. Skepetaris', 'agentPhoneNumber': '206-633-3900', 'brokerName': None, 'brokerPhoneNumber': '206-633-3900', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 49083667, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d744cd45ba5f95a4ccc92a227c30757e-p_c.jpg'}], 'price': 685000, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 2, 'livingArea': 1580, 'livingAreaValue': 1580, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 5087, 'lotAreaValue': 5087.808, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '7152 29th Ave SW', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98126'}, 'formattedChip': {'location': [{'fullValue': '7152 29th Ave SW'}, {'fullValue': 'Seattle, WA 98126'}]}, 'latitude': 47.537655, 'longitude': -122.36949, 'homeStatus': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/7152-29th-Ave-SW-Seattle-WA-98126/49083667_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882938', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Roy Powell Jr', 'agentPhoneNumber': '206-283-5200', 'brokerName': None, 'brokerPhoneNumber': '206-283-5200', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48657834, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/74d36ab86143748cf25ed8c14c826b43-p_c.jpg'}], 'price': 650000, 'currency': 'USD', 'bedrooms': 2, 'bathrooms': 2, 'livingArea': 1207, 'livingAreaValue': 1207, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 36960, 'lotAreaValue': 0.8485, 'lotAreaUnits': 'Acres', 'address': {'streetAddress': '1000 Aurora Ave N APT N210', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98109'}, 'formattedChip': {'location': [{'fullValue': '1000 Aurora Ave N APT N210'}, {'fullValue': 'Seattle, WA 98109'}]}, 'latitude': 47.6278, 'longitude': -122.343155, 'homeStatus': 'FOR_SALE', 'homeType': 'CONDO', 'hdpUrl': '/homedetails/1000-Aurora-Ave-N-APT-N210-Seattle-WA-98109/48657834_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882099', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Natalie English', 'agentPhoneNumber': '206-935-7200', 'brokerName': None, 'brokerPhoneNumber': '206-935-7200', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48697800, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/8aa0c24f3a18b51da000d8e82aad6584-p_c.jpg'}], 'price': 625000, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 1, 'livingArea': 1280, 'livingAreaValue': 1280, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 2874, 'lotAreaValue': 2874.96, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '4420 38th Ave SW', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98126'}, 'formattedChip': {'location': [{'fullValue': '4420 38th Ave SW'}, {'fullValue': 'Seattle, WA 98126'}]}, 'latitude': 47.564014, 'longitude': -122.37969, 'homeStatus': 'PENDING', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/4420-38th-Ave-SW-Seattle-WA-98126/48697800_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882415', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Margaret C. Nordahl', 'agentPhoneNumber': '206-935-7200', 'brokerName': None, 'brokerPhoneNumber': '206-935-7200', 'trueStatus': 'Pending'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 48666583, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/21df187f90c867ce7bd753b0c6e989c9-p_c.jpg'}], 'price': 699950, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 2, 'livingArea': 1860, 'livingAreaValue': 1860, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 15842, 'lotAreaValue': 0.3637, 'lotAreaUnits': 'Acres', 'address': {'streetAddress': '5006 S Ryan Way', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98178'}, 'formattedChip': {'location': [{'fullValue': '5006 S Ryan Way'}, {'fullValue': 'Seattle, WA 98178'}]}, 'latitude': 47.509842, 'longitude': -122.27107, 'homeStatus': 'PENDING', 'homeType': 'SINGLE_FAMILY', 'hdpUrl': '/homedetails/5006-S-Ryan-Way-Seattle-WA-98178/48666583_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882463', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'Brooke Ashley', 'agentPhoneNumber': '888-302-5550', 'brokerName': None, 'brokerPhoneNumber': '888-302-5550', 'trueStatus': 'Pending'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}, {'zpid': 2112249609, 'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/79d50e113010268ae464c6b7e4a9c6e3-p_c.jpg'}], 'price': 849950, 'currency': 'USD', 'bedrooms': 3, 'bathrooms': 3, 'livingArea': 1227, 'livingAreaValue': 1227, 'livingAreaUnits': 'Square Feet', 'livingAreaUnitsShort': 'sqft', 'lotSize': 1, 'lotAreaValue': 1, 'lotAreaUnits': 'Square Feet', 'address': {'streetAddress': '2005 NW 58th St', 'city': 'Seattle', 'state': 'WA', 'zipcode': '98107'}, 'formattedChip': {'location': [{'fullValue': '2005 NW 58th St'}, {'fullValue': 'Seattle, WA 98107'}]}, 'latitude': 47.670544, 'longitude': -122.38242, 'homeStatus': 'FOR_SALE', 'homeType': 'TOWNHOUSE', 'hdpUrl': '/homedetails/2005-NW-58th-St-Seattle-WA-98107/2112249609_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_forAuction': False, 'is_bankOwned': False, 'is_foreclosure': False, 'is_FSBO': False, 'is_comingSoon': False, 'is_FSBA': True}, 'providerListingID': None, 'attributionInfo': {'mlsId': '1882782', 'mlsName': None, 'providerLogo': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_48_23.jpg', 'agentName': 'David Sabban', 'agentPhoneNumber': '206-538-5505', 'brokerName': None, 'brokerPhoneNumber': '206-538-5505', 'trueStatus': 'Active'}, 'isPremierBuilder': False, 'state': 'WA', 'isZillowOwned': False, 'newConstructionType': None}], 'description': "Greenlake/Phinney Ridge fixer house, just a quick stroll to Greenlake via convenient underpass! Finish what the previous owner started & you'll be enjoying lake & mountain views from the rooftop deck by this summer! This 1906 Craftsman two-story currently has entry, kitchen, living, 1/2 bath & formal dining room on main; 4 rooms inc. master w/ensuite bath & 3/4 hall bath upstairs; oversized two-car garage off paved alley w/storage loft, plus basement area. 2002-era updates incl: wiring, plumbing, dual-pane windows, cedar siding, roof w/deck. Original wood floors & curved staircase. Upgraded high-efficiency gas furnace/water heater. Bring your interior updating/decorating ideas; exterior heritage color scheme & your general contractor!", 'whatILove': None, 'timeOnZillow': '5 days', 'pageViewCount': 10539, 'favoriteCount': 280, 'daysOnZillow': 5, 'latitude': 47.676277, 'longitude': -122.348564, 'openHouseSchedule': [], 'desktopWebHdpImageLink': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-p_h.jpg', 'brokerageName': 'Windermere Real Estate Whatcom', 'timeZone': 'America/Los_Angeles', 'pals': [], 'hasBadGeocode': False, 'streetViewMetadataUrlMediaWallLatLong': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=47.676277,-122.348564&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&signature=8I1mrKROCuv6C3X5oXxs7SO3lG8=', 'streetViewMetadataUrlMediaWallAddress': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=766%20N%2065th%20St%2C%20Seattle%2C%20WA%2098103&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&signature=XAgk1jkZQ9cIgvyc-bbALIWgihQ=', 'streetViewTileImageUrlMediumLatLong': 'https://maps.googleapis.com/maps/api/streetview?location=47.676277,-122.348564&size=400x250&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&signature=H0TnX_WtIdCjyHCR3F2At6x9C0Y=', 'streetViewTileImageUrlMediumAddress': 'https://maps.googleapis.com/maps/api/streetview?location=766%20N%2065th%20St%2C%20Seattle%2C%20WA%2098103&size=400x250&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&signature=1-NarLcnGQBLY7gOZM1nx0KthvM=', 'streetViewServiceUrl': 'https://proxy.zillowapi.com/street-view-url?zpid=48760005&address=766%20N%2065th%20St%2C%20Seattle%2C%20WA%2098103&width=512&height=234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&maxdistance=79&lat=47.676277&lon=-122.348564&signature=_3num_E-ZIaldukSv5h3rH7ifII=', 'staticMap': {'sources': [{'width': 192, 'url': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=15&size=192x144&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&signature=GTqkIaa8_-eM82mTiezInvNB9S0='}, {'width': 384, 'url': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=16&size=384x288&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&signature=-CkNgCcW56lYznAaGE6lqC2mzps='}, {'width': 768, 'url': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=17&size=768x576&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&signature=DleQALHnPAKnojjR0KZI3qVLfrw='}]}, 'homeInsights': [{'insights': [{'modelId': 'v1-1', 'treatmentId': 'model_0', 'phrases': ['Mountain views', 'Original wood floors', 'Oversized two-car garage']}, {'modelId': 'v2-1', 'treatmentId': 'model_1', 'phrases': ['Mountain views', 'Dual-pane windows', 'Original wood floors', 'Stroll to greenlake', 'Paved alley', 'Formal dining room', 'Basement area']}]}], 'sellingSoon': [{'treatmentId': 'model_0', 'percentile': 0.91}], 'listingProvider': None, 'isIncomeRestricted': None, 'brokerId': None, 'ssid': 39, 'monthlyHoaFee': None, 'mortgageRates': {'fifteenYearFixedRate': 2.569, 'thirtyYearFixedRate': 3.339, 'arm5Rate': 2.49}, 'propertyTaxRate': 1.01, 'hiResImageLink': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-p_f.jpg', 'hdpTypeDimension': 'ForSale', 'mlsid': '1878274', 'propertyTypeDimension': 'Single Family', 'mediumImageLink': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-p_d.jpg', 'enhancedBrokerImageUrl': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_95_35.jpg', 'listingAccountUserId': 'X1-ZUwxzkwtzcwn49_35s1y', 'tourEligibility': {'isPropertyTourEligible': True}, 'contactFormRenderData': {'data': {'abad_eligible': False, 'agent_module': {'agent_reason': 3, 'badge_type': 'Listing Agent', 'business_name': 'Windermere Real Estate Whatcom', 'display_name': 'Chris Thorndike-Kent', 'encoded_zuid': 'X1-ZUwxzkwtzcwn49_35s1y', 'first_name': 'Chris', 'image_data': {'height': 60, 'url': 'https://photos.zillowstatic.com/h_n/ISint1houzxvps0000000000.jpg', 'width': 60}, 'phone': {'areacode': '360', 'number': '5210', 'prefix': '920'}, 'profile_url': '/profile/WhatcomCountyRE/', 'rating_average': 0, 'recent_sales': 0, 'review_count': 0, 'reviews_url': '/profile/WhatcomCountyRE/#reviews', 'services_offered': [1, 2, 4, 6, 33], 'write_review_url': '/reviews/write/?s=X1-ZUwxzkwtzcwn49_35s1y', 'zpro': True}, 'authentication': {'hmac': '774129ea6b13ee9b60ea6d102b4ea5847d0a0998aeb26316389b71d60bfbc0c2', 'request_id': '3504bdd383d311ec9f610aa07bc20932'}, 'brokerage_info_must_be_shown': False, 'contact_button_text': 'Contact Agent', 'contact_recipients': [{'agent_reason': 1, 'badge_type': 'Premier Agent', 'display_name': 'Doron Weisbarth', 'encoded_zuid': 'X1-ZUz8geoif5cu89_1sm5f', 'first_name': 'Doron', 'has_caliber_pal': False, 'has_pal': True, 'has_wells_fargo_pal': False, 'image_data': {'height': 60, 'url': 'https://photos.zillowstatic.com/h_n/IS3jjaky6f2tq00000000000.jpg', 'width': 60}, 'is_remnant': False, 'phone': {'areacode': '206', 'number': '3665', 'prefix': '202'}, 'profile_url': '/profile/Doron-Weisbarth/', 'rating_average': 4.9, 'recent_sales': 2, 'review_count': 435, 'reviews_url': '/profile/Doron-Weisbarth/#reviews', 'services_offered': [1, 2, 3, 7], 'write_review_url': '/reviews/write/?s=X1-ZUz8geoif5cu89_1sm5f'}], 'covid_options': {'show_virtual_tour_banner': False, 'virtual_tour_banner_copy': ''}, 'cv_27': {'bal_checkboxes': '0100', 'brokerage_product': '00', 'field_flags': '1', 'form_identifier': 'opaque_la', 'mortgage_flags': '1200'}, 'desktop_phone_number': None, 'display_options': {'is_opaque_eligible': True}, 'displayed_agents': [{'agent_reason': 1, 'badge_type': 'Premier Agent', 'display_name': 'Doron Weisbarth', 'encoded_zuid': 'X1-ZUz8geoif5cu89_1sm5f', 'first_name': 'Doron', 'has_caliber_pal': False, 'has_pal': True, 'has_wells_fargo_pal': False, 'image_data': {'height': 60, 'url': 'https://photos.zillowstatic.com/h_n/IS3jjaky6f2tq00000000000.jpg', 'width': 60}, 'is_remnant': False, 'profile_url': '/profile/Doron-Weisbarth/', 'rating_average': 4.9, 'recent_sales': 2, 'review_count': 435, 'reviews_url': '/profile/Doron-Weisbarth/#reviews', 'services_offered': [1, 2, 3, 7], 'write_review_url': '/reviews/write/?s=X1-ZUz8geoif5cu89_1sm5f'}, {'agent_reason': 1, 'badge_type': 'Premier Agent', 'display_name': 'Hao Dang', 'encoded_zuid': 'X1-ZUz6cqus7nce15_4aijn', 'first_name': 'Hao', 'has_caliber_pal': False, 'has_pal': True, 'has_wells_fargo_pal': False, 'image_data': {'height': 60, 'url': 'https://photos.zillowstatic.com/h_n/ISd0x9mypljfrw1000000000.jpg', 'width': 60}, 'is_remnant': False, 'profile_url': '/profile/Hao-Dang/', 'rating_average': 5, 'recent_sales': 17, 'review_count': 503, 'reviews_url': '/profile/Hao-Dang/#reviews', 'services_offered': [1, 2, 3, 7, 41], 'write_review_url': '/reviews/write/?s=X1-ZUz6cqus7nce15_4aijn'}, {'agent_reason': 1, 'badge_type': 'Premier Agent', 'display_name': 'Maynard Wagner', 'encoded_zuid': 'X1-ZUz52fz5evwzyh_5rw5l', 'first_name': 'Maynard', 'has_caliber_pal': False, 'has_pal': True, 'has_wells_fargo_pal': False, 'image_data': {'height': 60, 'url': 'https://photos.zillowstatic.com/h_n/IS6umzb5guzkqj1000000000.jpg', 'width': 60}, 'is_remnant': False, 'profile_url': '/profile/MWREG/', 'rating_average': 5, 'recent_sales': 1, 'review_count': 217, 'reviews_url': '/profile/MWREG/#reviews', 'services_offered': [1, 2, 3, 33, 41], 'write_review_url': '/reviews/write/?s=X1-ZUz52fz5evwzyh_5rw5l'}], 'displayed_lenders': [{'agent_encoded_zuid': 'X1-ZUz8geoif5cu89_1sm5f', 'display_name': 'Julie Johnson', 'image_data': {'height': 36, 'url': 'https://mortgageapi.zillow.com/getLenderProfileImage?lenderId=ZUz8v2sog96h3d_23up7&imageId=ab5d941f12f4d31ad892ca3c15e37d6b&treatment=36x36', 'width': 36}, 'lender_encoded_zuid': 'X1-ZUz8v2sog96h3d_23up7', 'nmls_license': 302214, 'phone': {'areacode': '206', 'number': '6031', 'prefix': '769'}, 'profile_url': '/lender-profile/juliealjohnson/'}, {'agent_encoded_zuid': 'X1-ZUz6cqus7nce15_4aijn', 'display_name': 'James Reischling', 'image_data': {'height': 36, 'url': 'https://mortgageapi.zillow.com/getLenderProfileImage?lenderId=ZU13maxvhucvitl_7sxq5&imageId=08b013dee86cd7226730431a1ff207e6&treatment=36x36', 'width': 36}, 'lender_encoded_zuid': 'X1-ZU13maxvhucvitl_7sxq5', 'nmls_license': 64001, 'phone': {'areacode': '425', 'number': '2109', 'prefix': '599'}, 'profile_url': '/lender-profile/thereischlinggroup/'}, {'agent_encoded_zuid': 'X1-ZUz52fz5evwzyh_5rw5l', 'display_name': 'Jimmy Vann', 'image_data': {'height': 36, 'url': 'https://mortgageapi.zillow.com/getLenderProfileImage?lenderId=ZUyj9jqgz4vpxl_a6mey&imageId=cc8bc38612009e2d103bb714dac6f891&treatment=36x36', 'width': 36}, 'lender_encoded_zuid': 'X1-ZUyj9jqgz4vpxl_a6mey', 'nmls_license': 126296, 'phone': {'areacode': '425', 'number': '3916', 'prefix': '998'}, 'profile_url': '/lender-profile/jimmyvann/'}], 'fallback_form': {'contact_recipients': [], 'cv_27': {'bal_checkboxes': '0000', 'brokerage_product': '00', 'field_flags': '0', 'form_identifier': 'agent_directory', 'mortgage_flags': '0'}, 'footers': [{'external': False, 'text': 'Visit professional directory', 'url': '/professionals/real-estate-agent-reviews/seattle-wa/'}], 'hidden_fields': [], 'subtitle': 'Visit our professional directory to find an agent in your area that can help with your home search.', 'title': 'Contact Agent', 'tour_eligible': False, 'variant': 'agent_directory'}, 'hidden_fields': [{'name': 'variant', 'value': 'opaque'}, {'name': 'zpid', 'value': 48760005}, {'name': 'mlsCode', 'value': '1878274'}, {'name': 'onlyPreapprovalContact', 'value': 'false'}, {'name': 'showNameField', 'value': 'true'}, {'name': 'showPhoneField', 'value': 'true'}, {'name': 'suppressAccountCreation', 'value': 'false'}, {'name': 'submitId', 'value': '42898a69-4e8a-41ce-87e2-c9a59f8dc6ec'}, {'name': 'showPhoneMandatoryField', 'value': 'true'}, {'name': 'fpa', 'value': 'X1-ZUz8geoif5cu89_1sm5f'}, {'name': 'leaderboardZuids', 'value': 'X1-ZUz8geoif5cu89_1sm5f,1'}, {'name': 'isSelectListingAgent', 'value': 'false'}, {'name': 'zuid', 'value': 'X1-ZUz8geoif5cu89_1sm5f'}, {'name': 'ccListingAgent', 'value': 'false'}, {'name': 'palZuids', 'value': '{"X1-ZUwxzkwtzcwn49_35s1y": "X1-ZUz1ci99gqj409_uwi3", "X1-ZUz8geoif5cu89_1sm5f": "X1-ZUz8v2sog96h3d_23up7"}'}, {'name': 'pixelId', 'value': '90a66d24-05fb-45a7-8b24-c91e3394bda8'}], 'hide_textarea': False, 'info_box_visible': True, 'keller_williams': False, 'lender_details': {'preapproval': {'checked': False, 'label': 'I want financing information', 'message_when_checked': 'A Zillow confirmed lender will contact you.'}, 'preapproval_info': {'property_value': 669000, 'state_abbr': 'WA', 'zipcode': '98103'}}, 'listing': {'pazhl_eligible': False, 'supports_unselected_leads': True}, 'opaque_la': True, 'pixel_id': '90a66d24-05fb-45a7-8b24-c91e3394bda8', 'pixel_url': 'https://www.zillowstatic.com/contact-pixel/9gXJLbbekh3EcgFgh+EPG6CtLETWuJ9o5Xqx2viH3M5jrlvJJ9WBZWdZJMKN0bgsCo1lkWHrQjzvB_kCftm++IiVO6uj1VikUygpTgg36Jk1H1eGHHFHrdipWV0xAiXkjarknWpen5aGkqfuOszfZNPd4gn_UrrslCaUQABJN5M=', 'premier_agent_preferred_property': True, 'region_phone_number': {'areacode': '206', 'number': '4927', 'prefix': '203'}, 'request_trace': {'xpi': None, 'xsi': 'e9261faf5bc0c5c9', 'xti': '7eef92a2d70092188e45352f46fd2bde'}, 'tcpa': True, 'text_area': {'name': 'message', 'value': 'I am interested in 766 N 65th St, Seattle, WA 98103.'}, 'text_fields': [{'input_type': 'text', 'name': 'name', 'pattern': '^[^!@#$%&*+=]+$', 'placeholder': 'Your Name', 'required': True, 'required_for_preapproval': True, 'tooltip': 'Please enter your name.'}, {'input_type': 'tel', 'intl': False, 'maxlength': 23, 'name': 'phone', 'placeholder': 'Phone', 'required': True, 'tooltip': 'Please enter a valid US or Canadian phone number.'}, {'input_type': 'email', 'name': 'email', 'placeholder': 'Email', 'required': True, 'tooltip': 'Please enter a valid email address.'}], 'title': 'Contact Agent', 'tour_config': {'useFoundation': True}, 'tour_eligible': False, 'variant': 'opaque'}}, 'responsivePhotos': [{'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-p_d.jpg'}, {'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_192.jpg', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_384.jpg', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.jpg', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_768.jpg', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_960.jpg', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1152.jpg', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1344.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1536.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_192.webp', 'width': 192}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_384.webp', 'width': 384}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.webp', 'width': 576}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_768.webp', 'width': 768}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_960.webp', 'width': 960}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1152.webp', 'width': 1152}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1344.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_1536.webp', 'width': 1536}]}, 'caption': '', 'subjectType': None, 'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-p_d.jpg'}], 'virtualTourUrl': None, 'hasApprovedThirdPartyVirtualTourUrl': False, 'photoCount': 35, 'livingAreaUnits': 'Square Feet', 'postingProductType': 'Standard', 'marketingName': None, 'richMedia': None, 'ZoDsFsUpsellTop': {'display': False, 'displayCategory': 'none', 'displayAttributes': {'leadType': 'PARTNER_LEADS_INTEREST_LIST'}, 'treatment': 'DISABLED', 'surfaceId': 'fshdp', 'placementId': 'wow-top', 'reason': 'The property is ineligible for displaying upsell'}, 'onsiteMessage': {'eventId': 'db8a64f5-d18a-48fb-a0cc-b4d7b4fb8f2b', 'decisionContext': {}, 'messages': [{'skipDisplayReason': None, 'shouldDisplay': True, 'isGlobalHoldout': False, 'isPlacementHoldout': False, 'placementName': 'HDPTopSlot', 'testPhase': 'PORTFOLIO_INTEGRATION', 'bucket': 'PORTFOLIO_INTEGRATION_TREATMENT', 'placementId': 399, 'passThrottle': True, 'lastModified': '1643630669', 'eventId': '9e2fabb0-3dee-423c-8989-15789b025f30', 'decisionContext': {'guid': '56196bd7-c4db-44a2-9b0d-3d530f2f2bf9', 'tealiumAudience': [], 'homeStatus': 'fsba', 'isZillowOwned': False, 'homeType': 'SINGLE_FAMILY', 'listPrice': 669000, 'zipcode': '98103', 'isAdsRestricted': False, 'shouldDisplayUpsell': False, 'zoMarketCode': 'PDX', 'placementId': 'wow-top', 'surfaceId': 'fshdp', 'displayCategory': 'none', 'leadType': 'PARTNER_LEADS_INTEREST_LIST'}, 'selectedTreatment': {'id': 2239, 'name': 'ZGM_Purchase_FSHDP_Pre_Qual', 'component': 'UpsellWrapper', 'status': 'PORTFOLIO', 'renderingProps': '{"actionLink":"https://www.zillow.com/mortgages/#/landing&source=Z_ForSaleHDP_Inline","actionText":"Find a lender","actionType":"url_link","background":"backgroundBlue","bodyMarkdownText":"Talking to a lender early to get pre-qualified for a mortgage can give you an advantage in a competitive market. <p class=\\"zg-mls-note\\">Zillow Group Marketplace, Inc. NMLS #1303160 </p><style> div[class*=Upsell-] .zg-mls-note{ font-size: 10px; font-weight: 400; position: absolute; right: 4px; bottom: 0; margin-bottom: -4px; color: grey; } </style>","headingMarkdownText":"Get pre-qualified for a loan","icon":"houseWithDollarSign","overrideMargin":"16px","hasBorder":false,"gaImpressionCategory":"Homes","gaImpressionAction":"ZGM Purchase Upsell","gaImpressionLabel":"Display|fshdp|wow-top|zgm-purchase|get-pre-qualified|omp","gaEngagementCategory":"Homes","gaEngagementAction":"ZGM Purchase Upsell","gaEngagementLabel":"Click|fshdp|wow-top|zgm-purchase|get-pre-qualified|omp","gaHoverCategory":"Homes","gaHoverAction":"ZGM Purchase Upsell","gaHoverLabel":"Hover|fshdp|wow-top|zgm-purchase|get-pre-qualified|omp"}', 'lastModified': '1637161726'}, 'qualifiedTreatments': [{'id': 2435, 'name': 'engage_fshdp_top_home-saves_personalized-recs', 'status': 'BASELINE_EVALUATION', 'lastModified': '1643202336'}, {'id': 2239, 'name': 'ZGM_Purchase_FSHDP_Pre_Qual', 'status': 'PORTFOLIO', 'lastModified': '1637161726'}, {'id': 2431, 'name': 'engage_fshdp_top_home-saves_get-updates', 'status': 'BASELINE_EVALUATION', 'lastModified': '1643202379'}]}]}, 'cityId': 16037, 'stateId': 59, 'zipPlusFour': '5306', 'foreclosureDefaultFilingDate': None, 'foreclosureAuctionFilingDate': None, 'foreclosureLoanDate': None, 'foreclosureLoanOriginator': None, 'foreclosureLoanAmount': None, 'foreclosurePriorSaleDate': None, 'foreclosurePriorSaleAmount': None, 'foreclosureBalanceReportingDate': None, 'foreclosurePastDueBalance': None, 'foreclosureUnpaidBalance': None, 'foreclosureAuctionTime': None, 'foreclosureAuctionDescription': None, 'foreclosureAuctionCity': None, 'foreclosureAuctionLocation': None, 'foreclosureDate': None, 'foreclosureAmount': None, 'foreclosingBank': None, 'foreclosureJudicialType': 'Non-Judicial', 'datePostedString': '2022-01-27', 'foreclosureTypes': {'isBankOwned': False, 'isForeclosedNFS': False, 'isPreforeclosure': False, 'isAnyForeclosure': False, 'wasNonRetailAuction': False, 'wasForeclosed': False, 'wasREO': None, 'wasDefault': None}, 'foreclosureMoreInfo': None, 'big': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-cc_ft_576.webp', 'width': 576}}}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.jpg', 'width': 576, 'subjectType': None, 'mixedSources': {'jpeg': {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.jpg', 'width': 576}, 'webp': {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-cc_ft_576.webp', 'width': 576}}}], 'hasPublicVideo': False, 'primaryPublicVideo': None, 'richMediaVideos': None, 'thirdPartyVirtualTour': {'approved': False, 'lightboxUrl': None, 'externalUrl': None, 'staticUrl': None, 'providerKey': None}, 'mapTileGoogleMapUrlSmall': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=14&size=280x208&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=syIKU4f2d-pYSvCZ0J9wIQfGOSc=', 'mapTileGoogleMapUrlFullWidthLightbox': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=16&size=1024x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=UNP6iwg_lvgv5sB4yE2dHQ2rvqk=', 'mapTileGoogleMapUrlFullWidthMax': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=16&size=1920x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=1&signature=nUbz6Hg5qbKaeian2GOxlFQOQ5I=', 'mapTileGoogleMapUrlSmallWholeZipcode': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=12&size=280x208&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=oti31-BJgG-j07qQCoOoswC0HX0=', 'mapTileGoogleMapUrlFullWidthLightboxWholeZipcode': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=12&size=1024x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=2&signature=g0A9sNNKcFarpe4tbdxBXe6cB68=', 'mapTileGoogleMapUrlFullWidthMaxWholeZipcode': 'https://maps.googleapis.com/maps/api/staticmap?center=47.676277,-122.348564&zoom=12&size=1920x234&maptype=roadmap&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&scale=1&signature=MjC-Yohgdb_IDcoc-mGFkQTJqHs=', 'postingUrl': None, 'streetViewMetadataUrlMapLightboxAddress': 'https://maps.googleapis.com/maps/api/streetview/metadata?location=766%20N%2065th%20St%2C%20Seattle%2C%20WA%2098103&key=AIzaSyBV4lXhV-qzQOegyA3m0_AvGy9F21HIyOQ&source=outdoor&signature=Y1mMr-j-laNe343VCU5a3Cm5q4g=', 'thumb': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-p_a.jpg'}], 'isCommunityPillar': False, 'listingSubType': {'isFSBA': True, 'isPending': False, 'isNewHome': False, 'isForeclosure': False, 'isBankOwned': False, 'isForAuction': False, 'isOpenHouse': False, 'isComingSoon': False, 'isFSBO': False}, 'tourViewCount': 0, 'postingContact': {'name': 'Chris Thorndike-Kent', 'photo': None}, 'vrModel': {'vrModelGuid': None, 'revisionId': None}, 'responsivePhotosOriginalRatio': [{'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/2850c3e4b5dcc19a81c6280bfa57a188-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/751caff0445ca4a4906a12103136ce87-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7f56f2aca81c29ce9fe953ac731d80c6-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/60d9efaea65d4aa0e22ed35ae72c9258-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/c69732cf1059202e027fc401540b6ca9-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/30d1f6fbe00cb4158ab5bca99a7ac31d-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/052599294a9148f86f291d1fbf2e8826-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cced25a05bd08737e53583807b429f8a-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f85b0edc42cc86fdf571d3df6d7dabd8-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/da21efa4db147a293707bec60c63975a-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/6429aa4600d403ef89b909a16b6882be-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9d0955b2d8e0f7f06a9c12b0a13a58a0-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cf0af2e2fa7da1bcbd23c44221efb6d3-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/d9d23885d22b95235a721aa9e150d016-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/bce97366c97da393e098cab49cb32481-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/ba5edb91d9f585322775cf1d082b5e8f-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/03486483741389761122e075e7c74980-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/7a12d6de649deb432bb766117cec9bc7-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/0e2afe6c5417fa89646050b89f8cae89-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbdfb46d5edc06809fe0d81fd0aa6975-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/079d244d7aa6f906b3025cc524c86eee-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/add8553a7a754cffeb51b26cc981f262-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/136e76a5ca111eb51a39bcf0bf1ca021-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/43b4e73c18df5145fce90384776a6309-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/8dedf086748c1da37d7ee86204dfaf80-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17f35f3928bd5bdfca599c35c3652652-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/17db9767254a10927f44becaa22b6515-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1d06cb206020ecb91cd5bc3f372759b7-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/253e4880aa2ac23c903c0b2e932e67b9-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/9352044ad8c91d5d1e387a0383dcb277-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/07a9076142102432119659a0e5699771-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/1c81cfbcbfb51953c4d275643d4a8dca-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/f6a0e8bf546ef9cf1d8f577ea8a376fd-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/cbe7944c4d7a70de7534546a9ca53724-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}, {'caption': '', 'mixedSources': {'jpeg': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-d_d.jpg', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-o_a.jpg', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-uncropped_scaled_within_1344_1008.jpg', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-uncropped_scaled_within_1536_1152.jpg', 'width': 1536}], 'webp': [{'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-d_d.webp', 'width': 800}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-o_a.webp', 'width': 1024}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-uncropped_scaled_within_1344_1008.webp', 'width': 1344}, {'url': 'https://photos.zillowstatic.com/fp/73925be869ba4cdb8965b749c7b49741-uncropped_scaled_within_1536_1152.webp', 'width': 1536}]}}], 'listingAccount': None, 'topNavJson': {'topnav': {'json': {'logo': {'text': 'Zillow Real Estate', 'href': '/'}, 'main': {'sections': [{'link': {'text': 'Buy', 'href': '/homes/', 'classString': 'noroute'}, 'subsections': [{'title': 'Seattle homes for sale', 'links': [[{'text': 'Homes for sale', 'href': '/seattle-wa/', 'classString': 'noroute'}, {'text': 'Foreclosures', 'href': '/seattle-wa/foreclosures/', 'classString': 'noroute'}, {'text': 'For sale by owner', 'href': '/seattle-wa/fsbo/', 'classString': 'noroute'}, {'text': 'Open houses', 'href': '/seattle-wa/open-house/', 'classString': 'noroute'}], [{'text': 'New construction', 'href': '/seattle-wa/new-homes/', 'classString': 'noroute'}, {'text': 'Coming soon', 'href': '/seattle-wa/coming-soon/', 'classString': 'noroute'}, {'text': 'Recent home sales', 'href': '/seattle-wa/sold/', 'classString': 'noroute'}, {'text': 'All homes', 'href': '/browse/homes/'}]]}, {'title': 'Bundle buying & selling', 'links': [{'text': 'Buy and sell with Zillow 360', 'href': '/z/zillow-360/?t=z360-buy-topnav'}]}, {'title': 'Resources', 'links': [[{'text': 'Buyers Guide', 'href': '/home-buying-guide/'}, {'text': 'Foreclosure center', 'href': '/foreclosures/'}, {'text': 'Real estate app', 'href': '/mobile/realestate/'}, {'text': "Find a buyer's agent", 'href': '/professionals/real-estate-agent-reviews'}]]}]}, {'link': {'text': 'Rent', 'href': '/homes/for_rent/', 'classString': 'noroute'}, 'subsections': [{'title': 'Seattle rentals', 'links': [{'text': 'Rental buildings', 'href': '/seattle-wa/rental-buildings/', 'classString': 'noroute'}, {'text': 'Apartments for rent', 'href': '/seattle-wa/apartments/', 'classString': 'noroute'}, {'text': 'Houses for rent', 'href': '/seattle-wa/rent-houses/', 'classString': 'noroute'}, {'text': 'All rental listings', 'href': '/seattle-wa/rentals/', 'classString': 'noroute'}, {'text': 'All rental buildings', 'href': '/browse/b/'}]}, {'title': 'Renting', 'links': [{'text': 'Contacted rentals', 'href': '/renting/'}, {'text': 'Your rental', 'href': '/renting/your-rental/'}, {'text': 'Messages', 'href': '/renter-hub/inbox/'}]}, {'title': 'Resources', 'links': [{'text': 'Affordability calculator', 'href': '/rent-affordability-calculator/', 'gaClickEventObj': {'category': 'renter_tools', 'action': 'click', 'label': 'affordability'}}, {'text': 'Renters guide', 'href': '/rent/guide/', 'gaClickEventObj': {'category': 'renter_tools', 'action': 'click', 'label': 'guide'}}]}], 'gaHoverEventObj': {'category': 'nav_menu', 'action': 'mouseover', 'label': 'rent'}, 'gaExpandoClickObj': {'category': 'nav_menu', 'action': 'click_down', 'label': 'rent'}}, {'link': {'text': 'Sell', 'href': '/sell/'}, 'gaHoverEventObj': {'category': 'nav_menu', 'action': 'mouseover', 'label': 'sell'}, 'subsections': [{'title': 'Resources', 'links': [{'text': 'Explore your options', 'href': '/sell/'}, {'text': "See your home's Zestimate", 'href': '/how-much-is-my-home-worth/', 'gaClickEventObj': False}, {'text': 'Seattle Home values', 'href': '/seattle-wa/home-values/'}, {'text': 'Sellers guide', 'href': '/sellers-guide/'}]}, {'title': 'Bundle buying & selling', 'links': [{'text': 'Buy and sell with Zillow 360', 'href': '/z/zillow-360/?t=z360-sell-topnav'}]}, {'title': 'Selling options', 'links': [{'text': 'Sell with Zillow Offers', 'href': '/offers/?t=zo-sell-with-subnav', 'gaClickEventObj': False}, {'text': "Find a seller's agent", 'href': '/professionals/real-estate-agent-reviews/seattle-wa/?service=Selling'}, {'text': 'Post For Sale by Owner', 'href': '/for-sale-by-owner/'}]}]}, {'link': {'text': 'Home Loans', 'href': '/home-loans/#source=Z_Mortgagestopnav'}, 'subsections': [{'title': 'Shop mortgages', 'links': [{'text': 'Mortgage lenders', 'href': '/mortgages/#source=Z_Mortgageshovertopnav'}, {'text': 'HELOC lenders', 'href': '/mortgages/heloc/#source=Z_Mortgageshovertopnav'}, {'text': 'Mortgage rates', 'href': '/mortgage-rates/wa/seattle/'}, {'text': 'Refinance rates', 'href': '/refinance/wa/seattle/'}, {'text': 'All mortgage rates', 'href': '/mortgage/browse/'}]}, {'title': 'Calculators', 'links': [{'text': 'Mortgage calculator', 'href': '/mortgage-calculator/'}, {'text': 'Refinance calculator', 'href': '/mortgage-calculator/refinance-calculator/'}, {'text': 'Affordability calculator', 'href': '/mortgage-calculator/house-affordability/'}, {'text': 'Amortization calculator', 'href': '/mortgage-calculator/amortization-schedule-calculator/'}, {'text': 'Debt-to-Income calculator', 'href': '/mortgage-calculator/debt-to-income-calculator/'}]}, {'title': 'Resources', 'links': [{'text': 'Lender reviews', 'href': '/lender-directory/'}, {'text': 'Mortgage learning center', 'href': '/mortgage-learning/'}, {'text': 'Mortgages app', 'href': '/mobile/mortgages/'}, {'text': 'Lender resource center', 'href': '/lender-resources/'}]}]}, {'link': {'text': 'Agent finder', 'href': '/professionals/real-estate-agent-reviews/seattle-wa/'}, 'subsections': [{'title': 'Looking for pros?', 'links': [[{'text': 'Real estate agents', 'href': '/professionals/real-estate-agent-reviews/seattle-wa/'}, {'text': 'Property managers', 'href': '/professionals/property-manager-reviews/seattle-wa/'}, {'text': 'Home inspectors', 'href': '/professionals/home-inspector-reviews/seattle-wa/'}, {'text': 'Other pros', 'href': '/professionals/real-estate-services-reviews/seattle-wa/'}], [{'text': 'Home improvement pros', 'href': '/professionals/home-improvement-reviews/seattle-wa/'}, {'text': 'Home builders', 'href': '/home-builders/seattle-wa/16037/'}, {'text': 'Real estate photographers', 'href': '/professionals/photographer-reviews/seattle-wa/'}]]}, {'title': "I'm a pro", 'links': [[{'text': 'Agent advertising', 'href': 'https://premieragent.zillow.com/products/advertising/?itc=paw_z_sitewide-agentfinder_subnav-advertising_pa-ads_a_null'}, {'text': 'Agent resource center', 'href': '/agent-resources/'}, {'text': 'Create a free agent account', 'href': '/premier-agent/agent-account/?itc=paw_z_sitewide-agentfinder_subnav-createagentaccount_pa-reg_a_null'}], [{'text': 'Real estate business plan', 'href': '/agent-resources/agent-toolkit/real-estate-business-plan-template/'}, {'text': 'Real estate agent scripts', 'href': '/agent-resources/agent-toolkit/real-estate-follow-up-email-templates/'}, {'text': 'Listing flyer templates', 'href': '/agent-resources/agent-toolkit/real-estate-listing-flyer-templates/'}]]}]}]}, 'agent': False, 'marketing': {'sections': [{'link': {'text': 'Manage Rentals', 'href': '/rental-manager/?source=topnav&itc=postbutton_sitenav', 'classString': 'noroute'}, 'classString': 'znav-manage-rentals', 'id': 'manage-rentals', 'gaHoverEventObj': {'category': 'nav_menu', 'action': 'mouseover', 'label': 'manage_rentals'}, 'gaExpandoClickObj': {'category': 'nav_menu', 'action': 'click_down', 'label': 'manage_rentals'}, 'subsections': [{'title': 'Rental Management Tools', 'links': [[{'text': 'List a rental', 'href': '/rental-manager/post-a-listing?itc=ltr_zw_ltr_zrm-home_tpnv_post-a-listing', 'id': 'list_a_rental', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'list'}}, {'text': 'My Listings', 'href': '/rental-manager/select-property?type=listings&source=topnav&itc=postbutton_topnav', 'id': 'my_listings', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'listing'}}, {'text': 'Messages', 'href': '/rental-manager/inbox/', 'id': 'messages', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'messages'}}, {'text': 'Applications', 'href': '/rental-manager/select-property?type=applications&source=topnav&itc=postbutton_topnav', 'id': 'applications', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'applications'}}, {'text': 'Leases', 'href': '/rental-manager/select-property?type=leases&source=topnav&itc=postbutton_topnav', 'id': 'leases', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'leases'}}, {'text': 'Payments', 'href': '/rental-manager/select-property?type=payments&source=topnav&itc=postbutton_topnav', 'id': 'payments', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'payments'}}]]}, {'title': 'Learn More', 'links': [[{'text': 'Zillow Rental Manager', 'href': '/rental-manager/?source=topnav&itc=list_zrm_topnav', 'id': 'zrm', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'about'}}, {'text': 'Price My Rental', 'href': '/rental-manager/price-my-rental/?itc=ltr_zw_ltr_zrm-home_tpnv_price-my-rental', 'id': 'price_my_rental', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'price'}}, {'text': 'Resource Center', 'href': '/rental-manager/resources/', 'id': 'resource_center', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'resource'}}, {'text': 'Help Center', 'href': 'https://help.zillowrentalmanager.com/hc/en-us/', 'id': 'help_center', 'classString': 'noroute', 'gaClickEventObj': {'category': 'manage_rentals', 'action': 'click', 'label': 'help'}}]]}]}, {'link': {'text': 'Advertise', 'href': '/z/partners/advertise/'}}]}, 'regLogin': {'sections': [{'link': {'text': 'Sign in', 'href': '/user/acct/login/?cid=pf'}}, {'link': {'text': 'Join', 'href': '/user/acct/register/?cid=pf'}}]}, 'help': {'sections': [{'link': {'text': 'Help', 'href': 'https://zillow.zendesk.com/hc/en-us/'}}]}, 'common': {'home': {'text': 'Zillow Real Estate', 'href': '/'}, 'advertise': {'text': 'Advertise', 'href': '/advertise/'}, 'login': {'text': 'Sign in', 'href': '/user/acct/login/'}, 'register': {'text': 'Join', 'href': '/user/acct/register/'}}}}, 'core': {'js': 'https://s.zillowstatic.com/s3/pfs/core-e2fcd5461d18b7b549f7.js'}}, 'listingFeedID': None, 'priceChange': None, 'priceChangeDate': None, 'priceChangeDateString': None, 'formattedChip': {'location': [{'fullValue': '766 N 65th St'}, {'fullValue': 'Seattle, WA 98103'}]}, 'hideZestimate': False, 'comingSoonOnMarketDate': None, 'isPreforeclosureAuction': False, 'isRecentStatusChange': False, 'isNonOwnerOccupied': False, 'buildingId': None, 'county': 'King County', 'isFeatured': False, 'rentalApplicationsAcceptedType': 'REQUEST_TO_APPLY', 'listingTypeDimension': 'For Sale by Agent', 'featuredListingTypeDimension': 'organic', 'brokerIdDimension': 'For Sale by Agent', 'keystoneHomeStatus': 'ForSale', 'pageUrlFragment': 'ForSale', 'isRentalsLeadCapMet': False, 'isPaidMultiFamilyBrokerId': False, 'selfTour': {'hasSelfTour': False}}, 'viewer': None, 'abTests': {'AB_DASHBOARD_AA_TEST': 'CONTROL', 'ACT_THREE_ICON_CTA_TOUR_TEXT': 'CONTROL', 'ACT_THREE_ICON_CTA': 'ON', 'ADT_DESKTOP_HDP_CALLOUT': 'SAVE_AND_SHARE', 'ADT_HDP_CALLOUT': 'SAVE_AND_SHARE', 'AIPERS_SIMILAR_HOMES_GDP': 'CONTROL', 'AndroidMagellanHDP': 'MAGELLAN_HDP_ON', 'AR_BUYER_INITIATED_RELATIONSHIP_UI': 'CONTROL', 'AR_CSAT_ONSITE_HDP': 'ON', 'AR_CSAT_MODAL_HDP_LOAD_DELAY': 'CONTROL', 'AR_SHOWCASE_HDP_WIDGET': 'CONTROL', 'AR_BUYER_INITIATED_RELATIONSHIPS_DELAY': 'CONTROL', 'ARCS_A11Y_UI': 'ON', 'ARCS_ABAD_ATL': 'ON', 'ARCS_ABAD_PHX': 'CONTROL', 'ARCS_AFFILIATION_MESSAGING': 'CONTROL', 'ARCS_DESKTOP_INLINE_FORM_PLACEMENT': 'BELOW_FACTS_AND_FEATURES', 'ARCS_THREE_BUTTONS_APPS': 'ON_FOR_IOS', 'ARCS_THREE_BUTTONS_APPS_ANDROID': 'ON', 'ARCS_APPS_REWRITE': 'ON', 'ARCS_BAL_RADIO_REMOVAL': 'CONTROL', 'ARCS_BAL_REWRITE': 'ON', 'ARCS_BAL_TO_OPAQUE': 'ON', 'ARCS_BETH_VALUE_PROPS': 'CONTROL', 'ARCS_CLIENT_GEN_LEAD_ID': 'CONTROL', 'ARCS_EXPANDED_OPAQUE_SELLER_TITLE': 'ON', 'ARCS_FEATURED_IMAGE': 'CONTROL', 'ARCS_FEATURED_REWRITE': 'ON', 'ARCS_FORECLOSURE_REWRITE': 'ON', 'ARCS_GET_A_CALL': 'CONTROL', 'ARCS_INLINE_TOUR': 'ON_BUYERS_AGENT', 'ARCS_INLINE_TOUR_SECTION': 'ON', 'ARCS_LISTING_AGENT_RELOCATION': 'CONTROL', 'ARCS_MY_AGENT_A11Y_UI': 'ON', 'ARCS_MY_AGENT_REWRITE': 'ON', 'ARCS_NY_AD_COMPLIANCE': 'ON', 'ARCS_OPAQUE_EXPANSION_VALUE_PROPS': 'CONTROL', 'ARCS_OPAQUE_REWRITE': 'ON', 'ARCS_OWNER_REWRITE': 'ON', 'ARCS_PA_ZHL_LEAD': 'CONTROL', 'ARCS_PREAPPROVAL_CHECK': 'CONTROL', 'ARCS_PROPERTY_CFRD': 'ON', 'ARCS_REGION_PHONE': 'ON', 'ARCS_REMOVE_FINANCING': 'CONTROL', 'ARCS_SCHEDULE_A_TOUR_DESKTOP': 'ON', 'ARCS_SCHEDULE_A_TOUR_MOBILE': 'ON', 'ARCS_STREAMLINED_TOURS': 'T2_Simple_w_Photo', 'ARCS_STREAMLINED_TOURS_DESKTOP': 'ON', 'ARCS_TOUR_MESSAGE': 'CONTROL', 'ARCS_TOUR_TIME': 'TIME_SHOWN', 'ARCS_TOUR_REWRITE': 'ON', 'ARCS_WOW_LISTING_AGENT_ATTRIBUTION': 'ON', 'ARCS_CONTACTABLE_LISTING_AGENT': 'CONTROL', 'ARCS_DESKTOP_PHONE': 'CONTROL', 'ARCS_TOUR_UPGRADE_V1': 'CONTROL', 'AUTH_REG_LOGIN_STRONG_PASS2': 'TEST', 'CDP_SERVICE': 'ON', 'HDP_3D_WITH_BANNER': 'CONTROL', 'HDP_AD_MWEB': 'ON', 'HDP_AND_SEARCH_MAGELLAN': 'ON', 'HDP_CLASSIC_OM_REFI_UPSELL': 'ON', 'HDP_DESKTOP_LAYOUT_TOPNAV': 'CONTROL', 'HDP_DQ': 'ON', 'HDP_DQ_FS_OTHER': 'CONTROL', 'HDP_DQ_FSBA': 'CONTROL', 'HDP_DQ_NFS_RS': 'CONTROL', 'HDP_DQ_OVERRIDE': 'CONTROL', 'HDP_FNF_BULLETS': 'ON', 'HDP_FULL_SSR_FS_POT': 'ON', 'HDP_FULL_SSR_NC': 'CONTROL', 'HDP_FULL_SSR_NFS': 'ON', 'HDP_FULL_SSR_RENT': 'CONTROL', 'HDP_GOOGLE_STREETVIEW': 'CONTROL', 'HDP_HFF_ACCORDION': 'ON', 'HDP_HOMES_FOR_YOU_RECS_PLACEMENT': 'CONTROL', 'HDP_HOME_INSIGHTS': 'ON', 'HDP_INSIGHTS_VERSION': 'CONTROL', 'HDP_IMAGE_CAROUSEL_CHEVRON': 'ON', 'HDP_OPEN_HOUSE_SAVE_WEB': 'CONTROL', 'HDP_OPEN_HOUSE_SAVE': 'APP_ONLY', 'HDP_REDUCE_RERENDERS': 'CONTROL', 'HDP_REORDER_AT_A_GLANCE': 'CONTROL', 'HDP_SELLING_SOON_MSG': 'MOBILE_VARIANT_1', 'HDP_STATIC_COMMUTE_MAP': 'CONTROL', 'HDP_THROTTLE_SCROLL_EVENTS': 'ON', 'HDP_TOP_SLOT': 'ONSITE_MESSAGING', 'HDP_UPDATED_FNF': 'ON', 'HDP_UPDATED_STATS_DISPLAY': 'CONTROL', 'HDP_VT_HIGHER': 'ON', 'HDP_WEBVIEW_ZO_UPSELL': 'ON', 'HDP_WOW_CLASSIC_MWEB': 'CLASSIC_WOW', 'HDP_WOW_FSBA': 'ON', 'HDP_WOW_MORTGAGE_ITERATIONS': 'CONTROL', 'HDP_WOW_NFS_OWNER_VIEW_LINK': 'CONTROL', 'HDP_WOW_PANO': 'ON', 'HDP_WOW_RS_AND_NFS': 'ON', 'HDP_WOW_RS_AND_NFS_UPSELL': 'REFI_UPSELL', 'HDP_YOUR_HOME_COMPS_MODULE': 'ON_V1', 'HDP_ZMA': 'ON_ENFORCE_PW', 'HDP_ZMA_UPDATED_TERMS': 'ON', 'HDP_ZO_ABAD_NOTIFICATION': 'ON', 'HDP_ZO_DATA_BAL': 'CONTROL', 'HDP_ZO_WARRANTY_VP': 'BOTH_ON', 'HDP_HIGHER_3D': 'ON', 'HDP_SIMILAR_HOMES_PLACEMENT': 'ABOVE_PERSONAL_GUIDE_MODULE', 'HDP_ZHVI_CHART_MIGRATION': 'CONTROL', 'HDP_NEIGHBORHOOD_SEE_MORE': 'CONTROL', 'HDP_STREAMLINE_COMMUTE': 'CONTROL', 'IARCS_MY_AGENT_TOURING': 'ON', 'INSTANTOFFERS_UPSELLS_FORSALE': 'BUY_SELL', 'IOS_MAGELLAN_HDP': 'ON', 'KeystoneEvents3DHome': 'SEND_EVENT', 'NFSHDP_OWNER_OPTIONS_GOOGLE_AD': 'CONTROL', 'NOOP': None, 'OM_NOO_ZO_ELIGIBLE_RENTAL_UPSELL': 'ON', 'PERF_DEFERRED_HYDRATION': 'ON', 'PERF_HDP_SSR': 'ON', 'PERF_HDP_WEBP': 'ENABLED', 'PERF_REDUCE_SSR_IMAGES': 'ENABLED', 'PERF_PRELOAD_HDP_IMAGE': 'CONTROL', 'PA_FLEXIBLE_CTA_WIDGET': 'CONTROL', 'PERS_SHARED_FAVORITES_FEATURE': 'FEATURES_ON', 'PERS_SHARED_FAVORITES': 'CONTROL', 'PL_UPSELL_COPY': 'VARIANT_C', 'RE_Application_Upsell': 'TEST', 'RE_Mweb_Application_Upsell': 'CONTROL', 'RE_BlendedHomeRecsModule': 'CONTROL', 'RE_CANADA_CTA': 'CONTROL', 'RE_COVID_Tours': 'REMOVE_TOUR', 'RE_HDP_HOME_INSIGHTS': 'CONTROL', 'RE_HDP_HOME_INSIGHTS_VERSION': 'CONTROL', 'RE_IDVBadge': 'CONTROL', 'RE_Irene_Owner_Application_Upsell': 'TEST', 'RE_PRODUCT_MARKUP': 'CONTROL', 'RE_LOCAL_PROTECTIONS': 'ON', 'RE_OFF_MARKET_COMSCORE': 'TEST', 'RE_REQUEST_TOUR_NEW_LOOK': 'TEST', 'RE_RENTER_PROFILE_V3_REFRESH': 'TEST_A', 'RE_OMP_TOP_SLOT': 'TEST', 'RMX_3RD_PARTY_P1': 'ON', 'RMX_3RD_PARTY_HDP_UPDATE': 'ON', 'STABLE_HOME_VALUE_MODULE': 'CONTROL', 'SXP_HDP_Load_Order': 'OPTIMIZED', 'RE_SEO_Add_internal_links_from_HDPstoSRPs': 'TEST', 'rmxTiledPano': 'ON', 'RR_MF_OFFICE_HOUR_TOURS': 'ON', 'RR_REAL_TIME_MF_TOUR_SCHEDULING': 'CONTROL', 'RR_RENTER_PROFILE_V2': 'TEST', 'RR_RENTER_PROFILE_V2_APPS': 'TEST', 'SI_DownPaymentAssistance': 'ON_NO_CITY_FILTER', 'SI_DownPaymentVALender': 'CONTROL', 'SI_RenterInfo': 'TEST', 'SI_ShareWithCommunityPartner': 'ON', 'SEOTEST__HDP_3D_HOME_TOUR_META_DESCRIPTION': 'CONTROL', 'SPT_PSL_TO_PDC_IN_GDP': 'ON', 'SPT_RENDER_FOR_RENT_PAGE': 'CONTROL', 'SPT_RENDER_FOR_SALE_PAGE': 'ON', 'SXP_HDP_BLUE_TO_RED': 'ON', 'SXP_HDP_CONTINGENT_V2': 'ON', 'TRACK_HOME_VALUE_V1': 'COPY_A', 'UnassistedHomeShowingWeb': 'TREATMENT', 'VL_BDP_NEW_TAB': 'CONTROL', 'VL_HDP_MODULE': 'CONTROL', 'z3dNavArrowStyle': None, 'ZGMIAIR_CHIP_ZHL_PREQUAL': 'CONTROL', 'ZO_ABC_SellingQuestion': 'CONTROL', 'ZO_HDP_CHIP': 'CONTROL', 'ZO_HDP_HOUR_ONE_VIDEO': 'CONTROL', 'ZO_REDIRECT_ZO_UPSELL_TO_QUESTIONNAIRE': 'CONTROL', 'ZO_Rewards_FSHDP_Upsell': 'CONTROL', 'ZO_UPSELL_CHECK_FROM_OASIS': 'ON', 'ZO_OMHDP_Inline_Upsell': 'CONTROL', 'IMX_LIGHTBOX': 'ON', 'IMX_PHASE_2': 'CONTROL', 'IMX_REPORT_PROBLEM': 'CONTROL', 'z3dPanOnPageScroll': None, 'ZO_FSHDP_RTBP': 'CONTROL', 'ZO_FSHDP_RTBP_M3': 'CONTROL', 'HDP_SSR_WRAPPED_CONTENT_ONLY_FOR_BOTS': 'ON'}}}

# %%
def dict_find(element, dictionary, path=[]):
    for kt in dictionary.items():
        if type(kt[1]) == list:
            path2 = copy.copy(path)
            path2.append(kt[0])
            lst_find(element, kt[1], path2)
        elif type(kt[1]) == dict:
            path2 = copy.copy(path)
            path2.append(kt[0])
            dict_find(element, kt[1], path2)
        else:
            if kt[0] == element:
                print(path)
           #     return path

def lst_find(element, lst, path):
    for k in range(len(lst)):
        if lst[k] == 0:
            break
        elif type(lst[k]) == list:
            path2 = copy.copy(path)
            path2.append(k)
            lst_find(element, lst[k], path2)
        elif type(lst[k]) == dict:
            path2 = copy.copy(path)
            path2.append(k)
            dict_find(element, lst[k], path2)
        else:
            if lst[k] == element:
                print(path)
             #   return path

def json_find(key, json_):
    pass
dict_find('taxAnnualAmount', G)
print('\n')
dict_find('monthlyHoaFee', G)
print('\n')
dict_find('lotSize', G)
print('\n')
dict_find('yearBuilt', G)
print('\n')
# Out:
# ['ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}', 'property', 'resoFacts']
#
#
# ['ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}', 'property']
#
#
# ['VariantQuery{"zpid":48760005,"altId":null}', 'property']
# ['ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}', 'property', 'resoFacts']
# ['ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}', 'property']
# ['ForSaleShopperPlatformFullRenderQuery{"zpid":48760005,"contactFormRenderParameter":{"zpid":48760005,"platform":"desktop","isDoubleScroll":true}}', 'property', 'nearbyHomes', 0]
# ...
